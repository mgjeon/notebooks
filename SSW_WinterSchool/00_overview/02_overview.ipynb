# %% [markdown]
# # 2024-03-24 G4 Geomagnetic Storm
#
# - Date: 2024. 03. 24.
# - Dst: -130 nT
# - Shock arrival: March 24 20:35 UT
# - CME: Halo CME March 23 01:25 UT (CCMC CME Scoreboard)
# - Flare: X1.1 AR3614(+3615) (S14 E15) March 23 01:33 UT
# - Reference: Mavromichalaki et al. 2024

# %% [markdown]
# # CCMC
#
# ## Geomagnetic Storm (2024-03-24T12:00Z)
# https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/29769/1
# ```
# Geomagnetic Storm
# Catalog: M2M_CATALOG
# Start Time: 2024-03-24T12:00Z
# KP Index list :
# NOAA KP index 6.0 with synoptic period end time 2024-03-24T15:00Z by Hannah Hermann
# NOAA KP index 6.0 with synoptic period end time 2024-03-24T15:00Z by Auto Generated
# NOAA KP index 8.0 with synoptic period end time 2024-03-24T18:00Z by Auto Generated
# NOAA KP index 6.33 with synoptic period end time 2024-03-24T21:00Z by Auto Generated
# Activity ID: 2024-03-24T12:00:00-GST-001 (version 1)
# ```
#
# ## Interplanetary Shock (or CME Arrival) (2024-03-24T14:10Z)
# https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/IPS/29767/1
# ```
# Interplanetary Shock (or CME Arrival)
# Catalog: M2M_CATALOG
# Location: Earth
# Event Time: 2024-03-24T14:10Z ( DSCOVR: PLASMAG )
# All Detecting Spacecrafts:
# DSCOVR: PLASMAG
# ACE: SWEPAM
# ACE: MAG
# Activity ID: 2024-03-24T14:10:00-IPS-001 (version 1)
# ```
#
# ## Magnetopause Crossing (2024-03-24T16:25Z)
# https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/MPC/29770/1
# ```
# Magnetopause Crossing
# Catalog: M2M_CATALOG
# Event Time: 2024-03-24T16:25Z ( MODEL: SWMF )
# Activity ID: 2024-03-24T16:25:00-MPC-001 (version 1)
# ```

# %% [markdown]
# ## Solar Flare (2024-03-23T00:58Z)
# https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/FLR/29708/5
# ```
# Catalog: M2M_CATALOG
# Start Time: 2024-03-23T00:58Z ( GOES-P: EXIS 1.0-8.0 )
# Peak Time: 2024-03-23T01:33Z
# End Time: 2024-03-23T02:21Z
# Intensity: X1.1 class
# Source region N25E07 (13614)
# Activity ID: 2024-03-23T00:58:00-FLR-001 (version 5)
# Note: This flare appears to be a sympathetic eruption from both AR 3614 (flare centered ~N25E07) and AR 3615 (flare centered ~S14E15) in opposite hemispheres. The primary association is given to AR 3615 as it is marginally brighter of the two, but AR 3614 appears to be associated with an eruption/EUV wave seen in SDO AIA 193 while AR 3615 is not. Further analysis may need to be conducted of this event.
# ```
#
# ## Coronal Mass Ejection (2024-03-23T01:25Z)
# https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/29715/3
# ```
# Coronal Mass Ejection
# Catalog: M2M_CATALOG
# Start Time: 2024-03-23T01:25Z ( SOHO: LASCO/C2 )
# All Detecting Spacecrafts:
# SOHO: LASCO/C2
# SOHO: LASCO/C3
# STEREO A: SECCHI/COR2
# Activity ID: 2024-03-23T01:25:00-CME-001 (version 3)
# Source Location: N25E07
# Active Region Number: 13614
# Note Keyword:
# FOV: Front Bright front; may be evidence of pileup
# GAP: Data gap
# HAL: Halo CME
# OFL: Outflowing material at the back of the CME
# OVR: Event partially overlaps with another CME
# SEP: Solar Energetic Particle event
# Source Signature Keyword:
# FLR: Flare
# DFLR: Double ribbon flare
# PEA: Post eruption arcade
# DIM: Dimming
# EUVW: EUV Wave
# Morphology Keyword:
# FS: Flux Rope and Shock Candidate
# Note: Bright partial halo CME first seen to the north in SOHO LASCO C2 (appearing a few timestamps before the second northern front and the faint full halo to the SW). The CME is associated with the X1.1-class flare from Active Region 3614 centered ~N25E07 and with the associated eruption seen as an extensive EUV wave in SDO AIA 193, and as a NE-SW oriented large area of dimming and high post eruptive arcades roughly centered around Active Region 3614. This X-class flare is was also accompanied by/contributed to by a concurrent flare from Active Region 3615 (S14E15).
# ```
#
# ## Coronal Mass Ejection (2024-03-23T01:48Z)
# https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/29736/3
# ```
#
# Coronal Mass Ejection
# Catalog: M2M_CATALOG
# Start Time: 2024-03-23T01:48Z ( SOHO: LASCO/C2 )
# All Detecting Spacecrafts:
# SOHO: LASCO/C2
# SOHO: LASCO/C3
# STEREO A: SECCHI/COR2
# Activity ID: 2024-03-23T01:48:00-CME-001 (version 3)
# Active Region Number: 13615
# Note Keyword:
# COL: Possible collision with previous CME
# FOV: Front Bright front; may be evidence of pileup
# GAP: Data gap
# HAL: Halo CME
# OVR: Event partially overlaps with another CME
# SEP: Solar Energetic Particle event
# Source Signature Keyword:
# FLR: Flare
# PEA: Post eruption arcade
# DIM: Dimming
# Morphology Keyword:
# FS: Flux Rope and Shock Candidate
# Note: This CME is visible as a partial halo to the northwest following the front of the earlier CME, with a fainter shock front portion visible to the southwest in SOHO LASCO C2/C3 imagery. There is a data gap in STEREO A COR2 from 2024-03-22T18:23Z to 2024-03-23T03:23Z, after which the end of this event is seen for a few frames before exiting the field of view but it overlaps in coronagraphs with the previous CME. The possible source the slower developing dimming to the SSW of Active Region 3614 (N25E07) following the initial X1.1 class flare, EUV wave and deep northern dimming to the NE of this Active Region. Alternative source is the concurrent flare from Active Region 3615 (S14E15). This event likely with CME: 2024-03-23T01:25Z.
# ```
#
# ## Solar Energetic Particle (2024-03-23T05:57Z)
# ```
# 2024-03-23T05:57:00-SEP-001
# SOHO: COSTEP 15.8-39.8 MeV
# 2024-03-23T06:49:00-SEP-001
# SOHO: COSTEP 28.2-50.1 MeV
# 2024-03-23T08:15:00-SEP-001
# GOES-P: SEISS >10 MeV
# 2024-03-23T09:55:00-SEP-001
# STEREO A: IMPACT 13-100 MeV
# ```

# %% [markdown]
# ## WSA-ENLIL+Cone Model For 2.0 AU with Completion Time: 2024-03-23T16:27Z
#
# ```
# Model Inputs:
# 2024-03-23T01:25:00-CME-001 with CME Analysis: Lon.=2.0, Lat.=22.0, Speed=1613.0, HalfAngle=41.0, Time21.5=2024-03-23T03:19Z
# 2024-03-23T01:48:00-CME-001 with CME Analysis: Lon.=5.0, Lat.=5.0, Speed=1572.0, HalfAngle=45.0, Time21.5=2024-03-23T03:50Z
#
# Model Outputs:
# Earth Impact:
# Earth Shock Arrival Time = 2024-03-24T17:55Z (+- 7 hours) [PE: 3.8 hr]
# Duration of disturbance (hr) = 28.9 (+- 8 hours)
# Minimum magnetopause standoff distance: Rmin(Re) = 4.9
# Possible Kp index:
# (kp)90=6
# (kp)135=8
# (kp)180=8
# ```
#
# ![](data/20240323_031900_2.0_anim.tim-den.gif)

# %% [markdown]
# # CME (CACTUS)
#
# https://www.sidc.be/cactus/catalog/LASCO/2_5_0/qkl/2024/03/CME0103/CME.html
#
# ```
# # CME |          t0    | dt0| pa | da |  v  |  dv | minv| maxv| halo?
#   0103|2024/03/23 01:36| 04 | 144| 360| 0942| 0553| 0226| 1953|  IV
# ```
#
# ![](data/CME.jpeg)
#
#
# <video controls src="data/CME.mp4"></video>

# %% [markdown]
# # CME (SOHO LASCO CME Catalog)
#
# https://cdaw.gsfc.nasa.gov/movie/make_javamovie.php?stime=20240323_0011&etime=20240323_0358&img1=lasc2rdf&title=20240323.012551.p013g;V=1470km/s

# %% [markdown]
# # 우주환경 데이터
#
# https://kswrc.kasi.re.kr/ko/data/browser/environment
#
# - 2024-03-21
# - 1 week
#
# # GOES X-ray
# ![](data/fm_xray1.png)
# ![](data/fm_xray2.png)
#
# # Goes Proton
# ![](data/fm_particle1.png)
# ![](data/fm_particle2.png)
#
# # Kp
# ![](data/fm_kp1.png)
# ![](data/fm_kp2.png)
#
# # Dst
# ![](data/fm_dst1.png)
# ![](data/fm_dst2.png)
#
# # Solar wind
# ![](data/fm_ace1.png)
# ![](data/fm_ace2.png)

# %% [markdown]
# # Flare
#
# https://hesperia.gsfc.nasa.gov/goes/goes_event_listings/
#
# ```
# 23-Mar-2024 00:58   01:33   02:21   X1.1      13614
# ```

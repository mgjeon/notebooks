# %%
import solarmach

# %%
spacecraft = [
    'Earth',
    'PSP',
    'Solar Orbiter',
    'STEREO-A',
]
smach = solarmach.SolarMACH("2024-03-23T01:00", spacecraft, vsw_list=[400]*len(spacecraft))
smach.plot(plot_sun_body_line=True)

# %%
q_lasco = Fido.search(tr,
                      a.Instrument.lasco,
                      a.Detector.c2 | a.Detector.c3)

# %%
q_lasco
# Out:
# <sunpy.net.fido_factory.UnifiedResponse object>
# Results from 2 Providers:
#
# 20 Results from the VSOClient:
# Source: http://vso.stanford.edu/cgi-bin/search
# Total estimated size: 39.023 Mbyte
#
#        Start Time               End Time        Source ... Extent Type   Size
#                                                        ...              Mibyte
# ----------------------- ----------------------- ------ ... ----------- -------
# 2024-03-23 00:00:05.000 2024-03-23 00:00:30.000   SOHO ...      CORONA 2.01074
# 2024-03-23 00:12:05.000 2024-03-23 00:12:30.000   SOHO ...      CORONA 2.01074
# 2024-03-23 00:24:05.000 2024-03-23 00:24:30.000   SOHO ...      CORONA 2.01074
# 2024-03-23 00:36:05.000 2024-03-23 00:36:30.000   SOHO ...      CORONA 2.01074
# 2024-03-23 00:48:05.000 2024-03-23 00:48:30.000   SOHO ...      CORONA 2.01074
# 2024-03-23 01:25:51.000 2024-03-23 01:26:16.000   SOHO ...      CORONA 2.01074
# ...

# %%
files_lasco = Fido.fetch(q_lasco, path='data/{instrument}')
# Out:
# Files Downloaded:   0%|          | 0/37 [00:00<?, ?file/s]
# 22942565.fts:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# 22942569.fts:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# 22942568.fts:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# 22942567.fts:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# 22942566.fts:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# 22942570.fts:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# 22942571.fts:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# 22942572.fts:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# 22942573.fts:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# 22942574.fts:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# 22942575.fts:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# 22942576.fts:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# 22942577.fts:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# 22942578.fts:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# 22942579.fts:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# ...

# %%
q_aia = Fido.search(tr,
                    a.Instrument.aia,
                    a.Wavelength(304*u.angstrom) | a.Wavelength(171*u.angstrom))

# %% [markdown]
# # Fast ion flows observed by the MMS FPI during a dayside reconnection event on March 24, 2023
#
# - https://github.com/heliophysicsPy/summer-school-24/blob/main/pyspedas-tutorial/Generate_2D_slices_of_MMS_FPI_data.ipynb

# %% [markdown]
# This notebook shows how to create 2D slices of 3D particle data from the MMS Fast Plasma Investigation (FPI) instrument using PySPEDAS
#
# Note: these routines are still being beta tested; please report potential issues to Jim Lewis, jwl@ssl.berkeley.edu

# %% [markdown]
# Use the previously cached MMS data by setting SPEDAS_DATA_DIR

# %%
import os
os.environ["SPEDAS_DATA_DIR"] = "./pyspedas_data"

# %%
import pytplot
from pyspedas.mms.particles.mms_part_slice2d import mms_part_slice2d

# %% [markdown]
# This time was selected to coincide with magnetic field and ion flow reversals observed in MMS summary plot data.

# %%
time = '2023-03-24/07:07:33'

# %% [markdown]
# ## FPI ions with geometric interpolation
#
# The data are rotated such that the x axis is parallel to B field and the bulk velocity defines the x-y plane, and plotted using geometric interpolation (each point on the plot is given the value of the bin it intersects)

# %%
mms_part_slice2d(time=time, instrument='fpi', data_rate='brst', species='i', rotation='bv', erange=[0, 20000])
# Out:
# 28-Dec-24 19:46:31: Downloading mms1_fpi_brst_l2_dis-dist_20230324070453_v3.4.0.cdf to ./pyspedas_data/mms/mms1/fpi/brst/l2/dis-dist/2023/03/24
# 28-Dec-24 19:46:52: The name mms1_dis_pitchangdist_lowen_brst is currently not in pytplot
# 28-Dec-24 19:46:52: The name mms1_dis_pitchangdist_miden_brst is currently not in pytplot
# 28-Dec-24 19:46:52: The name mms1_dis_pitchangdist_highen_brst is currently not in pytplot
# 28-Dec-24 19:46:52: The name mms1_des_compressionloss_brst_moms is currently not in pytplot
# 28-Dec-24 19:46:52: The name mms1_des_compressionloss_brst_moms is currently not in pytplot
# 28-Dec-24 19:46:52: Problem reading the variable: mms1_des_compressionloss_brst_moms
# 28-Dec-24 19:46:52: The name mms1_dis_compressionloss_brst_moms is currently not in pytplot
# 28-Dec-24 19:46:52: The name mms1_dis_compressionloss_brst_moms is currently not in pytplot
# 28-Dec-24 19:46:52: Problem reading the variable: mms1_dis_compressionloss_brst_moms
# 28-Dec-24 19:46:52: The name mms1_des_compressionloss_brst_dist is currently not in pytplot
# 28-Dec-24 19:46:52: The name mms1_des_compressionloss_brst_dist is currently not in pytplot
# 28-Dec-24 19:46:52: Problem reading the variable: mms1_des_compressionloss_brst_dist
# 28-Dec-24 19:46:54: Downloading mms1_fgm_brst_l2_20230324070453_v5.391.0.cdf to ./pyspedas_data/mms/mms1/fgm/brst/l2/2023/03/24
# 28-Dec-24 19:46:57: Downloading mms1_fpi_brst_l2_dis-moms_20230324070453_v3.4.0.cdf to ./pyspedas_data/mms/mms1/fpi/brst/l2/dis-moms/2023/03/24
# 28-Dec-24 19:47:02: The name mms1_dis_pitchangdist_lowen_brst is currently not in pytplot
# 28-Dec-24 19:47:02: The name mms1_dis_pitchangdist_miden_brst is currently not in pytplot
# 28-Dec-24 19:47:02: The name mms1_dis_pitchangdist_highen_brst is currently not in pytplot
# 28-Dec-24 19:47:02: The name mms1_des_compressionloss_brst_moms is currently not in pytplot
# 28-Dec-24 19:47:02: The name mms1_des_compressionloss_brst_moms is currently not in pytplot
# 28-Dec-24 19:47:02: Problem reading the variable: mms1_des_compressionloss_brst_moms
# 28-Dec-24 19:47:02: The name mms1_des_compressionloss_brst_dist is currently not in pytplot
# 28-Dec-24 19:47:02: The name mms1_des_compressionloss_brst_dist is currently not in pytplot
# 28-Dec-24 19:47:02: Problem reading the variable: mms1_des_compressionloss_brst_dist
# 28-Dec-24 19:47:02: Averaging mms1_fgm_b_gse_brst_l2_bvec
# 28-Dec-24 19:47:02: Averaging mms1_dis_bulkv_gse_brst
# 28-Dec-24 19:47:02: Aligning slice plane to: bv
# 28-Dec-24 19:47:03: Finished slice at 2023-03-24 07:07:32.858868

# %% [markdown]
# Return the slice data structure (instead of plotting) by setting the `return_slice` keyword to `True`

# %%
the_slice = mms_part_slice2d(return_slice=True, time=time, instrument='fpi', species='i', rotation='bv', erange=[0, 20000])
# Out:
# 28-Dec-24 19:47:05: Downloading mms1_fpi_fast_l2_dis-dist_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms1/fpi/fast/l2/dis-dist/2023/03
# 28-Dec-24 19:47:37: The name mms1_dis_pitchangdist_lowen_fast is currently not in pytplot
# 28-Dec-24 19:47:37: The name mms1_dis_pitchangdist_miden_fast is currently not in pytplot
# 28-Dec-24 19:47:37: The name mms1_dis_pitchangdist_highen_fast is currently not in pytplot
# 28-Dec-24 19:47:38: Loading ./pyspedas_data/mms/mms1/fgm/srvy/l2/2023/03/mms1_fgm_srvy_l2_20230324_v5.393.0.cdf
# 28-Dec-24 19:47:43: Downloading mms1_fpi_fast_l2_dis-moms_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms1/fpi/fast/l2/dis-moms/2023/03
# 28-Dec-24 19:47:48: The name mms1_dis_pitchangdist_lowen_fast is currently not in pytplot
# 28-Dec-24 19:47:48: The name mms1_dis_pitchangdist_miden_fast is currently not in pytplot
# 28-Dec-24 19:47:48: The name mms1_dis_pitchangdist_highen_fast is currently not in pytplot
# 28-Dec-24 19:47:48: Averaging mms1_fgm_b_gse_srvy_l2_bvec
# 28-Dec-24 19:47:48: Averaging mms1_dis_bulkv_gse_fast
# 28-Dec-24 19:47:48: Aligning slice plane to: bv
# 28-Dec-24 19:47:52: Finished slice at 2023-03-24 07:07:29.408840

# %% [markdown]
# The slice is stored as a dictionary:

# %%
the_slice.keys()
# Out:
# dict_keys(['project_name', 'spacecraft', 'data_name', 'units_name', 'species', 'xyunits', 'rotation', 'energy', 'trange', 'zrange', 'rrange', 'rlog', 'interpolation', 'n_samples', 'data', 'xgrid', 'ygrid'])

# %% [markdown]
# You can also create 1D cuts through the 2D slice:

# %%
from pyspedas.particles.spd_slice2d.slice1d_plot import plot

plot(the_slice, 'x', [-100, 100])  # summed from Vv=[-100, 100]

# %% [markdown]
# ## FPI ions with 2D interpolation
#
# The data are rotated such that the x axis is parallel to B field and the bulk velocity defines the x-y plane, and plotted using 2D interpolation (data points within the specified theta or z-axis range are projected onto the slice plane and linearly interpolated onto a regular 2D grid). The default theta range is [-20, +20]

# %%
mms_part_slice2d(interpolation='2d', time=time, instrument='fpi', data_rate='brst', species='i', rotation='bv', erange=[0, 20000])
# Out:
# 28-Dec-24 19:47:53: Loading ./pyspedas_data/mms/mms1/fpi/brst/l2/dis-dist/2023/03/24/mms1_fpi_brst_l2_dis-dist_20230324070453_v3.4.0.cdf
# 28-Dec-24 19:47:57: The name mms1_dis_pitchangdist_lowen_brst is currently not in pytplot
# 28-Dec-24 19:47:57: The name mms1_dis_pitchangdist_miden_brst is currently not in pytplot
# 28-Dec-24 19:47:57: The name mms1_dis_pitchangdist_highen_brst is currently not in pytplot
# 28-Dec-24 19:47:57: The name mms1_des_compressionloss_brst_moms is currently not in pytplot
# 28-Dec-24 19:47:57: The name mms1_des_compressionloss_brst_moms is currently not in pytplot
# 28-Dec-24 19:47:57: Problem reading the variable: mms1_des_compressionloss_brst_moms
# 28-Dec-24 19:47:57: The name mms1_des_compressionloss_brst_dist is currently not in pytplot
# 28-Dec-24 19:47:57: The name mms1_des_compressionloss_brst_dist is currently not in pytplot
# 28-Dec-24 19:47:57: Problem reading the variable: mms1_des_compressionloss_brst_dist
# 28-Dec-24 19:47:58: Loading ./pyspedas_data/mms/mms1/fgm/brst/l2/2023/03/24/mms1_fgm_brst_l2_20230324070453_v5.391.0.cdf
# 28-Dec-24 19:47:59: Loading ./pyspedas_data/mms/mms1/fpi/brst/l2/dis-moms/2023/03/24/mms1_fpi_brst_l2_dis-moms_20230324070453_v3.4.0.cdf
# 28-Dec-24 19:48:03: The name mms1_dis_pitchangdist_lowen_brst is currently not in pytplot
# 28-Dec-24 19:48:03: The name mms1_dis_pitchangdist_miden_brst is currently not in pytplot
# 28-Dec-24 19:48:03: The name mms1_dis_pitchangdist_highen_brst is currently not in pytplot
# 28-Dec-24 19:48:03: The name mms1_des_compressionloss_brst_moms is currently not in pytplot
# 28-Dec-24 19:48:03: The name mms1_des_compressionloss_brst_moms is currently not in pytplot
# 28-Dec-24 19:48:03: Problem reading the variable: mms1_des_compressionloss_brst_moms
# 28-Dec-24 19:48:03: The name mms1_des_compressionloss_brst_dist is currently not in pytplot
# 28-Dec-24 19:48:03: The name mms1_des_compressionloss_brst_dist is currently not in pytplot
# 28-Dec-24 19:48:03: Problem reading the variable: mms1_des_compressionloss_brst_dist
# 28-Dec-24 19:48:03: Averaging mms1_fgm_b_gse_brst_l2_bvec
# 28-Dec-24 19:48:03: Averaging mms1_dis_bulkv_gse_brst
# 28-Dec-24 19:48:03: Aligning slice plane to: bv
# 28-Dec-24 19:48:04: Finished slice at 2023-03-24 07:07:32.858868

# %% [markdown]
# To see the other options, run help() on mms_part_slice2d:

# %%
help(mms_part_slice2d)
# Out:
# Help on function mms_part_slice2d in module pyspedas.mms.particles.mms_part_slice2d:
#
# mms_part_slice2d(trange=None, time=None, samples=None, window=None, center_time=False, erange=None, thetarange=None, zdirrange=None, average_angle=None, sum_angle=None, energy=False, log=False, probe='1', instrument='fpi', data_rate=None, level='l2', spdf=False, mag_data_rate=None, species=None, rotation='xy', custom_rotation=None, slice_x=None, slice_norm=None, subtract_bulk=False, xrange=None, yrange=None, zrange=None, resolution=None, interpolation='geometric', contours=False, title=None, smooth=None, save_jpeg=None, save_png=None, save_svg=None, save_pdf=None, save_eps=None, plotsize=10, dpi=None, return_slice=False, cmap=None, display=True)
#     This routine creates 2D slices of 3D distribution function data from the FPI and HPCA instruments.
#     This is essentially a wrapper around slice2d and slice2d_plot, that loads the data,
#     any required support data, calculates the slice with slice2d and plots it with slice2d_plot.
#
#     Parameters
#     -----------
#         probe: int or str
#             MMS spacecraft probe # (1, 2, 3 or 4)
#
#         instrument: str
#             MMS plasma instrument (fpi or hpca)
#
#         species: str
#             Particle species; depends on the instrument::
#
#                 FPI: 'e' for electrons, 'i' for ions
#                 HPCA: 'hplus' for H+, 'oplus' for O+, 'heplus' for He+, 'heplusplus', for He++
#
#         data_rate: str
#             FPI/HPCA data rate [fast (fpi), srvy (hpca), or brst (both fpi and hpca)]
#
#         mag_data_rate: str
#             FGM data rate for transformations
#
#         level: str
#             Data level (default: l2); lower levels require an SDC username and password
#
#         spdf: bool
#             Flag to download the data from SPDF instead of the MMS SDC
#
#         trange: list of str or list of float
#             Two-element time range over which data will be averaged (optional; can also use the 'time' keyword)
#
#         time: str or float
#             Time at which the slice will be computed (optional; can also use 'trange' above)
#
#         samples: int
#             Number of nearest samples to TIME to average.
#
#         window: float
#             Length in seconds from TIME over which data will be averaged
#
#         center_time: bool
#             Flag denoting that TIME should be midpoint for window instead of beginning
#
#         interpolation: str
#             Interpolation method; valid options::
#
#                 'geometric': Each point on the plot is given the value of the bin it intersects.
#                             This allows bin boundaries to be drawn at high resolutions.
#                 '2d': Data points within the specified theta or z-axis range are projected onto
#                             the slice plane and linearly interpolated onto a regular 2D grid.
#
#         rotation: str
#             Aligns the data relative to the magnetic field and/or bulk velocity.
#             This is applied after the CUSTOM_ROTATION. (BV and BE are invariant
#             between coordinate systems); valid options::
#
#                 'BV':  The x axis is parallel to B field; the bulk velocity defines the x-y plane
#                 'BE':  The x axis is parallel to B field; the B x V(bulk) vector defines the x-y plane
#                 'xy':  (default) The x axis is along the data's x axis and y is along the data's y axis
#                 'xz':  The x axis is along the data's x axis and y is along the data's z axis
#                 'yz':  The x axis is along the data's y axis and y is along the data's z axis
#                 'xvel':  The x axis is along the data's x axis; the x-y plane is defined by the bulk velocity
#                 'perp':  The x axis is the bulk velocity projected onto the plane normal to the B field; y is B x V(bulk)
#                 'perp_xy':  The data's x & y axes are projected onto the plane normal to the B field
#                 'perp_xz':  The data's x & z axes are projected onto the plane normal to the B field
#                 'perp_yz':  The data's y & z axes are projected onto the plane normal to the B field
#
#         custom_rotation: str or np.ndarray
#             Applies a custom rotation matrix to the data.  Input may be a
#             3x3 rotation matrix or a tplot variable containing matrices.
#             If the time window covers multiple matrices they will be averaged.
#             This is applied before other transformations
#
#         slice_x: str or np.ndarray
#             Specifies the slice plane's x-axis within the coordinates
#             specified by custom_rotation and rotation. If not specified, the given
#             coordinate's x-axis will be used. If slice_x is not perpendicular to the
#             normal, its projection onto the slice plane will be used.
#
#         slice_norm: str or np.ndarray
#             Specifies the slice plane's normal within the coordinates
#             specified by custom_rotation and rotation; if not specified, the given
#             coordinate's z-axis will be used (slice along by x-y plane in those coordinates).
#
#         energy: bool
#             Flag to plot data against energy (in eV) instead of velocity.
#
#         log: bool
#             Flag to apply logarithmic scaling to the radial measure (i.e. energy/velocity).
#             (on by default if ENERGY is True)
#
#         erange: list of float
#             Two element array specifying the energy range to be used in eV
#
#         thetarange: list of float
#             (2D interpolation only) Angle range, in degrees [-90,90], used to calculate slice.
#             Default = [-20,20]; will override ZDIRRANGE.
#
#         zdirrange: list of float
#             (2D interpolation only) Z-Axis range, in km/s, used to calculate slice.
#             Ignored if called with THETARANGE.
#
#         subtract_bulk: bool
#             Subtract the bulk velocity vector
#
#         resolution: int
#             Integer specifying the resolution along each dimension of the
#             slice (defaults:  2D interpolation: 150, geometric: 500)
#
#         smooth: int
#             An odd integer >=3 specifying the width of a smoothing window in #
#             of points.  Smoothing is applied to the final plot using a gaussian
#             convolution. Even entries will be incremented, 0 and 1 are ignored.
#
#         xrange: list of float
#             Keyword to limit the range of the slice's x-axis in the plot
#
#         yrange: list of float
#             Keyword to limit the range of the slice's y-axis in the plot
#
#         zrange: list of float
#             Keyword to limit the range of the slice's color bar
#
#         save_png: str
#             Save the plot as a PNG file
#
#         save_eps: str
#             Save the plot as an EPS file
#
#         save_pdf: str
#             Save the plot as a PDF file
#
#         save_svg: str
#             Save the plot as an SVG file
#
#         display: bool
#             Flag to allow disabling displaying of the figure
#
#         return_slice: bool
#             Flag to return the slice instead of displaying it
#
#     Returns
#     --------
#     None or dict
#         By default, no return value (but creates a figure). If return_slice=True, returns the slice data structure.
#
#     Examples
#     --------
#
#     >>> from pyspedas.projects.mms import mms_part_slice2d
#     >>> time = '2023-03-24/07:07:33'
#     >>> # FPI ions with geometric interpolation
#     >>> mms_part_slice2d(time=time, instrument='fpi', data_rate='brst', species='i', rotation='bv', erange=[0, 20000])
#     >>> # Same as above, but return the slice data structure
#     >>> the_slice = mms_part_slice2d(return_slice=True, time=time, instrument='fpi', species='i', rotation='bv', erange=[0, 20000])
#     >>> # FPI ions with 2D interpolation
#     >>> mms_part_slice2d(interpolation='2d', time=time, instrument='fpi', data_rate='brst', species='i', rotation='bv', erange=[0, 20000])

# %% [markdown]
# We'll look at the same slice, this time with the 'be' rotation specified

# %%
mms_part_slice2d(interpolation='2d', time='2023-03-24 07:07:33', instrument='fpi', species='i',rotation='be', data_rate='brst', erange=[0, 20000])
# Out:
# 28-Dec-24 19:48:05: Loading ./pyspedas_data/mms/mms1/fpi/brst/l2/dis-dist/2023/03/24/mms1_fpi_brst_l2_dis-dist_20230324070453_v3.4.0.cdf
# 28-Dec-24 19:48:08: The name mms1_dis_pitchangdist_lowen_brst is currently not in pytplot
# 28-Dec-24 19:48:08: The name mms1_dis_pitchangdist_miden_brst is currently not in pytplot
# 28-Dec-24 19:48:08: The name mms1_dis_pitchangdist_highen_brst is currently not in pytplot
# 28-Dec-24 19:48:08: The name mms1_des_compressionloss_brst_moms is currently not in pytplot
# 28-Dec-24 19:48:08: The name mms1_des_compressionloss_brst_moms is currently not in pytplot
# 28-Dec-24 19:48:08: Problem reading the variable: mms1_des_compressionloss_brst_moms
# 28-Dec-24 19:48:08: The name mms1_des_compressionloss_brst_dist is currently not in pytplot
# 28-Dec-24 19:48:08: The name mms1_des_compressionloss_brst_dist is currently not in pytplot
# 28-Dec-24 19:48:08: Problem reading the variable: mms1_des_compressionloss_brst_dist
# 28-Dec-24 19:48:10: Loading ./pyspedas_data/mms/mms1/fgm/brst/l2/2023/03/24/mms1_fgm_brst_l2_20230324070453_v5.391.0.cdf
# 28-Dec-24 19:48:11: Loading ./pyspedas_data/mms/mms1/fpi/brst/l2/dis-moms/2023/03/24/mms1_fpi_brst_l2_dis-moms_20230324070453_v3.4.0.cdf
# 28-Dec-24 19:48:15: The name mms1_dis_pitchangdist_lowen_brst is currently not in pytplot
# 28-Dec-24 19:48:15: The name mms1_dis_pitchangdist_miden_brst is currently not in pytplot
# 28-Dec-24 19:48:15: The name mms1_dis_pitchangdist_highen_brst is currently not in pytplot
# 28-Dec-24 19:48:15: The name mms1_des_compressionloss_brst_moms is currently not in pytplot
# 28-Dec-24 19:48:15: The name mms1_des_compressionloss_brst_moms is currently not in pytplot
# 28-Dec-24 19:48:15: Problem reading the variable: mms1_des_compressionloss_brst_moms
# 28-Dec-24 19:48:15: The name mms1_des_compressionloss_brst_dist is currently not in pytplot
# 28-Dec-24 19:48:15: The name mms1_des_compressionloss_brst_dist is currently not in pytplot
# 28-Dec-24 19:48:15: Problem reading the variable: mms1_des_compressionloss_brst_dist
# 28-Dec-24 19:48:15: Averaging mms1_fgm_b_gse_brst_l2_bvec
# 28-Dec-24 19:48:15: Averaging mms1_dis_bulkv_gse_brst
# 28-Dec-24 19:48:15: Aligning slice plane to: be
# 28-Dec-24 19:48:15: Finished slice at 2023-03-24 07:07:32.858868

# %% [markdown]
# The next slice is taken about 22 seconds later. By this time, the bulk velocity has decreased, and the beam structure seems less defined.

# %%
mms_part_slice2d(interpolation='2d', time='2023-03-24 07:07:55', instrument='fpi', species='i',rotation='bv', data_rate='brst', erange=[0, 20000])
# Out:
# 28-Dec-24 19:48:16: Loading ./pyspedas_data/mms/mms1/fpi/brst/l2/dis-dist/2023/03/24/mms1_fpi_brst_l2_dis-dist_20230324070453_v3.4.0.cdf
# 28-Dec-24 19:48:20: The name mms1_dis_pitchangdist_lowen_brst is currently not in pytplot
# 28-Dec-24 19:48:20: The name mms1_dis_pitchangdist_miden_brst is currently not in pytplot
# 28-Dec-24 19:48:20: The name mms1_dis_pitchangdist_highen_brst is currently not in pytplot
# 28-Dec-24 19:48:20: The name mms1_des_compressionloss_brst_moms is currently not in pytplot
# 28-Dec-24 19:48:20: The name mms1_des_compressionloss_brst_moms is currently not in pytplot
# 28-Dec-24 19:48:20: Problem reading the variable: mms1_des_compressionloss_brst_moms
# 28-Dec-24 19:48:20: The name mms1_des_compressionloss_brst_dist is currently not in pytplot
# 28-Dec-24 19:48:20: The name mms1_des_compressionloss_brst_dist is currently not in pytplot
# 28-Dec-24 19:48:20: Problem reading the variable: mms1_des_compressionloss_brst_dist
# 28-Dec-24 19:48:21: Loading ./pyspedas_data/mms/mms1/fgm/brst/l2/2023/03/24/mms1_fgm_brst_l2_20230324070453_v5.391.0.cdf
# 28-Dec-24 19:48:23: Loading ./pyspedas_data/mms/mms1/fpi/brst/l2/dis-moms/2023/03/24/mms1_fpi_brst_l2_dis-moms_20230324070453_v3.4.0.cdf
# 28-Dec-24 19:48:27: The name mms1_dis_pitchangdist_lowen_brst is currently not in pytplot
# 28-Dec-24 19:48:27: The name mms1_dis_pitchangdist_miden_brst is currently not in pytplot
# 28-Dec-24 19:48:27: The name mms1_dis_pitchangdist_highen_brst is currently not in pytplot
# 28-Dec-24 19:48:27: The name mms1_des_compressionloss_brst_moms is currently not in pytplot
# 28-Dec-24 19:48:27: The name mms1_des_compressionloss_brst_moms is currently not in pytplot
# 28-Dec-24 19:48:27: Problem reading the variable: mms1_des_compressionloss_brst_moms
# 28-Dec-24 19:48:27: The name mms1_des_compressionloss_brst_dist is currently not in pytplot
# 28-Dec-24 19:48:27: The name mms1_des_compressionloss_brst_dist is currently not in pytplot
# 28-Dec-24 19:48:27: Problem reading the variable: mms1_des_compressionloss_brst_dist
# 28-Dec-24 19:48:27: Averaging mms1_fgm_b_gse_brst_l2_bvec
# 28-Dec-24 19:48:27: Averaging mms1_dis_bulkv_gse_brst
# 28-Dec-24 19:48:27: Aligning slice plane to: bv
# 28-Dec-24 19:48:27: Finished slice at 2023-03-24 07:07:54.909068

# %% [markdown]
# ## Finding Magnetic Nulls near a reconnection event observed by MMS
#
# - https://github.com/heliophysicsPy/summer-school-24/blob/main/pyspedas-tutorial/Finding_Magnetic_Nulls_MMS_20230324.ipynb

# %% [markdown]
# This notebook will show how to use PySPEDAS to locate and characterize magnetic null points.
#
# During a dayside magneopause crossing on 2023-03-24, MMS observed the signature of a reconnection event: the magnetic field direction reversed (so, nearly antiparallel field lines in close proximity), simultaneous with fast (~400 km/sec) particle flows that also reversed direction during the event.
#
# Magnetic null points are an important aspect of the reconnection process.  Since MMS has four probes taking simultaneous magnetic field measurements in a tight, approximately tetrahedral formation, we have enough information to model the magnetic field in 3 dimensions in the vicinity of the MMS constellation.
#
# The method here is known as the First Order Taylor Expansion (FOTE) method.   By using the MMS field measurements, we can estimate the B field vector at the center of the tetrahedron. We can also estimate the 3x3 Jacobian matrix, capturing the partial derivative of the vector components Bx, By, and Bz with respect to the local X, Y, and Z coordinates.
#
# Together, these two estimates can be used to solve for a location where Bx = By = Bz: that is, a magnetic null point.   As long as the field measurements aren't identical between probes, a null can be found.  Whether that finding is credible or not depends on how well the assumption of linear field gradients holds over the distence to the null, and on some other figures of merit that can be derived from the trace and eigenvalues of the Jacobean matrix.

# %% [markdown]
# We'll start by importing some pyspedas and pytplot tools.

# %%
import os
os.environ["SPEDAS_DATA_DIR"] = "./pyspedas_data"

# %%
# Here are some imports we'll need below.
import pyspedas
import pytplot

# We'll import a few pytplot routines, to simplify things below
from pytplot import timespan, highlight, time_double, options, tplot, tnames

# %% [markdown]
# We need to know the MMS spacecraft locations, so we'll get them with mms_load_state()

# %%
state_vars = pyspedas.mms.mms_load_state(trange=['2023-03-24/07:00','2023-03-24/08:00'],probe=['1','2','3','4'])

# For FGM, we'll use the survey data for the overview plot, and burst data for the
# null analysis.

fgm_vars = pyspedas.mms.fgm(trange=['2023-03-24/07:00','2023-03-24/08:00'],probe=['1','2','3','4'],data_rate='brst',time_clip=True)
fgm_vars = pyspedas.mms.fgm(trange=['2023-03-24/07:00','2023-03-24/08:00'],probe=['1'],data_rate='srvy',time_clip=True)

fpi_vars = pyspedas.mms.mms_load_fpi(trange=['2023-03-24/07:00','2023-03-24/08:00'],probe=['1','2','3','4'],time_clip=True,data_rate='fast')

# Reset time limits from previous examples
timespan('2023-03-24/07:00',60.0,'minutes')

pytplot.tplot_names()
# Out:
# 28-Dec-24 19:55:57: Loading ./pyspedas_data/mms/ancillary/mms1/defeph/MMS1_DEFEPH_2023082_2023083.V01
# 28-Dec-24 19:55:57: Loading ./pyspedas_data/mms/ancillary/mms1/defeph/MMS1_DEFEPH_2023083_2023084.V01
# 28-Dec-24 19:55:58: Loading ./pyspedas_data/mms/ancillary/mms2/defeph/MMS2_DEFEPH_2023082_2023083.V01
# 28-Dec-24 19:55:58: Loading ./pyspedas_data/mms/ancillary/mms2/defeph/MMS2_DEFEPH_2023083_2023084.V01
# 28-Dec-24 19:55:59: Loading ./pyspedas_data/mms/ancillary/mms3/defeph/MMS3_DEFEPH_2023082_2023083.V01
# 28-Dec-24 19:55:59: Loading ./pyspedas_data/mms/ancillary/mms3/defeph/MMS3_DEFEPH_2023083_2023084.V01
# 28-Dec-24 19:56:00: Loading ./pyspedas_data/mms/ancillary/mms4/defeph/MMS4_DEFEPH_2023082_2023083.V01
# 28-Dec-24 19:56:00: Loading ./pyspedas_data/mms/ancillary/mms4/defeph/MMS4_DEFEPH_2023083_2023084.V01
# 28-Dec-24 19:56:01: Downloading mms1_fgm_brst_l2_20230324065643_v5.391.0.cdf to ./pyspedas_data/mms/mms1/fgm/brst/l2/2023/03/24
# 28-Dec-24 19:56:03: Downloading mms1_fgm_brst_l2_20230324070053_v5.391.0.cdf to ./pyspedas_data/mms/mms1/fgm/brst/l2/2023/03/24
# 28-Dec-24 19:56:03: Loading ./pyspedas_data/mms/mms1/fgm/brst/l2/2023/03/24/mms1_fgm_brst_l2_20230324070453_v5.391.0.cdf
# 28-Dec-24 19:56:03: Downloading mms1_fgm_brst_l2_20230324070903_v5.391.0.cdf to ./pyspedas_data/mms/mms1/fgm/brst/l2/2023/03/24
# 28-Dec-24 19:56:12: Downloading mms2_fgm_brst_l2_20230324065643_v5.391.0.cdf to ./pyspedas_data/mms/mms2/fgm/brst/l2/2023/03/24
# 28-Dec-24 19:56:19: Downloading mms2_fgm_brst_l2_20230324070053_v5.391.0.cdf to ./pyspedas_data/mms/mms2/fgm/brst/l2/2023/03/24
# 28-Dec-24 19:56:24: Downloading mms2_fgm_brst_l2_20230324070453_v5.391.0.cdf to ./pyspedas_data/mms/mms2/fgm/brst/l2/2023/03/24
# 28-Dec-24 19:56:27: Downloading mms2_fgm_brst_l2_20230324070903_v5.391.0.cdf to ./pyspedas_data/mms/mms2/fgm/brst/l2/2023/03/24
# 28-Dec-24 19:56:30: Downloading mms3_fgm_brst_l2_20230324065643_v5.391.0.cdf to ./pyspedas_data/mms/mms3/fgm/brst/l2/2023/03/24
# 28-Dec-24 19:56:33: Downloading mms3_fgm_brst_l2_20230324070053_v5.391.0.cdf to ./pyspedas_data/mms/mms3/fgm/brst/l2/2023/03/24
# 28-Dec-24 19:56:36: Downloading mms3_fgm_brst_l2_20230324070453_v5.391.0.cdf to ./pyspedas_data/mms/mms3/fgm/brst/l2/2023/03/24
# 28-Dec-24 19:56:38: Downloading mms3_fgm_brst_l2_20230324070903_v5.391.0.cdf to ./pyspedas_data/mms/mms3/fgm/brst/l2/2023/03/24
# 28-Dec-24 19:56:40: Downloading mms4_fgm_brst_l2_20230324065643_v5.391.0.cdf to ./pyspedas_data/mms/mms4/fgm/brst/l2/2023/03/24
# 28-Dec-24 19:56:42: Downloading mms4_fgm_brst_l2_20230324070053_v5.391.0.cdf to ./pyspedas_data/mms/mms4/fgm/brst/l2/2023/03/24
# 28-Dec-24 19:56:44: Downloading mms4_fgm_brst_l2_20230324070453_v5.391.0.cdf to ./pyspedas_data/mms/mms4/fgm/brst/l2/2023/03/24
# 28-Dec-24 19:56:46: Downloading mms4_fgm_brst_l2_20230324070903_v5.391.0.cdf to ./pyspedas_data/mms/mms4/fgm/brst/l2/2023/03/24
# 28-Dec-24 19:57:00: Loading ./pyspedas_data/mms/mms1/fgm/srvy/l2/2023/03/mms1_fgm_srvy_l2_20230324_v5.393.0.cdf
# 28-Dec-24 19:57:05: Downloading mms1_fpi_fast_l2_des-dist_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms1/fpi/fast/l2/des-dist/2023/03
# 28-Dec-24 19:57:36: Downloading mms1_fpi_fast_l2_dis-dist_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms1/fpi/fast/l2/dis-dist/2023/03
# 28-Dec-24 19:57:54: Downloading mms1_fpi_fast_l2_dis-moms_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms1/fpi/fast/l2/dis-moms/2023/03
# 28-Dec-24 19:57:54: Downloading mms1_fpi_fast_l2_des-moms_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms1/fpi/fast/l2/des-moms/2023/03
# 28-Dec-24 19:57:57: Downloading mms1_fpi_fast_l2_dis-momsaux_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms1/fpi/fast/l2/dis-momsaux/2023/03
# 28-Dec-24 19:57:58: Downloading mms1_fpi_fast_l2_des-momsaux_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms1/fpi/fast/l2/des-momsaux/2023/03
# 28-Dec-24 19:58:00: Downloading mms2_fpi_fast_l2_des-dist_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms2/fpi/fast/l2/des-dist/2023/03
# 28-Dec-24 19:58:20: Downloading mms2_fpi_fast_l2_dis-dist_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms2/fpi/fast/l2/dis-dist/2023/03
# 28-Dec-24 19:58:38: Downloading mms2_fpi_fast_l2_dis-moms_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms2/fpi/fast/l2/dis-moms/2023/03
# 28-Dec-24 19:58:39: Downloading mms2_fpi_fast_l2_des-moms_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms2/fpi/fast/l2/des-moms/2023/03
# 28-Dec-24 19:58:42: Downloading mms2_fpi_fast_l2_dis-momsaux_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms2/fpi/fast/l2/dis-momsaux/2023/03
# 28-Dec-24 19:58:44: Downloading mms2_fpi_fast_l2_des-momsaux_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms2/fpi/fast/l2/des-momsaux/2023/03
# 28-Dec-24 19:58:47: Downloading mms3_fpi_fast_l2_des-dist_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms3/fpi/fast/l2/des-dist/2023/03
# 28-Dec-24 19:59:16: Downloading mms3_fpi_fast_l2_dis-dist_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms3/fpi/fast/l2/dis-dist/2023/03
# 28-Dec-24 20:00:15: Downloading mms3_fpi_fast_l2_dis-moms_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms3/fpi/fast/l2/dis-moms/2023/03
# 28-Dec-24 20:00:18: Downloading mms3_fpi_fast_l2_des-moms_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms3/fpi/fast/l2/des-moms/2023/03
# 28-Dec-24 20:00:22: Downloading mms3_fpi_fast_l2_dis-momsaux_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms3/fpi/fast/l2/dis-momsaux/2023/03
# 28-Dec-24 20:00:30: Downloading mms3_fpi_fast_l2_des-momsaux_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms3/fpi/fast/l2/des-momsaux/2023/03
# 28-Dec-24 20:00:37: Downloading mms4_fpi_fast_l2_des-dist_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms4/fpi/fast/l2/des-dist/2023/03
# 28-Dec-24 20:01:33: Downloading mms4_fpi_fast_l2_dis-dist_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms4/fpi/fast/l2/dis-dist/2023/03
# 28-Dec-24 20:02:12: Downloading mms4_fpi_fast_l2_dis-moms_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms4/fpi/fast/l2/dis-moms/2023/03
# 28-Dec-24 20:02:12: Searching for local files...
# 28-Dec-24 20:02:13: Downloading mms4_fpi_fast_l2_dis-momsaux_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms4/fpi/fast/l2/dis-momsaux/2023/03
# 28-Dec-24 20:02:15: Searching for local files...
# 28-Dec-24 20:03:59: store_data: Data array for variable mms1_des_bulkv_part_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:03:59: store_data: Data array for variable mms1_des_bulkv_part_gse_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:03:59: store_data: Data array for variable mms1_des_prestensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:03:59: store_data: Data array for variable mms1_des_prestensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:03:59: store_data: Data array for variable mms1_des_temptensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:03:59: store_data: Data array for variable mms1_des_temptensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:03:59: store_data: Data array for variable mms1_des_numberflux_int_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:03:59: store_data: Data array for variable mms1_des_prestensor_int_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:03:59: store_data: Data array for variable mms1_dis_bulkv_part_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:03:59: store_data: Data array for variable mms1_dis_bulkv_part_gse_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:03:59: store_data: Data array for variable mms1_dis_prestensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:03:59: store_data: Data array for variable mms1_dis_prestensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:03:59: store_data: Data array for variable mms1_dis_temptensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:03:59: store_data: Data array for variable mms1_dis_temptensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:03:59: store_data: Data array for variable mms1_dis_numberflux_int_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:03:59: store_data: Data array for variable mms1_dis_prestensor_int_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:03:59: store_data: Data array for variable mms2_des_bulkv_part_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:03:59: store_data: Data array for variable mms2_des_bulkv_part_gse_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:03:59: store_data: Data array for variable mms2_des_prestensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:03:59: store_data: Data array for variable mms2_des_prestensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:03:59: store_data: Data array for variable mms2_des_temptensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:03:59: store_data: Data array for variable mms2_des_temptensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:03:59: store_data: Data array for variable mms2_des_numberflux_int_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:03:59: store_data: Data array for variable mms2_des_prestensor_int_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:00: store_data: Data array for variable mms2_dis_bulkv_part_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:00: store_data: Data array for variable mms2_dis_bulkv_part_gse_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:00: store_data: Data array for variable mms2_dis_prestensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:00: store_data: Data array for variable mms2_dis_prestensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:00: store_data: Data array for variable mms2_dis_temptensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:00: store_data: Data array for variable mms2_dis_temptensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:00: store_data: Data array for variable mms2_dis_numberflux_int_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:00: store_data: Data array for variable mms2_dis_prestensor_int_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:00: store_data: Data array for variable mms3_des_bulkv_part_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:00: store_data: Data array for variable mms3_des_bulkv_part_gse_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:00: store_data: Data array for variable mms3_des_prestensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:00: store_data: Data array for variable mms3_des_prestensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:00: store_data: Data array for variable mms3_des_temptensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:00: store_data: Data array for variable mms3_des_temptensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:00: store_data: Data array for variable mms3_des_numberflux_int_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:00: store_data: Data array for variable mms3_des_prestensor_int_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:01: store_data: Data array for variable mms3_dis_bulkv_part_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:01: store_data: Data array for variable mms3_dis_bulkv_part_gse_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:01: store_data: Data array for variable mms3_dis_prestensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:01: store_data: Data array for variable mms3_dis_prestensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:01: store_data: Data array for variable mms3_dis_temptensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:01: store_data: Data array for variable mms3_dis_temptensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:01: store_data: Data array for variable mms3_dis_numberflux_int_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:01: store_data: Data array for variable mms3_dis_prestensor_int_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:01: store_data: Data array for variable mms4_dis_bulkv_part_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:01: store_data: Data array for variable mms4_dis_bulkv_part_gse_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:01: store_data: Data array for variable mms4_dis_prestensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:01: store_data: Data array for variable mms4_dis_prestensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:01: store_data: Data array for variable mms4_dis_temptensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:01: store_data: Data array for variable mms4_dis_temptensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:01: store_data: Data array for variable mms4_dis_numberflux_int_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:01: store_data: Data array for variable mms4_dis_prestensor_int_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms1_des_bulkv_part_dbcs_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms1_des_bulkv_part_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms1_des_bulkv_part_gse_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms1_des_bulkv_part_gse_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms1_des_prestensor_part_dbcs_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms1_des_prestensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms1_des_prestensor_part_gse_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms1_des_prestensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms1_des_temptensor_part_dbcs_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms1_des_temptensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms1_des_temptensor_part_gse_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms1_des_temptensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms1_des_numberflux_int_dbcs_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms1_des_numberflux_int_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms1_des_prestensor_int_dbcs_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms1_des_prestensor_int_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms1_dis_bulkv_part_dbcs_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms1_dis_bulkv_part_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms1_dis_bulkv_part_gse_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms1_dis_bulkv_part_gse_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms1_dis_prestensor_part_dbcs_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms1_dis_prestensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms1_dis_prestensor_part_gse_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms1_dis_prestensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms1_dis_temptensor_part_dbcs_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms1_dis_temptensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms1_dis_temptensor_part_gse_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms1_dis_temptensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms1_dis_numberflux_int_dbcs_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms1_dis_numberflux_int_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms1_dis_prestensor_int_dbcs_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms1_dis_prestensor_int_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms2_des_bulkv_part_dbcs_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms2_des_bulkv_part_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms2_des_bulkv_part_gse_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms2_des_bulkv_part_gse_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms2_des_prestensor_part_dbcs_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms2_des_prestensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms2_des_prestensor_part_gse_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms2_des_prestensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms2_des_temptensor_part_dbcs_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms2_des_temptensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms2_des_temptensor_part_gse_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms2_des_temptensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms2_des_numberflux_int_dbcs_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms2_des_numberflux_int_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms2_des_prestensor_int_dbcs_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms2_des_prestensor_int_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms2_dis_bulkv_part_dbcs_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms2_dis_bulkv_part_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms2_dis_bulkv_part_gse_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms2_dis_bulkv_part_gse_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms2_dis_prestensor_part_dbcs_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms2_dis_prestensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms2_dis_prestensor_part_gse_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms2_dis_prestensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms2_dis_temptensor_part_dbcs_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms2_dis_temptensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms2_dis_temptensor_part_gse_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms2_dis_temptensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms2_dis_numberflux_int_dbcs_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms2_dis_numberflux_int_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:02: At least one Vn tag is missing, cannot create spec_bins from variable mms2_dis_prestensor_int_dbcs_fast.
# 28-Dec-24 20:04:02: store_data: Data array for variable mms2_dis_prestensor_int_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:03: At least one Vn tag is missing, cannot create spec_bins from variable mms3_des_bulkv_part_dbcs_fast.
# 28-Dec-24 20:04:03: store_data: Data array for variable mms3_des_bulkv_part_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:03: At least one Vn tag is missing, cannot create spec_bins from variable mms3_des_bulkv_part_gse_fast.
# 28-Dec-24 20:04:03: store_data: Data array for variable mms3_des_bulkv_part_gse_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:03: At least one Vn tag is missing, cannot create spec_bins from variable mms3_des_prestensor_part_dbcs_fast.
# 28-Dec-24 20:04:03: store_data: Data array for variable mms3_des_prestensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:03: At least one Vn tag is missing, cannot create spec_bins from variable mms3_des_prestensor_part_gse_fast.
# 28-Dec-24 20:04:03: store_data: Data array for variable mms3_des_prestensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:03: At least one Vn tag is missing, cannot create spec_bins from variable mms3_des_temptensor_part_dbcs_fast.
# 28-Dec-24 20:04:03: store_data: Data array for variable mms3_des_temptensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:03: At least one Vn tag is missing, cannot create spec_bins from variable mms3_des_temptensor_part_gse_fast.
# 28-Dec-24 20:04:03: store_data: Data array for variable mms3_des_temptensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:03: At least one Vn tag is missing, cannot create spec_bins from variable mms3_des_numberflux_int_dbcs_fast.
# 28-Dec-24 20:04:03: store_data: Data array for variable mms3_des_numberflux_int_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:03: At least one Vn tag is missing, cannot create spec_bins from variable mms3_des_prestensor_int_dbcs_fast.
# 28-Dec-24 20:04:03: store_data: Data array for variable mms3_des_prestensor_int_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:03: At least one Vn tag is missing, cannot create spec_bins from variable mms3_dis_bulkv_part_dbcs_fast.
# 28-Dec-24 20:04:03: store_data: Data array for variable mms3_dis_bulkv_part_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:03: At least one Vn tag is missing, cannot create spec_bins from variable mms3_dis_bulkv_part_gse_fast.
# 28-Dec-24 20:04:03: store_data: Data array for variable mms3_dis_bulkv_part_gse_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:03: At least one Vn tag is missing, cannot create spec_bins from variable mms3_dis_prestensor_part_dbcs_fast.
# 28-Dec-24 20:04:03: store_data: Data array for variable mms3_dis_prestensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:03: At least one Vn tag is missing, cannot create spec_bins from variable mms3_dis_prestensor_part_gse_fast.
# 28-Dec-24 20:04:03: store_data: Data array for variable mms3_dis_prestensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:03: At least one Vn tag is missing, cannot create spec_bins from variable mms3_dis_temptensor_part_dbcs_fast.
# 28-Dec-24 20:04:03: store_data: Data array for variable mms3_dis_temptensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:03: At least one Vn tag is missing, cannot create spec_bins from variable mms3_dis_temptensor_part_gse_fast.
# 28-Dec-24 20:04:03: store_data: Data array for variable mms3_dis_temptensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:03: At least one Vn tag is missing, cannot create spec_bins from variable mms3_dis_numberflux_int_dbcs_fast.
# 28-Dec-24 20:04:03: store_data: Data array for variable mms3_dis_numberflux_int_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:03: At least one Vn tag is missing, cannot create spec_bins from variable mms3_dis_prestensor_int_dbcs_fast.
# 28-Dec-24 20:04:03: store_data: Data array for variable mms3_dis_prestensor_int_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:03: At least one Vn tag is missing, cannot create spec_bins from variable mms4_dis_bulkv_part_dbcs_fast.
# 28-Dec-24 20:04:03: store_data: Data array for variable mms4_dis_bulkv_part_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:03: At least one Vn tag is missing, cannot create spec_bins from variable mms4_dis_bulkv_part_gse_fast.
# 28-Dec-24 20:04:03: store_data: Data array for variable mms4_dis_bulkv_part_gse_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:03: At least one Vn tag is missing, cannot create spec_bins from variable mms4_dis_prestensor_part_dbcs_fast.
# 28-Dec-24 20:04:03: store_data: Data array for variable mms4_dis_prestensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:03: At least one Vn tag is missing, cannot create spec_bins from variable mms4_dis_prestensor_part_gse_fast.
# 28-Dec-24 20:04:03: store_data: Data array for variable mms4_dis_prestensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:03: At least one Vn tag is missing, cannot create spec_bins from variable mms4_dis_temptensor_part_dbcs_fast.
# 28-Dec-24 20:04:03: store_data: Data array for variable mms4_dis_temptensor_part_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:03: At least one Vn tag is missing, cannot create spec_bins from variable mms4_dis_temptensor_part_gse_fast.
# 28-Dec-24 20:04:03: store_data: Data array for variable mms4_dis_temptensor_part_gse_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:03: At least one Vn tag is missing, cannot create spec_bins from variable mms4_dis_numberflux_int_dbcs_fast.
# 28-Dec-24 20:04:03: store_data: Data array for variable mms4_dis_numberflux_int_dbcs_fast has 3 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:03: At least one Vn tag is missing, cannot create spec_bins from variable mms4_dis_prestensor_int_dbcs_fast.
# 28-Dec-24 20:04:03: store_data: Data array for variable mms4_dis_prestensor_int_dbcs_fast has 4 dimensions, but only 1 v_n keys plus time. Adding empty v_n keys.
# 28-Dec-24 20:04:04: Downloading mms1_fpi_fast_l2_des-moms_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms1/fpi/fast/l2/des-moms/2023/03
# 28-Dec-24 20:04:08: Downloading mms2_fpi_fast_l2_des-moms_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms2/fpi/fast/l2/des-moms/2023/03
# 28-Dec-24 20:04:10: Downloading mms3_fpi_fast_l2_des-moms_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms3/fpi/fast/l2/des-moms/2023/03
# 28-Dec-24 20:04:11: Searching for local files...
# 28-Dec-24 20:04:13: Downloading mms1_fpi_fast_l2_des-dist_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms1/fpi/fast/l2/des-dist/2023/03
# 28-Dec-24 20:04:34: Downloading mms2_fpi_fast_l2_des-dist_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms2/fpi/fast/l2/des-dist/2023/03
# 28-Dec-24 20:05:06: Downloading mms3_fpi_fast_l2_des-dist_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms3/fpi/fast/l2/des-dist/2023/03
# 28-Dec-24 20:05:49: Downloading mms4_fpi_fast_l2_des-dist_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms4/fpi/fast/l2/des-dist/2023/03
# 28-Dec-24 20:06:14: Downloading mms1_fpi_fast_l2_dis-moms_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms1/fpi/fast/l2/dis-moms/2023/03
# 28-Dec-24 20:06:16: Downloading mms2_fpi_fast_l2_dis-moms_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms2/fpi/fast/l2/dis-moms/2023/03
# 28-Dec-24 20:06:16: Downloading mms3_fpi_fast_l2_dis-moms_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms3/fpi/fast/l2/dis-moms/2023/03
# 28-Dec-24 20:06:23: Downloading mms4_fpi_fast_l2_dis-moms_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms4/fpi/fast/l2/dis-moms/2023/03
# 28-Dec-24 20:06:31: Downloading mms1_fpi_fast_l2_dis-dist_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms1/fpi/fast/l2/dis-dist/2023/03
# 28-Dec-24 20:08:14: Downloading mms2_fpi_fast_l2_dis-dist_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms2/fpi/fast/l2/dis-dist/2023/03
# 28-Dec-24 20:08:56: Downloading mms3_fpi_fast_l2_dis-dist_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms3/fpi/fast/l2/dis-dist/2023/03
# 28-Dec-24 20:10:07: Downloading mms4_fpi_fast_l2_dis-dist_20230324060000_v3.4.0.cdf to ./pyspedas_data/mms/mms4/fpi/fast/l2/dis-dist/2023/03
# 28-Dec-24 20:11:40: The name mms1_dis_pitchangdist_lowen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms1_dis_pitchangdist_miden_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms1_dis_pitchangdist_highen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms1_dis_pitchangdist_lowen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms1_dis_pitchangdist_miden_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms1_dis_pitchangdist_highen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms1_dis_pitchangdist_lowen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms1_dis_pitchangdist_miden_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms1_dis_pitchangdist_highen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms2_dis_pitchangdist_lowen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms2_dis_pitchangdist_miden_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms2_dis_pitchangdist_highen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms2_dis_pitchangdist_lowen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms2_dis_pitchangdist_miden_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms2_dis_pitchangdist_highen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms2_dis_pitchangdist_lowen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms2_dis_pitchangdist_miden_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms2_dis_pitchangdist_highen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms3_dis_pitchangdist_lowen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms3_dis_pitchangdist_miden_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms3_dis_pitchangdist_highen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms3_dis_pitchangdist_lowen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms3_dis_pitchangdist_miden_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms3_dis_pitchangdist_highen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms3_dis_pitchangdist_lowen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms3_dis_pitchangdist_miden_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms3_dis_pitchangdist_highen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms4_des_pitchangdist_lowen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms4_des_pitchangdist_miden_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms4_des_pitchangdist_highen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms4_dis_pitchangdist_lowen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms4_dis_pitchangdist_miden_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms4_dis_pitchangdist_highen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms4_dis_pitchangdist_lowen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms4_dis_pitchangdist_miden_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms4_dis_pitchangdist_highen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms4_des_pitchangdist_lowen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms4_des_pitchangdist_miden_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms4_des_pitchangdist_highen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms4_des_errorflags_fast_moms is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms4_des_errorflags_fast_moms is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms4_dis_pitchangdist_lowen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms4_dis_pitchangdist_miden_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms4_dis_pitchangdist_highen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms4_des_pitchangdist_lowen_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms4_des_pitchangdist_miden_fast is currently not in pytplot
# 28-Dec-24 20:11:40: The name mms4_des_pitchangdist_highen_fast is currently not in pytplot
# 0 : mms1_defeph_pos
# 1 : mms1_defeph_vel
# 2 : mms2_defeph_pos
# 3 : mms2_defeph_vel
# 4 : mms3_defeph_pos
# 5 : mms3_defeph_vel
# 6 : mms4_defeph_pos
# 7 : mms4_defeph_vel
# 8 : Epoch
# 9 : mms1_fgm_b_gse_brst_l2
# 10 : mms1_fgm_b_gsm_brst_l2
# 11 : mms1_fgm_b_dmpa_brst_l2
# 12 : mms1_fgm_b_bcs_brst_l2
# 13 : mms1_fgm_flag_brst_l2
# 14 : Epoch_state
# 15 : mms1_fgm_hirange_brst_l2
# 16 : mms1_fgm_bdeltahalf_brst_l2
# 17 : mms1_fgm_stemp_brst_l2
# 18 : mms1_fgm_etemp_brst_l2
# 19 : mms1_fgm_mode_brst_l2
# 20 : mms2_fgm_b_gse_brst_l2
# 21 : mms2_fgm_b_gsm_brst_l2
# 22 : mms2_fgm_b_dmpa_brst_l2
# 23 : mms2_fgm_b_bcs_brst_l2
# 24 : mms2_fgm_flag_brst_l2
# 25 : mms2_fgm_hirange_brst_l2
# 26 : mms2_fgm_bdeltahalf_brst_l2
# 27 : mms2_fgm_stemp_brst_l2
# 28 : mms2_fgm_etemp_brst_l2
# 29 : mms2_fgm_mode_brst_l2
# 30 : mms3_fgm_b_gse_brst_l2
# 31 : mms3_fgm_b_gsm_brst_l2
# 32 : mms3_fgm_b_dmpa_brst_l2
# 33 : mms3_fgm_b_bcs_brst_l2
# 34 : mms3_fgm_flag_brst_l2
# 35 : mms3_fgm_hirange_brst_l2
# 36 : mms3_fgm_bdeltahalf_brst_l2
# 37 : mms3_fgm_stemp_brst_l2
# 38 : mms3_fgm_etemp_brst_l2
# 39 : mms3_fgm_mode_brst_l2
# 40 : mms4_fgm_b_gse_brst_l2
# 41 : mms4_fgm_b_gsm_brst_l2
# 42 : mms4_fgm_b_dmpa_brst_l2
# 43 : mms4_fgm_b_bcs_brst_l2
# 44 : mms4_fgm_flag_brst_l2
# 45 : mms4_fgm_hirange_brst_l2
# 46 : mms4_fgm_bdeltahalf_brst_l2
# 47 : mms4_fgm_stemp_brst_l2
# 48 : mms4_fgm_etemp_brst_l2
# 49 : mms4_fgm_mode_brst_l2
# 50 : mms1_fgm_b_dmpa_brst_l2_bvec
# 51 : mms1_fgm_b_dmpa_brst_l2_btot
# 52 : mms1_fgm_b_gse_brst_l2_bvec
# 53 : mms1_fgm_b_gse_brst_l2_btot
# 54 : mms1_fgm_b_gsm_brst_l2_bvec
# 55 : mms1_fgm_b_gsm_brst_l2_btot
# 56 : mms1_fgm_b_bcs_brst_l2_bvec
# 57 : mms1_fgm_b_bcs_brst_l2_btot
# 58 : mms2_fgm_b_dmpa_brst_l2_bvec
# 59 : mms2_fgm_b_dmpa_brst_l2_btot
# 60 : mms2_fgm_b_gse_brst_l2_bvec
# 61 : mms2_fgm_b_gse_brst_l2_btot
# 62 : mms2_fgm_b_gsm_brst_l2_bvec
# 63 : mms2_fgm_b_gsm_brst_l2_btot
# 64 : mms2_fgm_b_bcs_brst_l2_bvec
# 65 : mms2_fgm_b_bcs_brst_l2_btot
# 66 : mms3_fgm_b_dmpa_brst_l2_bvec
# 67 : mms3_fgm_b_dmpa_brst_l2_btot
# 68 : mms3_fgm_b_gse_brst_l2_bvec
# 69 : mms3_fgm_b_gse_brst_l2_btot
# 70 : mms3_fgm_b_gsm_brst_l2_bvec
# 71 : mms3_fgm_b_gsm_brst_l2_btot
# 72 : mms3_fgm_b_bcs_brst_l2_bvec
# 73 : mms3_fgm_b_bcs_brst_l2_btot
# 74 : mms4_fgm_b_dmpa_brst_l2_bvec
# 75 : mms4_fgm_b_dmpa_brst_l2_btot
# 76 : mms4_fgm_b_gse_brst_l2_bvec
# 77 : mms4_fgm_b_gse_brst_l2_btot
# 78 : mms4_fgm_b_gsm_brst_l2_bvec
# 79 : mms4_fgm_b_gsm_brst_l2_btot
# 80 : mms4_fgm_b_bcs_brst_l2_bvec
# 81 : mms4_fgm_b_bcs_brst_l2_btot
# 82 : mms1_fgm_b_gse_srvy_l2
# 83 : mms1_fgm_b_gsm_srvy_l2
# 84 : mms1_fgm_b_dmpa_srvy_l2
# 85 : mms1_fgm_b_bcs_srvy_l2
# 86 : mms1_fgm_flag_srvy_l2
# 87 : mms1_fgm_hirange_srvy_l2
# 88 : mms1_fgm_bdeltahalf_srvy_l2
# 89 : mms1_fgm_stemp_srvy_l2
# 90 : mms1_fgm_etemp_srvy_l2
# 91 : mms1_fgm_mode_srvy_l2
# 92 : mms1_fgm_b_dmpa_srvy_l2_bvec
# 93 : mms1_fgm_b_dmpa_srvy_l2_btot
# 94 : mms1_fgm_b_gse_srvy_l2_bvec
# 95 : mms1_fgm_b_gse_srvy_l2_btot
# 96 : mms1_fgm_b_gsm_srvy_l2_bvec
# 97 : mms1_fgm_b_gsm_srvy_l2_btot
# 98 : mms1_fgm_b_bcs_srvy_l2_bvec
# 99 : mms1_fgm_b_bcs_srvy_l2_btot
# 100 : Epoch_plus_var
# 101 : Epoch_minus_var
# 102 : mms1_des_startdelphi_count_fast
# 103 : mms1_des_startdelphi_angle_fast
# 104 : mms1_des_dist_fast
# 105 : mms1_des_disterr_fast
# 106 : mms1_des_avgf1counts_fast
# 107 : mms1_des_theta_fast
# 108 : mms1_des_theta_delta_fast
# 109 : mms1_des_energy_fast
# 110 : mms1_des_energy_delta_fast
# 111 : mms1_des_phi_fast
# 112 : mms1_des_phi_delta_fast
# 113 : mms1_des_pitchangdist_lowen_fast
# 114 : mms1_des_pitchangdist_miden_fast
# 115 : mms1_des_pitchangdist_highen_fast
# 116 : mms1_des_energyspectr_px_fast
# 117 : mms1_des_energyspectr_mx_fast
# 118 : mms1_des_energyspectr_py_fast
# 119 : mms1_des_energyspectr_my_fast
# 120 : mms1_des_energyspectr_pz_fast
# 121 : mms1_des_energyspectr_mz_fast
# 122 : mms1_des_energyspectr_par_fast
# 123 : mms1_des_energyspectr_anti_fast
# 124 : mms1_des_energyspectr_perp_fast
# 125 : mms1_des_energyspectr_omni_fast
# 126 : mms1_des_numberdensity_fast
# 127 : mms1_des_numberdensity_err_fast
# 128 : mms1_des_densityextrapolation_low_fast
# 129 : mms1_des_densityextrapolation_high_fast
# 130 : mms1_des_bulkv_dbcs_fast
# 131 : mms1_des_bulkv_spintone_dbcs_fast
# 132 : mms1_des_bulkv_gse_fast
# 133 : mms1_des_bulkv_spintone_gse_fast
# 134 : mms1_des_bulkv_err_fast
# 135 : mms1_des_prestensor_dbcs_fast
# 136 : mms1_des_prestensor_gse_fast
# 137 : mms1_des_prestensor_err_fast
# 138 : mms1_des_temptensor_dbcs_fast
# 139 : mms1_des_temptensor_gse_fast
# 140 : mms1_des_temptensor_err_fast
# 141 : mms1_des_heatq_dbcs_fast
# 142 : mms1_des_heatq_gse_fast
# 143 : mms1_des_heatq_err_fast
# 144 : mms1_des_alpha_fast
# 145 : mms1_des_alpha_delta_fast
# 146 : mms1_des_temppara_fast
# 147 : mms1_des_tempperp_fast
# 148 : mms1_des_numberdensity_part_fast
# 149 : mms1_des_bulkv_part_dbcs_fast
# 150 : mms1_des_bulkv_part_gse_fast
# 151 : mms1_des_prestensor_part_dbcs_fast
# 152 : mms1_des_prestensor_part_gse_fast
# 153 : mms1_des_temptensor_part_dbcs_fast
# 154 : mms1_des_temptensor_part_gse_fast
# 155 : mms1_des_temppara_part_fast
# 156 : mms1_des_tempperp_part_fast
# 157 : mms1_des_part_index_fast
# 158 : mms1_des_bhat_dbcs_fast
# 159 : mms1_des_gse_xform_fast
# 160 : mms1_des_scpot_mean_fast
# 161 : mms1_des_scpot_max_fast
# 162 : mms1_des_fpibentpipe_dsc_fast
# 163 : mms1_des_fpib_gse_srvy_fast
# 164 : mms1_des_fpib_dmpa_srvy_fast
# 165 : mms1_des_pos_gse_fast
# 166 : mms1_des_pos_gsm_fast
# 167 : mms1_des_numberdensity_int_fast
# 168 : mms1_des_numberflux_int_dbcs_fast
# 169 : mms1_des_prestensor_int_dbcs_fast
# 170 : mms1_des_ugrid_int_fast
# 171 : mms1_dis_startdelphi_count_fast
# 172 : mms1_dis_startdelphi_angle_fast
# 173 : mms1_dis_dist_fast
# 174 : mms1_dis_disterr_fast
# 175 : mms1_dis_avgf1counts_fast
# 176 : mms1_dis_theta_fast
# 177 : mms1_dis_theta_delta_fast
# 178 : mms1_dis_energy_fast
# 179 : mms1_dis_energy_delta_fast
# 180 : mms1_dis_phi_fast
# 181 : mms1_dis_phi_delta_fast
# 182 : mms1_dis_energyspectr_px_fast
# 183 : mms1_dis_energyspectr_mx_fast
# 184 : mms1_dis_energyspectr_py_fast
# 185 : mms1_dis_energyspectr_my_fast
# 186 : mms1_dis_energyspectr_pz_fast
# 187 : mms1_dis_energyspectr_mz_fast
# 188 : mms1_dis_energyspectr_omni_fast
# 189 : mms1_dis_spectr_bg_fast
# 190 : mms1_dis_numberdensity_bg_fast
# 191 : mms1_dis_numberdensity_fast
# 192 : mms1_dis_numberdensity_err_fast
# 193 : mms1_dis_densityextrapolation_low_fast
# 194 : mms1_dis_densityextrapolation_high_fast
# 195 : mms1_dis_bulkv_dbcs_fast
# 196 : mms1_dis_bulkv_spintone_dbcs_fast
# 197 : mms1_dis_bulkv_gse_fast
# 198 : mms1_dis_bulkv_spintone_gse_fast
# 199 : mms1_dis_bulkv_err_fast
# 200 : mms1_dis_prestensor_dbcs_fast
# 201 : mms1_dis_prestensor_gse_fast
# 202 : mms1_dis_prestensor_err_fast
# 203 : mms1_dis_pres_bg_fast
# 204 : mms1_dis_temptensor_dbcs_fast
# 205 : mms1_dis_temptensor_gse_fast
# 206 : mms1_dis_temptensor_err_fast
# 207 : mms1_dis_heatq_dbcs_fast
# 208 : mms1_dis_heatq_gse_fast
# 209 : mms1_dis_heatq_err_fast
# 210 : mms1_dis_temppara_fast
# 211 : mms1_dis_tempperp_fast
# 212 : mms1_dis_numberdensity_part_fast
# 213 : mms1_dis_bulkv_part_dbcs_fast
# 214 : mms1_dis_bulkv_part_gse_fast
# 215 : mms1_dis_prestensor_part_dbcs_fast
# 216 : mms1_dis_prestensor_part_gse_fast
# 217 : mms1_dis_temptensor_part_dbcs_fast
# 218 : mms1_dis_temptensor_part_gse_fast
# 219 : mms1_dis_temppara_part_fast
# 220 : mms1_dis_tempperp_part_fast
# 221 : mms1_dis_part_index_fast
# 222 : mms1_dis_bhat_dbcs_fast
# 223 : mms1_dis_gse_xform_fast
# 224 : mms1_dis_scpot_mean_fast
# 225 : mms1_dis_scpot_max_fast
# 226 : mms1_dis_fpibentpipe_dsc_fast
# 227 : mms1_dis_fpib_gse_srvy_fast
# 228 : mms1_dis_fpib_dmpa_srvy_fast
# 229 : mms1_dis_pos_gse_fast
# 230 : mms1_dis_pos_gsm_fast
# 231 : mms1_dis_numberdensity_int_fast
# 232 : mms1_dis_numberflux_int_dbcs_fast
# 233 : mms1_dis_prestensor_int_dbcs_fast
# 234 : mms1_dis_ugrid_int_fast
# 235 : mms2_des_startdelphi_count_fast
# 236 : mms2_des_startdelphi_angle_fast
# 237 : mms2_des_dist_fast
# 238 : mms2_des_disterr_fast
# 239 : mms2_des_avgf1counts_fast
# 240 : mms2_des_theta_fast
# 241 : mms2_des_theta_delta_fast
# 242 : mms2_des_energy_fast
# 243 : mms2_des_energy_delta_fast
# 244 : mms2_des_phi_fast
# 245 : mms2_des_phi_delta_fast
# 246 : mms2_des_pitchangdist_lowen_fast
# 247 : mms2_des_pitchangdist_miden_fast
# 248 : mms2_des_pitchangdist_highen_fast
# 249 : mms2_des_energyspectr_px_fast
# 250 : mms2_des_energyspectr_mx_fast
# 251 : mms2_des_energyspectr_py_fast
# 252 : mms2_des_energyspectr_my_fast
# 253 : mms2_des_energyspectr_pz_fast
# 254 : mms2_des_energyspectr_mz_fast
# 255 : mms2_des_energyspectr_par_fast
# 256 : mms2_des_energyspectr_anti_fast
# 257 : mms2_des_energyspectr_perp_fast
# 258 : mms2_des_energyspectr_omni_fast
# 259 : mms2_des_numberdensity_fast
# 260 : mms2_des_numberdensity_err_fast
# 261 : mms2_des_densityextrapolation_low_fast
# 262 : mms2_des_densityextrapolation_high_fast
# 263 : mms2_des_bulkv_dbcs_fast
# 264 : mms2_des_bulkv_spintone_dbcs_fast
# 265 : mms2_des_bulkv_gse_fast
# 266 : mms2_des_bulkv_spintone_gse_fast
# 267 : mms2_des_bulkv_err_fast
# 268 : mms2_des_prestensor_dbcs_fast
# 269 : mms2_des_prestensor_gse_fast
# 270 : mms2_des_prestensor_err_fast
# 271 : mms2_des_temptensor_dbcs_fast
# 272 : mms2_des_temptensor_gse_fast
# 273 : mms2_des_temptensor_err_fast
# 274 : mms2_des_heatq_dbcs_fast
# 275 : mms2_des_heatq_gse_fast
# 276 : mms2_des_heatq_err_fast
# 277 : mms2_des_alpha_fast
# 278 : mms2_des_alpha_delta_fast
# 279 : mms2_des_temppara_fast
# 280 : mms2_des_tempperp_fast
# 281 : mms2_des_numberdensity_part_fast
# 282 : mms2_des_bulkv_part_dbcs_fast
# 283 : mms2_des_bulkv_part_gse_fast
# 284 : mms2_des_prestensor_part_dbcs_fast
# 285 : mms2_des_prestensor_part_gse_fast
# 286 : mms2_des_temptensor_part_dbcs_fast
# 287 : mms2_des_temptensor_part_gse_fast
# 288 : mms2_des_temppara_part_fast
# 289 : mms2_des_tempperp_part_fast
# 290 : mms2_des_part_index_fast
# 291 : mms2_des_bhat_dbcs_fast
# 292 : mms2_des_gse_xform_fast
# 293 : mms2_des_scpot_mean_fast
# 294 : mms2_des_scpot_max_fast
# 295 : mms2_des_fpibentpipe_dsc_fast
# 296 : mms2_des_fpib_gse_srvy_fast
# 297 : mms2_des_fpib_dmpa_srvy_fast
# 298 : mms2_des_pos_gse_fast
# 299 : mms2_des_pos_gsm_fast
# 300 : mms2_des_numberdensity_int_fast
# 301 : mms2_des_numberflux_int_dbcs_fast
# 302 : mms2_des_prestensor_int_dbcs_fast
# 303 : mms2_des_ugrid_int_fast
# 304 : mms2_dis_startdelphi_count_fast
# 305 : mms2_dis_startdelphi_angle_fast
# 306 : mms2_dis_dist_fast
# 307 : mms2_dis_disterr_fast
# 308 : mms2_dis_avgf1counts_fast
# 309 : mms2_dis_theta_fast
# 310 : mms2_dis_theta_delta_fast
# 311 : mms2_dis_energy_fast
# 312 : mms2_dis_energy_delta_fast
# 313 : mms2_dis_phi_fast
# 314 : mms2_dis_phi_delta_fast
# 315 : mms2_dis_energyspectr_px_fast
# 316 : mms2_dis_energyspectr_mx_fast
# 317 : mms2_dis_energyspectr_py_fast
# 318 : mms2_dis_energyspectr_my_fast
# ...
#  'mms1_des_prestensor_int_dbcs_fast',
#  'mms1_des_ugrid_int_fast',
#  'mms1_dis_startdelphi_count_fast',
#  'mms1_dis_startdelphi_angle_fast',
#  'mms1_dis_dist_fast',
#  'mms1_dis_disterr_fast',
#  'mms1_dis_avgf1counts_fast',
#  'mms1_dis_theta_fast',
#  'mms1_dis_theta_delta_fast',
#  'mms1_dis_energy_fast',
#  'mms1_dis_energy_delta_fast',
#  'mms1_dis_phi_fast',
#  'mms1_dis_phi_delta_fast',
#  'mms1_dis_energyspectr_px_fast',
#  'mms1_dis_energyspectr_mx_fast',
#  'mms1_dis_energyspectr_py_fast',
#  'mms1_dis_energyspectr_my_fast',
#  'mms1_dis_energyspectr_pz_fast',
#  'mms1_dis_energyspectr_mz_fast',
#  'mms1_dis_energyspectr_omni_fast',
#  'mms1_dis_spectr_bg_fast',
#  'mms1_dis_numberdensity_bg_fast',
#  'mms1_dis_numberdensity_fast',
#  'mms1_dis_numberdensity_err_fast',
#  'mms1_dis_densityextrapolation_low_fast',
#  'mms1_dis_densityextrapolation_high_fast',
#  'mms1_dis_bulkv_dbcs_fast',
#  'mms1_dis_bulkv_spintone_dbcs_fast',
#  'mms1_dis_bulkv_gse_fast',
#  'mms1_dis_bulkv_spintone_gse_fast',
#  'mms1_dis_bulkv_err_fast',
#  'mms1_dis_prestensor_dbcs_fast',
#  'mms1_dis_prestensor_gse_fast',
#  'mms1_dis_prestensor_err_fast',
#  'mms1_dis_pres_bg_fast',
#  'mms1_dis_temptensor_dbcs_fast',
#  'mms1_dis_temptensor_gse_fast',
#  'mms1_dis_temptensor_err_fast',
#  'mms1_dis_heatq_dbcs_fast',
#  'mms1_dis_heatq_gse_fast',
#  'mms1_dis_heatq_err_fast',
#  'mms1_dis_temppara_fast',
#  'mms1_dis_tempperp_fast',
#  'mms1_dis_numberdensity_part_fast',
#  'mms1_dis_bulkv_part_dbcs_fast',
#  'mms1_dis_bulkv_part_gse_fast',
#  'mms1_dis_prestensor_part_dbcs_fast',
#  'mms1_dis_prestensor_part_gse_fast',
#  'mms1_dis_temptensor_part_dbcs_fast',
#  'mms1_dis_temptensor_part_gse_fast',
#  'mms1_dis_temppara_part_fast',
#  'mms1_dis_tempperp_part_fast',
#  'mms1_dis_part_index_fast',
#  'mms1_dis_bhat_dbcs_fast',
#  'mms1_dis_gse_xform_fast',
#  'mms1_dis_scpot_mean_fast',
#  'mms1_dis_scpot_max_fast',
#  'mms1_dis_fpibentpipe_dsc_fast',
#  'mms1_dis_fpib_gse_srvy_fast',
#  'mms1_dis_fpib_dmpa_srvy_fast',
#  'mms1_dis_pos_gse_fast',
#  'mms1_dis_pos_gsm_fast',
#  'mms1_dis_numberdensity_int_fast',
#  'mms1_dis_numberflux_int_dbcs_fast',
#  'mms1_dis_prestensor_int_dbcs_fast',
#  'mms1_dis_ugrid_int_fast',
#  'mms2_des_startdelphi_count_fast',
#  'mms2_des_startdelphi_angle_fast',
#  'mms2_des_dist_fast',
#  'mms2_des_disterr_fast',
#  'mms2_des_avgf1counts_fast',
#  'mms2_des_theta_fast',
#  'mms2_des_theta_delta_fast',
#  'mms2_des_energy_fast',
#  'mms2_des_energy_delta_fast',
#  'mms2_des_phi_fast',
#  'mms2_des_phi_delta_fast',
#  'mms2_des_pitchangdist_lowen_fast',
#  'mms2_des_pitchangdist_miden_fast',
#  'mms2_des_pitchangdist_highen_fast',
#  'mms2_des_energyspectr_px_fast',
#  'mms2_des_energyspectr_mx_fast',
#  'mms2_des_energyspectr_py_fast',
#  'mms2_des_energyspectr_my_fast',
#  'mms2_des_energyspectr_pz_fast',
#  'mms2_des_energyspectr_mz_fast',
#  'mms2_des_energyspectr_par_fast',
#  'mms2_des_energyspectr_anti_fast',
#  'mms2_des_energyspectr_perp_fast',
#  'mms2_des_energyspectr_omni_fast',
#  'mms2_des_numberdensity_fast',
#  'mms2_des_numberdensity_err_fast',
#  'mms2_des_densityextrapolation_low_fast',
#  'mms2_des_densityextrapolation_high_fast',
#  'mms2_des_bulkv_dbcs_fast',
#  'mms2_des_bulkv_spintone_dbcs_fast',
#  'mms2_des_bulkv_gse_fast',
#  'mms2_des_bulkv_spintone_gse_fast',
#  'mms2_des_bulkv_err_fast',
#  'mms2_des_prestensor_dbcs_fast',
#  'mms2_des_prestensor_gse_fast',
#  'mms2_des_prestensor_err_fast',
#  'mms2_des_temptensor_dbcs_fast',
#  'mms2_des_temptensor_gse_fast',
#  'mms2_des_temptensor_err_fast',
#  'mms2_des_heatq_dbcs_fast',
#  'mms2_des_heatq_gse_fast',
#  'mms2_des_heatq_err_fast',
#  'mms2_des_alpha_fast',
#  'mms2_des_alpha_delta_fast',
#  'mms2_des_temppara_fast',
#  'mms2_des_tempperp_fast',
#  'mms2_des_numberdensity_part_fast',
#  'mms2_des_bulkv_part_dbcs_fast',
#  'mms2_des_bulkv_part_gse_fast',
#  'mms2_des_prestensor_part_dbcs_fast',
#  'mms2_des_prestensor_part_gse_fast',
#  'mms2_des_temptensor_part_dbcs_fast',
#  'mms2_des_temptensor_part_gse_fast',
#  'mms2_des_temppara_part_fast',
#  'mms2_des_tempperp_part_fast',
#  'mms2_des_part_index_fast',
#  'mms2_des_bhat_dbcs_fast',
#  'mms2_des_gse_xform_fast',
#  'mms2_des_scpot_mean_fast',
#  'mms2_des_scpot_max_fast',
#  'mms2_des_fpibentpipe_dsc_fast',
#  'mms2_des_fpib_gse_srvy_fast',
#  'mms2_des_fpib_dmpa_srvy_fast',
#  'mms2_des_pos_gse_fast',
#  'mms2_des_pos_gsm_fast',
#  'mms2_des_numberdensity_int_fast',
#  'mms2_des_numberflux_int_dbcs_fast',
#  'mms2_des_prestensor_int_dbcs_fast',
#  'mms2_des_ugrid_int_fast',
#  'mms2_dis_startdelphi_count_fast',
#  'mms2_dis_startdelphi_angle_fast',
#  'mms2_dis_dist_fast',
#  'mms2_dis_disterr_fast',
#  'mms2_dis_avgf1counts_fast',
#  'mms2_dis_theta_fast',
#  'mms2_dis_theta_delta_fast',
#  'mms2_dis_energy_fast',
#  'mms2_dis_energy_delta_fast',
#  'mms2_dis_phi_fast',
#  'mms2_dis_phi_delta_fast',
#  'mms2_dis_energyspectr_px_fast',
#  'mms2_dis_energyspectr_mx_fast',
#  'mms2_dis_energyspectr_py_fast',
#  'mms2_dis_energyspectr_my_fast',
#  'mms2_dis_energyspectr_pz_fast',
#  'mms2_dis_energyspectr_mz_fast',
#  'mms2_dis_energyspectr_omni_fast',
#  'mms2_dis_spectr_bg_fast',
#  'mms2_dis_numberdensity_bg_fast',
#  'mms2_dis_numberdensity_fast',
#  'mms2_dis_numberdensity_err_fast',
#  'mms2_dis_densityextrapolation_low_fast',
#  'mms2_dis_densityextrapolation_high_fast',
#  'mms2_dis_bulkv_dbcs_fast',
#  'mms2_dis_bulkv_spintone_dbcs_fast',
#  'mms2_dis_bulkv_gse_fast',
#  'mms2_dis_bulkv_spintone_gse_fast',
#  'mms2_dis_bulkv_err_fast',
#  'mms2_dis_prestensor_dbcs_fast',
#  'mms2_dis_prestensor_gse_fast',
#  'mms2_dis_prestensor_err_fast',
#  'mms2_dis_pres_bg_fast',
#  'mms2_dis_temptensor_dbcs_fast',
#  'mms2_dis_temptensor_gse_fast',
#  'mms2_dis_temptensor_err_fast',
#  'mms2_dis_heatq_dbcs_fast',
#  'mms2_dis_heatq_gse_fast',
#  'mms2_dis_heatq_err_fast',
#  'mms2_dis_temppara_fast',
#  'mms2_dis_tempperp_fast',
#  'mms2_dis_numberdensity_part_fast',
#  'mms2_dis_bulkv_part_dbcs_fast',
#  'mms2_dis_bulkv_part_gse_fast',
#  'mms2_dis_prestensor_part_dbcs_fast',
#  'mms2_dis_prestensor_part_gse_fast',
#  'mms2_dis_temptensor_part_dbcs_fast',
#  'mms2_dis_temptensor_part_gse_fast',
#  'mms2_dis_temppara_part_fast',
#  'mms2_dis_tempperp_part_fast',
#  'mms2_dis_part_index_fast',
#  'mms2_dis_bhat_dbcs_fast',
#  'mms2_dis_gse_xform_fast',
#  'mms2_dis_scpot_mean_fast',
#  'mms2_dis_scpot_max_fast',
#  'mms2_dis_fpibentpipe_dsc_fast',
#  'mms2_dis_fpib_gse_srvy_fast',
#  'mms2_dis_fpib_dmpa_srvy_fast',
#  'mms2_dis_pos_gse_fast',
#  'mms2_dis_pos_gsm_fast',
#  'mms2_dis_numberdensity_int_fast',
#  'mms2_dis_numberflux_int_dbcs_fast',
#  'mms2_dis_prestensor_int_dbcs_fast',
#  'mms2_dis_ugrid_int_fast',
#  'mms3_des_startdelphi_count_fast',
#  'mms3_des_startdelphi_angle_fast',
#  'mms3_des_dist_fast',
#  'mms3_des_disterr_fast',
#  'mms3_des_avgf1counts_fast',
#  'mms3_des_theta_fast',
#  'mms3_des_theta_delta_fast',
#  'mms3_des_energy_fast',
#  'mms3_des_energy_delta_fast',
#  'mms3_des_phi_fast',
#  'mms3_des_phi_delta_fast',
#  'mms3_des_pitchangdist_lowen_fast',
#  'mms3_des_pitchangdist_miden_fast',
#  'mms3_des_pitchangdist_highen_fast',
#  'mms3_des_energyspectr_px_fast',
#  'mms3_des_energyspectr_mx_fast',
#  'mms3_des_energyspectr_py_fast',
#  'mms3_des_energyspectr_my_fast',
#  'mms3_des_energyspectr_pz_fast',
#  'mms3_des_energyspectr_mz_fast',
#  'mms3_des_energyspectr_par_fast',
#  'mms3_des_energyspectr_anti_fast',
#  'mms3_des_energyspectr_perp_fast',
#  'mms3_des_energyspectr_omni_fast',
#  'mms3_des_numberdensity_fast',
#  'mms3_des_numberdensity_err_fast',
#  'mms3_des_densityextrapolation_low_fast',
#  'mms3_des_densityextrapolation_high_fast',
#  'mms3_des_bulkv_dbcs_fast',
#  'mms3_des_bulkv_spintone_dbcs_fast',
#  'mms3_des_bulkv_gse_fast',
#  'mms3_des_bulkv_spintone_gse_fast',
#  'mms3_des_bulkv_err_fast',
#  'mms3_des_prestensor_dbcs_fast',
#  'mms3_des_prestensor_gse_fast',
#  'mms3_des_prestensor_err_fast',
#  'mms3_des_temptensor_dbcs_fast',
#  'mms3_des_temptensor_gse_fast',
#  'mms3_des_temptensor_err_fast',
#  'mms3_des_heatq_dbcs_fast',
#  'mms3_des_heatq_gse_fast',
#  'mms3_des_heatq_err_fast',
#  'mms3_des_alpha_fast',
#  'mms3_des_alpha_delta_fast',
#  'mms3_des_temppara_fast',
#  'mms3_des_tempperp_fast',
#  'mms3_des_numberdensity_part_fast',
#  'mms3_des_bulkv_part_dbcs_fast',
#  'mms3_des_bulkv_part_gse_fast',
#  'mms3_des_prestensor_part_dbcs_fast',
#  'mms3_des_prestensor_part_gse_fast',
#  'mms3_des_temptensor_part_dbcs_fast',
#  'mms3_des_temptensor_part_gse_fast',
#  'mms3_des_temppara_part_fast',
#  'mms3_des_tempperp_part_fast',
#  'mms3_des_part_index_fast',
#  'mms3_des_bhat_dbcs_fast',
#  'mms3_des_gse_xform_fast',
#  'mms3_des_scpot_mean_fast',
#  'mms3_des_scpot_max_fast',
#  'mms3_des_fpibentpipe_dsc_fast',
#  'mms3_des_fpib_gse_srvy_fast',
#  'mms3_des_fpib_dmpa_srvy_fast',
#  'mms3_des_pos_gse_fast',
#  'mms3_des_pos_gsm_fast',
#  'mms3_des_numberdensity_int_fast',
#  'mms3_des_numberflux_int_dbcs_fast',
#  'mms3_des_prestensor_int_dbcs_fast',
#  'mms3_des_ugrid_int_fast',
#  'mms3_dis_startdelphi_count_fast',
#  'mms3_dis_startdelphi_angle_fast',
#  'mms3_dis_dist_fast',
#  'mms3_dis_disterr_fast',
#  'mms3_dis_avgf1counts_fast',
#  'mms3_dis_theta_fast',
#  'mms3_dis_theta_delta_fast',
#  'mms3_dis_energy_fast',
#  'mms3_dis_energy_delta_fast',
#  'mms3_dis_phi_fast',
#  'mms3_dis_phi_delta_fast',
#  'mms3_dis_energyspectr_px_fast',
#  'mms3_dis_energyspectr_mx_fast',
#  'mms3_dis_energyspectr_py_fast',
#  'mms3_dis_energyspectr_my_fast',
#  'mms3_dis_energyspectr_pz_fast',
#  'mms3_dis_energyspectr_mz_fast',
#  'mms3_dis_energyspectr_omni_fast',
#  'mms3_dis_spectr_bg_fast',
#  'mms3_dis_numberdensity_bg_fast',
#  'mms3_dis_numberdensity_fast',
#  'mms3_dis_numberdensity_err_fast',
#  'mms3_dis_densityextrapolation_low_fast',
#  'mms3_dis_densityextrapolation_high_fast',
#  'mms3_dis_bulkv_dbcs_fast',
#  'mms3_dis_bulkv_spintone_dbcs_fast',
#  'mms3_dis_bulkv_gse_fast',
#  'mms3_dis_bulkv_spintone_gse_fast',
#  'mms3_dis_bulkv_err_fast',
#  'mms3_dis_prestensor_dbcs_fast',
#  'mms3_dis_prestensor_gse_fast',
#  'mms3_dis_prestensor_err_fast',
#  'mms3_dis_pres_bg_fast',
#  'mms3_dis_temptensor_dbcs_fast',
#  'mms3_dis_temptensor_gse_fast',
#  'mms3_dis_temptensor_err_fast',
#  'mms3_dis_heatq_dbcs_fast',
#  'mms3_dis_heatq_gse_fast',
#  'mms3_dis_heatq_err_fast',
#  'mms3_dis_temppara_fast',
#  'mms3_dis_tempperp_fast',
#  'mms3_dis_numberdensity_part_fast',
#  'mms3_dis_bulkv_part_dbcs_fast',
#  'mms3_dis_bulkv_part_gse_fast',
#  'mms3_dis_prestensor_part_dbcs_fast',
#  'mms3_dis_prestensor_part_gse_fast',
#  'mms3_dis_temptensor_part_dbcs_fast',
#  'mms3_dis_temptensor_part_gse_fast',
#  'mms3_dis_temppara_part_fast',
#  'mms3_dis_tempperp_part_fast',
#  'mms3_dis_part_index_fast',
#  'mms3_dis_bhat_dbcs_fast',
#  'mms3_dis_gse_xform_fast',
#  'mms3_dis_scpot_mean_fast',
#  'mms3_dis_scpot_max_fast',
#  'mms3_dis_fpibentpipe_dsc_fast',
#  'mms3_dis_fpib_gse_srvy_fast',
#  'mms3_dis_fpib_dmpa_srvy_fast',
#  'mms3_dis_pos_gse_fast',
#  'mms3_dis_pos_gsm_fast',
#  'mms3_dis_numberdensity_int_fast',
#  'mms3_dis_numberflux_int_dbcs_fast',
#  'mms3_dis_prestensor_int_dbcs_fast',
#  'mms3_dis_ugrid_int_fast',
#  'mms4_des_startdelphi_count_fast',
#  'mms4_des_startdelphi_angle_fast',
#  'mms4_des_dist_fast',
#  'mms4_des_disterr_fast',
#  'mms4_des_avgf1counts_fast',
#  'mms4_des_theta_fast',
#  'mms4_des_theta_delta_fast',
#  'mms4_des_energy_fast',
#  'mms4_des_energy_delta_fast',
#  'mms4_des_phi_fast',
#  'mms4_des_phi_delta_fast',
#  'mms4_dis_startdelphi_count_fast',
#  'mms4_dis_startdelphi_angle_fast',
#  'mms4_dis_dist_fast',
#  'mms4_dis_disterr_fast',
#  'mms4_dis_avgf1counts_fast',
#  'mms4_dis_theta_fast',
#  'mms4_dis_theta_delta_fast',
#  'mms4_dis_energy_fast',
#  'mms4_dis_energy_delta_fast',
#  'mms4_dis_phi_fast',
#  'mms4_dis_phi_delta_fast',
#  'mms4_dis_energyspectr_px_fast',
#  'mms4_dis_energyspectr_mx_fast',
#  'mms4_dis_energyspectr_py_fast',
#  'mms4_dis_energyspectr_my_fast',
#  'mms4_dis_energyspectr_pz_fast',
#  'mms4_dis_energyspectr_mz_fast',
#  'mms4_dis_energyspectr_omni_fast',
#  'mms4_dis_spectr_bg_fast',
#  'mms4_dis_numberdensity_bg_fast',
#  'mms4_dis_numberdensity_fast',
#  'mms4_dis_numberdensity_err_fast',
#  'mms4_dis_densityextrapolation_low_fast',
#  'mms4_dis_densityextrapolation_high_fast',
#  'mms4_dis_bulkv_dbcs_fast',
#  'mms4_dis_bulkv_spintone_dbcs_fast',
#  'mms4_dis_bulkv_gse_fast',
#  'mms4_dis_bulkv_spintone_gse_fast',
#  'mms4_dis_bulkv_err_fast',
#  'mms4_dis_prestensor_dbcs_fast',
#  'mms4_dis_prestensor_gse_fast',
#  'mms4_dis_prestensor_err_fast',
#  'mms4_dis_pres_bg_fast',
#  'mms4_dis_temptensor_dbcs_fast',
#  'mms4_dis_temptensor_gse_fast',
#  'mms4_dis_temptensor_err_fast',
#  'mms4_dis_heatq_dbcs_fast',
#  'mms4_dis_heatq_gse_fast',
#  'mms4_dis_heatq_err_fast',
#  'mms4_dis_temppara_fast',
#  'mms4_dis_tempperp_fast',
#  'mms4_dis_numberdensity_part_fast',
#  'mms4_dis_bulkv_part_dbcs_fast',
#  'mms4_dis_bulkv_part_gse_fast',
#  'mms4_dis_prestensor_part_dbcs_fast',
#  'mms4_dis_prestensor_part_gse_fast',
#  'mms4_dis_temptensor_part_dbcs_fast',
#  'mms4_dis_temptensor_part_gse_fast',
#  'mms4_dis_temppara_part_fast',
#  'mms4_dis_tempperp_part_fast',
#  'mms4_dis_part_index_fast',
#  'mms4_dis_bhat_dbcs_fast',
#  'mms4_dis_gse_xform_fast',
#  'mms4_dis_scpot_mean_fast',
#  'mms4_dis_scpot_max_fast',
#  'mms4_dis_fpibentpipe_dsc_fast',
#  'mms4_dis_fpib_gse_srvy_fast',
#  'mms4_dis_fpib_dmpa_srvy_fast',
#  'mms4_dis_pos_gse_fast',
#  'mms4_dis_pos_gsm_fast',
#  'mms4_dis_numberdensity_int_fast',
#  'mms4_dis_numberflux_int_dbcs_fast',
#  'mms4_dis_prestensor_int_dbcs_fast',
#  'mms4_dis_ugrid_int_fast',
#  'mms1_des_errorflags_fast_moms',
#  'mms1_des_compressionloss_fast_moms',
#  'mms2_des_errorflags_fast_moms',
#  'mms2_des_compressionloss_fast_moms',
#  'mms3_des_errorflags_fast_moms',
#  'mms3_des_compressionloss_fast_moms',
#  'mms1_des_errorflags_fast_dist',
#  'mms1_des_compressionloss_fast_dist',
#  'mms2_des_errorflags_fast_dist',
#  'mms2_des_compressionloss_fast_dist',
#  'mms3_des_errorflags_fast_dist',
#  'mms3_des_compressionloss_fast_dist',
#  'mms4_des_errorflags_fast_dist',
#  'mms4_des_compressionloss_fast_dist',
#  'mms1_dis_errorflags_fast_moms',
#  'mms1_dis_compressionloss_fast_moms',
#  'mms2_dis_errorflags_fast_moms',
#  'mms2_dis_compressionloss_fast_moms',
#  'mms3_dis_errorflags_fast_moms',
#  'mms3_dis_compressionloss_fast_moms',
#  'mms4_dis_errorflags_fast_moms',
#  'mms4_dis_compressionloss_fast_moms',
#  'mms1_dis_errorflags_fast_dist',
#  'mms1_dis_compressionloss_fast_dist',
#  'mms2_dis_errorflags_fast_dist',
#  'mms2_dis_compressionloss_fast_dist',
#  'mms3_dis_errorflags_fast_dist',
#  'mms3_dis_compressionloss_fast_dist',
#  'mms4_dis_errorflags_fast_dist',
#  'mms4_dis_compressionloss_fast_dist',
#  'mms1_des_pitchangdist_avg',
#  'mms1_des_errorflags_fast_dist_flagbars_dist',
#  'mms1_dis_errorflags_fast_dist_flagbars_dist',
#  'mms1_dis_errorflags_fast_moms_flagbars_full',
#  'mms1_dis_errorflags_fast_moms_flagbars_main',
#  'mms1_dis_errorflags_fast_moms_flagbars_others',
#  'mms1_dis_errorflags_fast_moms_flagbars_mini',
#  'mms1_des_errorflags_fast_moms_flagbars_full',
#  'mms1_des_errorflags_fast_moms_flagbars_main',
#  'mms1_des_errorflags_fast_moms_flagbars_others',
#  'mms1_des_errorflags_fast_moms_flagbars_mini',
#  'mms2_des_pitchangdist_avg',
#  'mms2_des_errorflags_fast_dist_flagbars_dist',
#  'mms2_dis_errorflags_fast_dist_flagbars_dist',
#  'mms2_dis_errorflags_fast_moms_flagbars_full',
#  'mms2_dis_errorflags_fast_moms_flagbars_main',
#  'mms2_dis_errorflags_fast_moms_flagbars_others',
#  'mms2_dis_errorflags_fast_moms_flagbars_mini',
#  'mms2_des_errorflags_fast_moms_flagbars_full',
#  'mms2_des_errorflags_fast_moms_flagbars_main',
#  'mms2_des_errorflags_fast_moms_flagbars_others',
#  'mms2_des_errorflags_fast_moms_flagbars_mini',
#  'mms3_des_pitchangdist_avg',
#  'mms3_des_errorflags_fast_dist_flagbars_dist',
#  'mms3_dis_errorflags_fast_dist_flagbars_dist',
#  'mms3_dis_errorflags_fast_moms_flagbars_full',
#  'mms3_dis_errorflags_fast_moms_flagbars_main',
#  'mms3_dis_errorflags_fast_moms_flagbars_others',
#  'mms3_dis_errorflags_fast_moms_flagbars_mini',
#  'mms3_des_errorflags_fast_moms_flagbars_full',
#  'mms3_des_errorflags_fast_moms_flagbars_main',
#  'mms3_des_errorflags_fast_moms_flagbars_others',
#  'mms3_des_errorflags_fast_moms_flagbars_mini',
#  'mms4_des_errorflags_fast_dist_flagbars_dist',
#  'mms4_dis_errorflags_fast_dist_flagbars_dist',
#  'mms4_dis_errorflags_fast_moms_flagbars_full',
#  'mms4_dis_errorflags_fast_moms_flagbars_main',
#  'mms4_dis_errorflags_fast_moms_flagbars_others',
#  'mms4_dis_errorflags_fast_moms_flagbars_mini']

# %% [markdown]
# The MMS ephemeris data is in ECI coordinates.  We'll be working in GSE, so we need to transform the loaded variables.

# %%
# To use the MMS qcotrans routine, the quaternions representing the transforms must be
# loaded from the MEC dataset.
pyspedas.mms.mec(trange=['2023-03-24/07:00','2023-03-24/08:00'], probe=['1','2','3','4'])

for i in ('1','2','3','4'): 
    pyspedas.mms.mms_qcotrans('mms'+i+'_defeph_pos','mms'+i+'_defeph_pos_gse',in_coord='eci',out_coord='gse')
    pyspedas.mms.mms_qcotrans('mms'+i+'_defeph_vel','mms'+i+'_defeph_vel_gse',in_coord='eci',out_coord='gse')
# Out:
# 28-Dec-24 20:11:41: Loading ./pyspedas_data/mms/mms1/mec/srvy/l2/epht89q/2023/03/mms1_mec_srvy_l2_epht89q_20230324_v2.2.0.cdf
# 28-Dec-24 20:11:41: Loading ./pyspedas_data/mms/mms2/mec/srvy/l2/epht89q/2023/03/mms2_mec_srvy_l2_epht89q_20230324_v2.2.0.cdf
# 28-Dec-24 20:11:41: Loading ./pyspedas_data/mms/mms3/mec/srvy/l2/epht89q/2023/03/mms3_mec_srvy_l2_epht89q_20230324_v2.2.0.cdf
# 28-Dec-24 20:11:41: Loading ./pyspedas_data/mms/mms4/mec/srvy/l2/epht89q/2023/03/mms4_mec_srvy_l2_epht89q_20230324_v2.2.0.cdf
# 28-Dec-24 20:12:12: Interpolating the data to the MEC quaternion time stamps.
# 28-Dec-24 20:12:12: tinterpol (linear) was applied to: mms1_defeph_pos-itrp
# 28-Dec-24 20:12:12: Interpolating the data to the MEC quaternion time stamps.
# 28-Dec-24 20:12:12: tinterpol (linear) was applied to: mms1_defeph_vel-itrp
# 28-Dec-24 20:12:12: Interpolating the data to the MEC quaternion time stamps.
# 28-Dec-24 20:12:12: tinterpol (linear) was applied to: mms2_defeph_pos-itrp
# 28-Dec-24 20:12:13: Interpolating the data to the MEC quaternion time stamps.
# 28-Dec-24 20:12:13: tinterpol (linear) was applied to: mms2_defeph_vel-itrp
# 28-Dec-24 20:12:13: Interpolating the data to the MEC quaternion time stamps.
# 28-Dec-24 20:12:13: tinterpol (linear) was applied to: mms3_defeph_pos-itrp
# 28-Dec-24 20:12:13: Interpolating the data to the MEC quaternion time stamps.
# 28-Dec-24 20:12:13: tinterpol (linear) was applied to: mms3_defeph_vel-itrp
# 28-Dec-24 20:12:13: Interpolating the data to the MEC quaternion time stamps.
# 28-Dec-24 20:12:13: tinterpol (linear) was applied to: mms4_defeph_pos-itrp
# 28-Dec-24 20:12:13: Interpolating the data to the MEC quaternion time stamps.
# 28-Dec-24 20:12:13: tinterpol (linear) was applied to: mms4_defeph_vel-itrp

# %% [markdown]
# We'll generate a summary plot of the data loaded so far:

# %%
timespan('2023-03-24/07:00',10,'minutes')
options('mms1_des_numberdensity_fast','ylog',False)
fig1_vars=['mms1_defeph_pos_gse','mms1_defeph_vel_gse','mms1_fgm_b_gse_srvy_l2','mms1_dis_bulkv_dbcs_fast','mms1_des_numberdensity_fast','mms1_des_energyspectr_omni_fast','mms1_dis_energyspectr_omni_fast']

tplot(fig1_vars)

# %% [markdown]
# Let's get a sense of the probe separations and orbital velocity during this time:

# %%
from pytplot import subtract
from pyspedas import tvectot

subtract('mms1_defeph_pos_gse','mms2_defeph_pos_gse',newname='mms1_mms2_dist')
subtract('mms1_defeph_pos_gse','mms3_defeph_pos_gse',newname='mms1_mms3_dist')
subtract('mms1_defeph_pos_gse','mms4_defeph_pos_gse',newname='mms1_mms4_dist')
subtract('mms2_defeph_pos_gse','mms3_defeph_pos_gse',newname='mms2_mms3_dist')
tvectot(['mms1_mms2_dist','mms1_mms3_dist','mms1_mms4_dist','mms2_mms3_dist','mms1_defeph_vel_gse'])
tplot(['mms1_mms2_dist_tot','mms1_mms3_dist_tot','mms1_mms4_dist_tot', 'mms2_mms3_dist_tot','mms1_defeph_vel_gse_tot'])
# Out:
# 28-Dec-24 20:12:13: wildcard_expand: No match found for mms1_mms2_dist_tot
# 28-Dec-24 20:12:13: wildcard_expand: No match found for mms1_mms3_dist_tot
# 28-Dec-24 20:12:13: wildcard_expand: No match found for mms1_mms4_dist_tot
# 28-Dec-24 20:12:13: wildcard_expand: No match found for mms2_mms3_dist_tot
# 28-Dec-24 20:12:13: wildcard_expand: No match found for mms1_defeph_vel_gse_tot
# 28-Dec-24 20:12:13: tplot: No matching tplot names were found

# %% [markdown]
# So for future reference, the tetrahedron size is on the order of 75 km, and the constellation is moving at about 3.45 km/sec.

# %% [markdown]
# Now we will find the magnetic nulls during this event, and examine the field toplology for a couple of them:

# %%
mms_positions = ['mms1_defeph_pos_gse','mms2_defeph_pos_gse','mms3_defeph_pos_gse','mms4_defeph_pos_gse']
mms_fields = ['mms1_fgm_b_gse_brst_l2','mms2_fgm_b_gse_brst_l2','mms3_fgm_b_gse_brst_l2','mms4_fgm_b_gse_brst_l2']

null_vars = pyspedas.find_magnetic_nulls_fote(fields=mms_fields, positions=mms_positions, smooth_fields=True)

pytplot.tplot_names()

print(null_vars)
# Out:
# 28-Dec-24 20:12:15: tsmooth was applied to: mms1_fgm_b_gse_brst_l2_sm
# 28-Dec-24 20:12:16: tsmooth was applied to: mms2_fgm_b_gse_brst_l2_sm
# 28-Dec-24 20:12:17: tsmooth was applied to: mms3_fgm_b_gse_brst_l2_sm
# 28-Dec-24 20:12:19: tsmooth was applied to: mms4_fgm_b_gse_brst_l2_sm
# 28-Dec-24 20:12:19: tinterpol (linear) was applied to: pos1_i
# 28-Dec-24 20:12:19: tinterpol (linear) was applied to: pos2_i
# 28-Dec-24 20:12:19: tinterpol (linear) was applied to: pos3_i
# 28-Dec-24 20:12:19: tinterpol (linear) was applied to: pos4_i
# 28-Dec-24 20:12:19: tinterpol (linear) was applied to: b1_i
# 28-Dec-24 20:12:19: tinterpol (linear) was applied to: b2_i
# 28-Dec-24 20:12:19: tinterpol (linear) was applied to: b3_i
# 28-Dec-24 20:12:19: tinterpol (linear) was applied to: b4_i
# 28-Dec-24 20:12:28: Calculations completed
# 0 : mms1_defeph_pos
# 1 : mms1_defeph_vel
# 2 : mms2_defeph_pos
# 3 : mms2_defeph_vel
# 4 : mms3_defeph_pos
# 5 : mms3_defeph_vel
# 6 : mms4_defeph_pos
# 7 : mms4_defeph_vel
# 8 : Epoch
# 9 : mms1_fgm_b_gse_brst_l2
# 10 : mms1_fgm_b_gsm_brst_l2
# 11 : mms1_fgm_b_dmpa_brst_l2
# 12 : mms1_fgm_b_bcs_brst_l2
# 13 : mms1_fgm_flag_brst_l2
# 14 : Epoch_state
# 15 : mms1_fgm_hirange_brst_l2
# 16 : mms1_fgm_bdeltahalf_brst_l2
# 17 : mms1_fgm_stemp_brst_l2
# 18 : mms1_fgm_etemp_brst_l2
# 19 : mms1_fgm_mode_brst_l2
# 20 : mms2_fgm_b_gse_brst_l2
# 21 : mms2_fgm_b_gsm_brst_l2
# 22 : mms2_fgm_b_dmpa_brst_l2
# 23 : mms2_fgm_b_bcs_brst_l2
# 24 : mms2_fgm_flag_brst_l2
# 25 : mms2_fgm_hirange_brst_l2
# 26 : mms2_fgm_bdeltahalf_brst_l2
# 27 : mms2_fgm_stemp_brst_l2
# 28 : mms2_fgm_etemp_brst_l2
# 29 : mms2_fgm_mode_brst_l2
# 30 : mms3_fgm_b_gse_brst_l2
# 31 : mms3_fgm_b_gsm_brst_l2
# 32 : mms3_fgm_b_dmpa_brst_l2
# 33 : mms3_fgm_b_bcs_brst_l2
# 34 : mms3_fgm_flag_brst_l2
# 35 : mms3_fgm_hirange_brst_l2
# 36 : mms3_fgm_bdeltahalf_brst_l2
# 37 : mms3_fgm_stemp_brst_l2
# 38 : mms3_fgm_etemp_brst_l2
# 39 : mms3_fgm_mode_brst_l2
# 40 : mms4_fgm_b_gse_brst_l2
# 41 : mms4_fgm_b_gsm_brst_l2
# 42 : mms4_fgm_b_dmpa_brst_l2
# 43 : mms4_fgm_b_bcs_brst_l2
# 44 : mms4_fgm_flag_brst_l2
# 45 : mms4_fgm_hirange_brst_l2
# 46 : mms4_fgm_bdeltahalf_brst_l2
# 47 : mms4_fgm_stemp_brst_l2
# 48 : mms4_fgm_etemp_brst_l2
# 49 : mms4_fgm_mode_brst_l2
# 50 : mms1_fgm_b_dmpa_brst_l2_bvec
# 51 : mms1_fgm_b_dmpa_brst_l2_btot
# 52 : mms1_fgm_b_gse_brst_l2_bvec
# 53 : mms1_fgm_b_gse_brst_l2_btot
# 54 : mms1_fgm_b_gsm_brst_l2_bvec
# 55 : mms1_fgm_b_gsm_brst_l2_btot
# 56 : mms1_fgm_b_bcs_brst_l2_bvec
# 57 : mms1_fgm_b_bcs_brst_l2_btot
# 58 : mms2_fgm_b_dmpa_brst_l2_bvec
# 59 : mms2_fgm_b_dmpa_brst_l2_btot
# 60 : mms2_fgm_b_gse_brst_l2_bvec
# 61 : mms2_fgm_b_gse_brst_l2_btot
# 62 : mms2_fgm_b_gsm_brst_l2_bvec
# 63 : mms2_fgm_b_gsm_brst_l2_btot
# 64 : mms2_fgm_b_bcs_brst_l2_bvec
# 65 : mms2_fgm_b_bcs_brst_l2_btot
# 66 : mms3_fgm_b_dmpa_brst_l2_bvec
# 67 : mms3_fgm_b_dmpa_brst_l2_btot
# 68 : mms3_fgm_b_gse_brst_l2_bvec
# 69 : mms3_fgm_b_gse_brst_l2_btot
# 70 : mms3_fgm_b_gsm_brst_l2_bvec
# 71 : mms3_fgm_b_gsm_brst_l2_btot
# 72 : mms3_fgm_b_bcs_brst_l2_bvec
# 73 : mms3_fgm_b_bcs_brst_l2_btot
# 74 : mms4_fgm_b_dmpa_brst_l2_bvec
# 75 : mms4_fgm_b_dmpa_brst_l2_btot
# 76 : mms4_fgm_b_gse_brst_l2_bvec
# 77 : mms4_fgm_b_gse_brst_l2_btot
# 78 : mms4_fgm_b_gsm_brst_l2_bvec
# 79 : mms4_fgm_b_gsm_brst_l2_btot
# 80 : mms4_fgm_b_bcs_brst_l2_bvec
# 81 : mms4_fgm_b_bcs_brst_l2_btot
# 82 : mms1_fgm_b_gse_srvy_l2
# 83 : mms1_fgm_b_gsm_srvy_l2
# 84 : mms1_fgm_b_dmpa_srvy_l2
# 85 : mms1_fgm_b_bcs_srvy_l2
# 86 : mms1_fgm_flag_srvy_l2
# 87 : mms1_fgm_hirange_srvy_l2
# 88 : mms1_fgm_bdeltahalf_srvy_l2
# 89 : mms1_fgm_stemp_srvy_l2
# 90 : mms1_fgm_etemp_srvy_l2
# 91 : mms1_fgm_mode_srvy_l2
# 92 : mms1_fgm_b_dmpa_srvy_l2_bvec
# 93 : mms1_fgm_b_dmpa_srvy_l2_btot
# 94 : mms1_fgm_b_gse_srvy_l2_bvec
# 95 : mms1_fgm_b_gse_srvy_l2_btot
# 96 : mms1_fgm_b_gsm_srvy_l2_bvec
# 97 : mms1_fgm_b_gsm_srvy_l2_btot
# 98 : mms1_fgm_b_bcs_srvy_l2_bvec
# 99 : mms1_fgm_b_bcs_srvy_l2_btot
# 100 : Epoch_plus_var
# 101 : Epoch_minus_var
# 102 : mms1_des_startdelphi_count_fast
# 103 : mms1_des_startdelphi_angle_fast
# 104 : mms1_des_dist_fast
# 105 : mms1_des_disterr_fast
# 106 : mms1_des_avgf1counts_fast
# 107 : mms1_des_theta_fast
# 108 : mms1_des_theta_delta_fast
# 109 : mms1_des_energy_fast
# 110 : mms1_des_energy_delta_fast
# 111 : mms1_des_phi_fast
# 112 : mms1_des_phi_delta_fast
# 113 : mms1_des_pitchangdist_lowen_fast
# 114 : mms1_des_pitchangdist_miden_fast
# 115 : mms1_des_pitchangdist_highen_fast
# 116 : mms1_des_energyspectr_px_fast
# 117 : mms1_des_energyspectr_mx_fast
# 118 : mms1_des_energyspectr_py_fast
# 119 : mms1_des_energyspectr_my_fast
# 120 : mms1_des_energyspectr_pz_fast
# 121 : mms1_des_energyspectr_mz_fast
# 122 : mms1_des_energyspectr_par_fast
# 123 : mms1_des_energyspectr_anti_fast
# 124 : mms1_des_energyspectr_perp_fast
# 125 : mms1_des_energyspectr_omni_fast
# 126 : mms1_des_numberdensity_fast
# 127 : mms1_des_numberdensity_err_fast
# 128 : mms1_des_densityextrapolation_low_fast
# 129 : mms1_des_densityextrapolation_high_fast
# 130 : mms1_des_bulkv_dbcs_fast
# 131 : mms1_des_bulkv_spintone_dbcs_fast
# 132 : mms1_des_bulkv_gse_fast
# 133 : mms1_des_bulkv_spintone_gse_fast
# 134 : mms1_des_bulkv_err_fast
# 135 : mms1_des_prestensor_dbcs_fast
# 136 : mms1_des_prestensor_gse_fast
# 137 : mms1_des_prestensor_err_fast
# 138 : mms1_des_temptensor_dbcs_fast
# 139 : mms1_des_temptensor_gse_fast
# 140 : mms1_des_temptensor_err_fast
# 141 : mms1_des_heatq_dbcs_fast
# 142 : mms1_des_heatq_gse_fast
# 143 : mms1_des_heatq_err_fast
# 144 : mms1_des_alpha_fast
# 145 : mms1_des_alpha_delta_fast
# 146 : mms1_des_temppara_fast
# 147 : mms1_des_tempperp_fast
# 148 : mms1_des_numberdensity_part_fast
# 149 : mms1_des_bulkv_part_dbcs_fast
# 150 : mms1_des_bulkv_part_gse_fast
# 151 : mms1_des_prestensor_part_dbcs_fast
# 152 : mms1_des_prestensor_part_gse_fast
# 153 : mms1_des_temptensor_part_dbcs_fast
# 154 : mms1_des_temptensor_part_gse_fast
# 155 : mms1_des_temppara_part_fast
# 156 : mms1_des_tempperp_part_fast
# 157 : mms1_des_part_index_fast
# 158 : mms1_des_bhat_dbcs_fast
# 159 : mms1_des_gse_xform_fast
# 160 : mms1_des_scpot_mean_fast
# 161 : mms1_des_scpot_max_fast
# 162 : mms1_des_fpibentpipe_dsc_fast
# 163 : mms1_des_fpib_gse_srvy_fast
# 164 : mms1_des_fpib_dmpa_srvy_fast
# 165 : mms1_des_pos_gse_fast
# 166 : mms1_des_pos_gsm_fast
# 167 : mms1_des_numberdensity_int_fast
# 168 : mms1_des_numberflux_int_dbcs_fast
# 169 : mms1_des_prestensor_int_dbcs_fast
# 170 : mms1_des_ugrid_int_fast
# 171 : mms1_dis_startdelphi_count_fast
# 172 : mms1_dis_startdelphi_angle_fast
# 173 : mms1_dis_dist_fast
# 174 : mms1_dis_disterr_fast
# 175 : mms1_dis_avgf1counts_fast
# 176 : mms1_dis_theta_fast
# 177 : mms1_dis_theta_delta_fast
# 178 : mms1_dis_energy_fast
# 179 : mms1_dis_energy_delta_fast
# 180 : mms1_dis_phi_fast
# 181 : mms1_dis_phi_delta_fast
# 182 : mms1_dis_energyspectr_px_fast
# 183 : mms1_dis_energyspectr_mx_fast
# 184 : mms1_dis_energyspectr_py_fast
# 185 : mms1_dis_energyspectr_my_fast
# 186 : mms1_dis_energyspectr_pz_fast
# 187 : mms1_dis_energyspectr_mz_fast
# 188 : mms1_dis_energyspectr_omni_fast
# 189 : mms1_dis_spectr_bg_fast
# 190 : mms1_dis_numberdensity_bg_fast
# 191 : mms1_dis_numberdensity_fast
# 192 : mms1_dis_numberdensity_err_fast
# 193 : mms1_dis_densityextrapolation_low_fast
# 194 : mms1_dis_densityextrapolation_high_fast
# 195 : mms1_dis_bulkv_dbcs_fast
# 196 : mms1_dis_bulkv_spintone_dbcs_fast
# 197 : mms1_dis_bulkv_gse_fast
# 198 : mms1_dis_bulkv_spintone_gse_fast
# 199 : mms1_dis_bulkv_err_fast
# 200 : mms1_dis_prestensor_dbcs_fast
# 201 : mms1_dis_prestensor_gse_fast
# 202 : mms1_dis_prestensor_err_fast
# 203 : mms1_dis_pres_bg_fast
# 204 : mms1_dis_temptensor_dbcs_fast
# 205 : mms1_dis_temptensor_gse_fast
# 206 : mms1_dis_temptensor_err_fast
# 207 : mms1_dis_heatq_dbcs_fast
# 208 : mms1_dis_heatq_gse_fast
# 209 : mms1_dis_heatq_err_fast
# 210 : mms1_dis_temppara_fast
# 211 : mms1_dis_tempperp_fast
# 212 : mms1_dis_numberdensity_part_fast
# 213 : mms1_dis_bulkv_part_dbcs_fast
# 214 : mms1_dis_bulkv_part_gse_fast
# 215 : mms1_dis_prestensor_part_dbcs_fast
# 216 : mms1_dis_prestensor_part_gse_fast
# 217 : mms1_dis_temptensor_part_dbcs_fast
# 218 : mms1_dis_temptensor_part_gse_fast
# 219 : mms1_dis_temppara_part_fast
# 220 : mms1_dis_tempperp_part_fast
# 221 : mms1_dis_part_index_fast
# 222 : mms1_dis_bhat_dbcs_fast
# 223 : mms1_dis_gse_xform_fast
# 224 : mms1_dis_scpot_mean_fast
# 225 : mms1_dis_scpot_max_fast
# 226 : mms1_dis_fpibentpipe_dsc_fast
# 227 : mms1_dis_fpib_gse_srvy_fast
# 228 : mms1_dis_fpib_dmpa_srvy_fast
# 229 : mms1_dis_pos_gse_fast
# 230 : mms1_dis_pos_gsm_fast
# 231 : mms1_dis_numberdensity_int_fast
# 232 : mms1_dis_numberflux_int_dbcs_fast
# 233 : mms1_dis_prestensor_int_dbcs_fast
# 234 : mms1_dis_ugrid_int_fast
# 235 : mms2_des_startdelphi_count_fast
# 236 : mms2_des_startdelphi_angle_fast
# 237 : mms2_des_dist_fast
# 238 : mms2_des_disterr_fast
# 239 : mms2_des_avgf1counts_fast
# 240 : mms2_des_theta_fast
# 241 : mms2_des_theta_delta_fast
# 242 : mms2_des_energy_fast
# 243 : mms2_des_energy_delta_fast
# 244 : mms2_des_phi_fast
# 245 : mms2_des_phi_delta_fast
# 246 : mms2_des_pitchangdist_lowen_fast
# 247 : mms2_des_pitchangdist_miden_fast
# 248 : mms2_des_pitchangdist_highen_fast
# 249 : mms2_des_energyspectr_px_fast
# 250 : mms2_des_energyspectr_mx_fast
# 251 : mms2_des_energyspectr_py_fast
# 252 : mms2_des_energyspectr_my_fast
# 253 : mms2_des_energyspectr_pz_fast
# 254 : mms2_des_energyspectr_mz_fast
# 255 : mms2_des_energyspectr_par_fast
# 256 : mms2_des_energyspectr_anti_fast
# 257 : mms2_des_energyspectr_perp_fast
# 258 : mms2_des_energyspectr_omni_fast
# 259 : mms2_des_numberdensity_fast
# 260 : mms2_des_numberdensity_err_fast
# 261 : mms2_des_densityextrapolation_low_fast
# 262 : mms2_des_densityextrapolation_high_fast
# 263 : mms2_des_bulkv_dbcs_fast
# 264 : mms2_des_bulkv_spintone_dbcs_fast
# 265 : mms2_des_bulkv_gse_fast
# 266 : mms2_des_bulkv_spintone_gse_fast
# 267 : mms2_des_bulkv_err_fast
# 268 : mms2_des_prestensor_dbcs_fast
# 269 : mms2_des_prestensor_gse_fast
# 270 : mms2_des_prestensor_err_fast
# 271 : mms2_des_temptensor_dbcs_fast
# 272 : mms2_des_temptensor_gse_fast
# 273 : mms2_des_temptensor_err_fast
# 274 : mms2_des_heatq_dbcs_fast
# 275 : mms2_des_heatq_gse_fast
# 276 : mms2_des_heatq_err_fast
# 277 : mms2_des_alpha_fast
# 278 : mms2_des_alpha_delta_fast
# 279 : mms2_des_temppara_fast
# 280 : mms2_des_tempperp_fast
# 281 : mms2_des_numberdensity_part_fast
# 282 : mms2_des_bulkv_part_dbcs_fast
# 283 : mms2_des_bulkv_part_gse_fast
# 284 : mms2_des_prestensor_part_dbcs_fast
# 285 : mms2_des_prestensor_part_gse_fast
# 286 : mms2_des_temptensor_part_dbcs_fast
# 287 : mms2_des_temptensor_part_gse_fast
# 288 : mms2_des_temppara_part_fast
# 289 : mms2_des_tempperp_part_fast
# 290 : mms2_des_part_index_fast
# 291 : mms2_des_bhat_dbcs_fast
# 292 : mms2_des_gse_xform_fast
# 293 : mms2_des_scpot_mean_fast
# 294 : mms2_des_scpot_max_fast
# 295 : mms2_des_fpibentpipe_dsc_fast
# 296 : mms2_des_fpib_gse_srvy_fast
# 297 : mms2_des_fpib_dmpa_srvy_fast
# 298 : mms2_des_pos_gse_fast
# 299 : mms2_des_pos_gsm_fast
# 300 : mms2_des_numberdensity_int_fast
# 301 : mms2_des_numberflux_int_dbcs_fast
# 302 : mms2_des_prestensor_int_dbcs_fast
# 303 : mms2_des_ugrid_int_fast
# 304 : mms2_dis_startdelphi_count_fast
# 305 : mms2_dis_startdelphi_angle_fast
# 306 : mms2_dis_dist_fast
# 307 : mms2_dis_disterr_fast
# 308 : mms2_dis_avgf1counts_fast
# 309 : mms2_dis_theta_fast
# 310 : mms2_dis_theta_delta_fast
# 311 : mms2_dis_energy_fast
# 312 : mms2_dis_energy_delta_fast
# 313 : mms2_dis_phi_fast
# 314 : mms2_dis_phi_delta_fast
# 315 : mms2_dis_energyspectr_px_fast
# 316 : mms2_dis_energyspectr_mx_fast
# 317 : mms2_dis_energyspectr_py_fast
# 318 : mms2_dis_energyspectr_my_fast
# 319 : mms2_dis_energyspectr_pz_fast
# 320 : mms2_dis_energyspectr_mz_fast
# 321 : mms2_dis_energyspectr_omni_fast
# 322 : mms2_dis_spectr_bg_fast
# 323 : mms2_dis_numberdensity_bg_fast
# 324 : mms2_dis_numberdensity_fast
# 325 : mms2_dis_numberdensity_err_fast
# 326 : mms2_dis_densityextrapolation_low_fast
# 327 : mms2_dis_densityextrapolation_high_fast
# 328 : mms2_dis_bulkv_dbcs_fast
# 329 : mms2_dis_bulkv_spintone_dbcs_fast
# 330 : mms2_dis_bulkv_gse_fast
# 331 : mms2_dis_bulkv_spintone_gse_fast
# 332 : mms2_dis_bulkv_err_fast
# 333 : mms2_dis_prestensor_dbcs_fast
# 334 : mms2_dis_prestensor_gse_fast
# 335 : mms2_dis_prestensor_err_fast
# 336 : mms2_dis_pres_bg_fast
# 337 : mms2_dis_temptensor_dbcs_fast
# 338 : mms2_dis_temptensor_gse_fast
# 339 : mms2_dis_temptensor_err_fast
# 340 : mms2_dis_heatq_dbcs_fast
# 341 : mms2_dis_heatq_gse_fast
# 342 : mms2_dis_heatq_err_fast
# 343 : mms2_dis_temppara_fast
# 344 : mms2_dis_tempperp_fast
# 345 : mms2_dis_numberdensity_part_fast
# 346 : mms2_dis_bulkv_part_dbcs_fast
# 347 : mms2_dis_bulkv_part_gse_fast
# 348 : mms2_dis_prestensor_part_dbcs_fast
# 349 : mms2_dis_prestensor_part_gse_fast
# 350 : mms2_dis_temptensor_part_dbcs_fast
# 351 : mms2_dis_temptensor_part_gse_fast
# 352 : mms2_dis_temppara_part_fast
# 353 : mms2_dis_tempperp_part_fast
# 354 : mms2_dis_part_index_fast
# 355 : mms2_dis_bhat_dbcs_fast
# 356 : mms2_dis_gse_xform_fast
# 357 : mms2_dis_scpot_mean_fast
# 358 : mms2_dis_scpot_max_fast
# 359 : mms2_dis_fpibentpipe_dsc_fast
# 360 : mms2_dis_fpib_gse_srvy_fast
# 361 : mms2_dis_fpib_dmpa_srvy_fast
# 362 : mms2_dis_pos_gse_fast
# 363 : mms2_dis_pos_gsm_fast
# 364 : mms2_dis_numberdensity_int_fast
# 365 : mms2_dis_numberflux_int_dbcs_fast
# 366 : mms2_dis_prestensor_int_dbcs_fast
# 367 : mms2_dis_ugrid_int_fast
# 368 : mms3_des_startdelphi_count_fast
# 369 : mms3_des_startdelphi_angle_fast
# 370 : mms3_des_dist_fast
# 371 : mms3_des_disterr_fast
# 372 : mms3_des_avgf1counts_fast
# 373 : mms3_des_theta_fast
# 374 : mms3_des_theta_delta_fast
# 375 : mms3_des_energy_fast
# 376 : mms3_des_energy_delta_fast
# 377 : mms3_des_phi_fast
# 378 : mms3_des_phi_delta_fast
# 379 : mms3_des_pitchangdist_lowen_fast
# 380 : mms3_des_pitchangdist_miden_fast
# 381 : mms3_des_pitchangdist_highen_fast
# 382 : mms3_des_energyspectr_px_fast
# 383 : mms3_des_energyspectr_mx_fast
# 384 : mms3_des_energyspectr_py_fast
# 385 : mms3_des_energyspectr_my_fast
# 386 : mms3_des_energyspectr_pz_fast
# 387 : mms3_des_energyspectr_mz_fast
# 388 : mms3_des_energyspectr_par_fast
# 389 : mms3_des_energyspectr_anti_fast
# 390 : mms3_des_energyspectr_perp_fast
# 391 : mms3_des_energyspectr_omni_fast
# 392 : mms3_des_numberdensity_fast
# 393 : mms3_des_numberdensity_err_fast
# 394 : mms3_des_densityextrapolation_low_fast
# 395 : mms3_des_densityextrapolation_high_fast
# 396 : mms3_des_bulkv_dbcs_fast
# 397 : mms3_des_bulkv_spintone_dbcs_fast
# 398 : mms3_des_bulkv_gse_fast
# 399 : mms3_des_bulkv_spintone_gse_fast
# 400 : mms3_des_bulkv_err_fast
# 401 : mms3_des_prestensor_dbcs_fast
# 402 : mms3_des_prestensor_gse_fast
# 403 : mms3_des_prestensor_err_fast
# 404 : mms3_des_temptensor_dbcs_fast
# 405 : mms3_des_temptensor_gse_fast
# 406 : mms3_des_temptensor_err_fast
# 407 : mms3_des_heatq_dbcs_fast
# 408 : mms3_des_heatq_gse_fast
# 409 : mms3_des_heatq_err_fast
# 410 : mms3_des_alpha_fast
# 411 : mms3_des_alpha_delta_fast
# 412 : mms3_des_temppara_fast
# 413 : mms3_des_tempperp_fast
# 414 : mms3_des_numberdensity_part_fast
# 415 : mms3_des_bulkv_part_dbcs_fast
# 416 : mms3_des_bulkv_part_gse_fast
# 417 : mms3_des_prestensor_part_dbcs_fast
# 418 : mms3_des_prestensor_part_gse_fast
# 419 : mms3_des_temptensor_part_dbcs_fast
# 420 : mms3_des_temptensor_part_gse_fast
# 421 : mms3_des_temppara_part_fast
# 422 : mms3_des_tempperp_part_fast
# 423 : mms3_des_part_index_fast
# 424 : mms3_des_bhat_dbcs_fast
# 425 : mms3_des_gse_xform_fast
# 426 : mms3_des_scpot_mean_fast
# 427 : mms3_des_scpot_max_fast
# 428 : mms3_des_fpibentpipe_dsc_fast
# 429 : mms3_des_fpib_gse_srvy_fast
# 430 : mms3_des_fpib_dmpa_srvy_fast
# 431 : mms3_des_pos_gse_fast
# 432 : mms3_des_pos_gsm_fast
# 433 : mms3_des_numberdensity_int_fast
# 434 : mms3_des_numberflux_int_dbcs_fast
# 435 : mms3_des_prestensor_int_dbcs_fast
# 436 : mms3_des_ugrid_int_fast
# 437 : mms3_dis_startdelphi_count_fast
# 438 : mms3_dis_startdelphi_angle_fast
# 439 : mms3_dis_dist_fast
# 440 : mms3_dis_disterr_fast
# 441 : mms3_dis_avgf1counts_fast
# 442 : mms3_dis_theta_fast
# 443 : mms3_dis_theta_delta_fast
# 444 : mms3_dis_energy_fast
# 445 : mms3_dis_energy_delta_fast
# 446 : mms3_dis_phi_fast
# 447 : mms3_dis_phi_delta_fast
# 448 : mms3_dis_energyspectr_px_fast
# 449 : mms3_dis_energyspectr_mx_fast
# 450 : mms3_dis_energyspectr_py_fast
# 451 : mms3_dis_energyspectr_my_fast
# 452 : mms3_dis_energyspectr_pz_fast
# 453 : mms3_dis_energyspectr_mz_fast
# 454 : mms3_dis_energyspectr_omni_fast
# 455 : mms3_dis_spectr_bg_fast
# 456 : mms3_dis_numberdensity_bg_fast
# 457 : mms3_dis_numberdensity_fast
# 458 : mms3_dis_numberdensity_err_fast
# 459 : mms3_dis_densityextrapolation_low_fast
# 460 : mms3_dis_densityextrapolation_high_fast
# 461 : mms3_dis_bulkv_dbcs_fast
# 462 : mms3_dis_bulkv_spintone_dbcs_fast
# 463 : mms3_dis_bulkv_gse_fast
# 464 : mms3_dis_bulkv_spintone_gse_fast
# 465 : mms3_dis_bulkv_err_fast
# 466 : mms3_dis_prestensor_dbcs_fast
# 467 : mms3_dis_prestensor_gse_fast
# 468 : mms3_dis_prestensor_err_fast
# 469 : mms3_dis_pres_bg_fast
# 470 : mms3_dis_temptensor_dbcs_fast
# 471 : mms3_dis_temptensor_gse_fast
# 472 : mms3_dis_temptensor_err_fast
# 473 : mms3_dis_heatq_dbcs_fast
# 474 : mms3_dis_heatq_gse_fast
# 475 : mms3_dis_heatq_err_fast
# 476 : mms3_dis_temppara_fast
# 477 : mms3_dis_tempperp_fast
# 478 : mms3_dis_numberdensity_part_fast
# 479 : mms3_dis_bulkv_part_dbcs_fast
# 480 : mms3_dis_bulkv_part_gse_fast
# 481 : mms3_dis_prestensor_part_dbcs_fast
# 482 : mms3_dis_prestensor_part_gse_fast
# 483 : mms3_dis_temptensor_part_dbcs_fast
# 484 : mms3_dis_temptensor_part_gse_fast
# 485 : mms3_dis_temppara_part_fast
# 486 : mms3_dis_tempperp_part_fast
# 487 : mms3_dis_part_index_fast
# 488 : mms3_dis_bhat_dbcs_fast
# 489 : mms3_dis_gse_xform_fast
# 490 : mms3_dis_scpot_mean_fast
# 491 : mms3_dis_scpot_max_fast
# 492 : mms3_dis_fpibentpipe_dsc_fast
# 493 : mms3_dis_fpib_gse_srvy_fast
# 494 : mms3_dis_fpib_dmpa_srvy_fast
# 495 : mms3_dis_pos_gse_fast
# 496 : mms3_dis_pos_gsm_fast
# 497 : mms3_dis_numberdensity_int_fast
# 498 : mms3_dis_numberflux_int_dbcs_fast
# 499 : mms3_dis_prestensor_int_dbcs_fast
# 500 : mms3_dis_ugrid_int_fast
# 501 : mms4_des_startdelphi_count_fast
# 502 : mms4_des_startdelphi_angle_fast
# 503 : mms4_des_dist_fast
# 504 : mms4_des_disterr_fast
# 505 : mms4_des_avgf1counts_fast
# 506 : mms4_des_theta_fast
# 507 : mms4_des_theta_delta_fast
# 508 : mms4_des_energy_fast
# 509 : mms4_des_energy_delta_fast
# 510 : mms4_des_phi_fast
# 511 : mms4_des_phi_delta_fast
# 512 : mms4_dis_startdelphi_count_fast
# 513 : mms4_dis_startdelphi_angle_fast
# 514 : mms4_dis_dist_fast
# 515 : mms4_dis_disterr_fast
# 516 : mms4_dis_avgf1counts_fast
# 517 : mms4_dis_theta_fast
# 518 : mms4_dis_theta_delta_fast
# 519 : mms4_dis_energy_fast
# 520 : mms4_dis_energy_delta_fast
# 521 : mms4_dis_phi_fast
# 522 : mms4_dis_phi_delta_fast
# 523 : mms4_dis_energyspectr_px_fast
# 524 : mms4_dis_energyspectr_mx_fast
# 525 : mms4_dis_energyspectr_py_fast
# 526 : mms4_dis_energyspectr_my_fast
# 527 : mms4_dis_energyspectr_pz_fast
# 528 : mms4_dis_energyspectr_mz_fast
# 529 : mms4_dis_energyspectr_omni_fast
# 530 : mms4_dis_spectr_bg_fast
# 531 : mms4_dis_numberdensity_bg_fast
# 532 : mms4_dis_numberdensity_fast
# 533 : mms4_dis_numberdensity_err_fast
# 534 : mms4_dis_densityextrapolation_low_fast
# 535 : mms4_dis_densityextrapolation_high_fast
# 536 : mms4_dis_bulkv_dbcs_fast
# 537 : mms4_dis_bulkv_spintone_dbcs_fast
# 538 : mms4_dis_bulkv_gse_fast
# 539 : mms4_dis_bulkv_spintone_gse_fast
# 540 : mms4_dis_bulkv_err_fast
# 541 : mms4_dis_prestensor_dbcs_fast
# 542 : mms4_dis_prestensor_gse_fast
# 543 : mms4_dis_prestensor_err_fast
# 544 : mms4_dis_pres_bg_fast
# 545 : mms4_dis_temptensor_dbcs_fast
# 546 : mms4_dis_temptensor_gse_fast
# 547 : mms4_dis_temptensor_err_fast
# 548 : mms4_dis_heatq_dbcs_fast
# 549 : mms4_dis_heatq_gse_fast
# 550 : mms4_dis_heatq_err_fast
# 551 : mms4_dis_temppara_fast
# 552 : mms4_dis_tempperp_fast
# 553 : mms4_dis_numberdensity_part_fast
# 554 : mms4_dis_bulkv_part_dbcs_fast
# 555 : mms4_dis_bulkv_part_gse_fast
# 556 : mms4_dis_prestensor_part_dbcs_fast
# 557 : mms4_dis_prestensor_part_gse_fast
# 558 : mms4_dis_temptensor_part_dbcs_fast
# 559 : mms4_dis_temptensor_part_gse_fast
# 560 : mms4_dis_temppara_part_fast
# 561 : mms4_dis_tempperp_part_fast
# 562 : mms4_dis_part_index_fast
# 563 : mms4_dis_bhat_dbcs_fast
# 564 : mms4_dis_gse_xform_fast
# 565 : mms4_dis_scpot_mean_fast
# 566 : mms4_dis_scpot_max_fast
# 567 : mms4_dis_fpibentpipe_dsc_fast
# 568 : mms4_dis_fpib_gse_srvy_fast
# 569 : mms4_dis_fpib_dmpa_srvy_fast
# 570 : mms4_dis_pos_gse_fast
# 571 : mms4_dis_pos_gsm_fast
# 572 : mms4_dis_numberdensity_int_fast
# 573 : mms4_dis_numberflux_int_dbcs_fast
# 574 : mms4_dis_prestensor_int_dbcs_fast
# 575 : mms4_dis_ugrid_int_fast
# 576 : mms1_des_errorflags_fast_moms
# 577 : mms1_des_compressionloss_fast_moms
# 578 : mms2_des_errorflags_fast_moms
# 579 : mms2_des_compressionloss_fast_moms
# 580 : mms3_des_errorflags_fast_moms
# 581 : mms3_des_compressionloss_fast_moms
# 582 : mms1_des_errorflags_fast_dist
# 583 : mms1_des_compressionloss_fast_dist
# 584 : mms2_des_errorflags_fast_dist
# 585 : mms2_des_compressionloss_fast_dist
# 586 : mms3_des_errorflags_fast_dist
# 587 : mms3_des_compressionloss_fast_dist
# 588 : mms4_des_errorflags_fast_dist
# 589 : mms4_des_compressionloss_fast_dist
# 590 : mms1_dis_errorflags_fast_moms
# 591 : mms1_dis_compressionloss_fast_moms
# 592 : mms2_dis_errorflags_fast_moms
# 593 : mms2_dis_compressionloss_fast_moms
# 594 : mms3_dis_errorflags_fast_moms
# 595 : mms3_dis_compressionloss_fast_moms
# 596 : mms4_dis_errorflags_fast_moms
# 597 : mms4_dis_compressionloss_fast_moms
# 598 : mms1_dis_errorflags_fast_dist
# 599 : mms1_dis_compressionloss_fast_dist
# 600 : mms2_dis_errorflags_fast_dist
# 601 : mms2_dis_compressionloss_fast_dist
# 602 : mms3_dis_errorflags_fast_dist
# 603 : mms3_dis_compressionloss_fast_dist
# 604 : mms4_dis_errorflags_fast_dist
# 605 : mms4_dis_compressionloss_fast_dist
# 606 : mms1_des_pitchangdist_avg
# 607 : mms1_des_errorflags_fast_dist_flagbars_dist
# 608 : mms1_dis_errorflags_fast_dist_flagbars_dist
# 609 : mms1_dis_errorflags_fast_moms_flagbars_full
# 610 : mms1_dis_errorflags_fast_moms_flagbars_main
# 611 : mms1_dis_errorflags_fast_moms_flagbars_others
# 612 : mms1_dis_errorflags_fast_moms_flagbars_mini
# 613 : mms1_des_errorflags_fast_moms_flagbars_full
# 614 : mms1_des_errorflags_fast_moms_flagbars_main
# 615 : mms1_des_errorflags_fast_moms_flagbars_others
# 616 : mms1_des_errorflags_fast_moms_flagbars_mini
# 617 : mms2_des_pitchangdist_avg
# 618 : mms2_des_errorflags_fast_dist_flagbars_dist
# 619 : mms2_dis_errorflags_fast_dist_flagbars_dist
# 620 : mms2_dis_errorflags_fast_moms_flagbars_full
# 621 : mms2_dis_errorflags_fast_moms_flagbars_main
# 622 : mms2_dis_errorflags_fast_moms_flagbars_others
# 623 : mms2_dis_errorflags_fast_moms_flagbars_mini
# 624 : mms2_des_errorflags_fast_moms_flagbars_full
# 625 : mms2_des_errorflags_fast_moms_flagbars_main
# 626 : mms2_des_errorflags_fast_moms_flagbars_others
# 627 : mms2_des_errorflags_fast_moms_flagbars_mini
# 628 : mms3_des_pitchangdist_avg
# 629 : mms3_des_errorflags_fast_dist_flagbars_dist
# 630 : mms3_dis_errorflags_fast_dist_flagbars_dist
# 631 : mms3_dis_errorflags_fast_moms_flagbars_full
# 632 : mms3_dis_errorflags_fast_moms_flagbars_main
# 633 : mms3_dis_errorflags_fast_moms_flagbars_others
# 634 : mms3_dis_errorflags_fast_moms_flagbars_mini
# 635 : mms3_des_errorflags_fast_moms_flagbars_full
# 636 : mms3_des_errorflags_fast_moms_flagbars_main
# 637 : mms3_des_errorflags_fast_moms_flagbars_others
# 638 : mms3_des_errorflags_fast_moms_flagbars_mini
# 639 : mms4_des_errorflags_fast_dist_flagbars_dist
# 640 : mms4_dis_errorflags_fast_dist_flagbars_dist
# 641 : mms4_dis_errorflags_fast_moms_flagbars_full
# 642 : mms4_dis_errorflags_fast_moms_flagbars_main
# 643 : mms4_dis_errorflags_fast_moms_flagbars_others
# 644 : mms4_dis_errorflags_fast_moms_flagbars_mini
# 645 : mms1_mec_dipole_tilt
# 646 : mms1_mec_gmst
# 647 : mms1_mec_mlat
# 648 : mms1_mec_mlt
# 649 : mms1_mec_l_dipole
# 650 : mms1_mec_quat_eci_to_bcs
# 651 : mms1_mec_quat_eci_to_dbcs
# 652 : mms1_mec_quat_eci_to_dmpa
# 653 : mms1_mec_quat_eci_to_smpa
# 654 : mms1_mec_quat_eci_to_dsl
# 655 : mms1_mec_quat_eci_to_ssl
# 656 : mms1_mec_L_vec
# 657 : mms1_mec_Z_vec
# 658 : mms1_mec_P_vec
# 659 : mms1_mec_L_phase
# 660 : mms1_mec_Z_phase
# 661 : mms1_mec_P_phase
# 662 : mms1_mec_kp
# 663 : mms1_mec_dst
# 664 : mms1_mec_earth_eclipse_flag
# 665 : mms1_mec_moon_eclipse_flag
# 666 : mms1_mec_r_eci
# 667 : mms1_mec_v_eci
# 668 : mms1_mec_r_gsm
# 669 : mms1_mec_v_gsm
# 670 : mms1_mec_quat_eci_to_gsm
# 671 : mms1_mec_r_geo
# 672 : mms1_mec_v_geo
# 673 : mms1_mec_quat_eci_to_geo
# 674 : mms1_mec_r_sm
# 675 : mms1_mec_v_sm
# 676 : mms1_mec_quat_eci_to_sm
# 677 : mms1_mec_r_gse
# 678 : mms1_mec_v_gse
# 679 : mms1_mec_quat_eci_to_gse
# 680 : mms1_mec_r_gse2000
# 681 : mms1_mec_v_gse2000
# 682 : mms1_mec_quat_eci_to_gse2000
# 683 : mms1_mec_geod_lat
# 684 : mms1_mec_geod_lon
# 685 : mms1_mec_geod_height
# 686 : mms1_mec_r_sun_de421_eci
# 687 : mms1_mec_r_moon_de421_eci
# 688 : mms1_mec_fieldline_type
# 689 : mms1_mec_bsc_gsm
# 690 : mms1_mec_loss_cone_angle_s
# 691 : mms1_mec_loss_cone_angle_n
# 692 : mms1_mec_pfs_geod_latlon
# 693 : mms1_mec_pfn_geod_latlon
# 694 : mms1_mec_pfs_gsm
# 695 : mms1_mec_bfs_gsm
# 696 : mms1_mec_pfn_gsm
# 697 : mms1_mec_bfn_gsm
# 698 : mms1_mec_pmin_gsm
# 699 : mms1_mec_bmin_gsm
# 700 : mms2_mec_dipole_tilt
# 701 : mms2_mec_gmst
# 702 : mms2_mec_mlat
# 703 : mms2_mec_mlt
# 704 : mms2_mec_l_dipole
# 705 : mms2_mec_quat_eci_to_bcs
# 706 : mms2_mec_quat_eci_to_dbcs
# 707 : mms2_mec_quat_eci_to_dmpa
# 708 : mms2_mec_quat_eci_to_smpa
# 709 : mms2_mec_quat_eci_to_dsl
# 710 : mms2_mec_quat_eci_to_ssl
# 711 : mms2_mec_L_vec
# 712 : mms2_mec_Z_vec
# 713 : mms2_mec_P_vec
# 714 : mms2_mec_L_phase
# 715 : mms2_mec_Z_phase
# 716 : mms2_mec_P_phase
# 717 : mms2_mec_kp
# 718 : mms2_mec_dst
# 719 : mms2_mec_earth_eclipse_flag
# 720 : mms2_mec_moon_eclipse_flag
# 721 : mms2_mec_r_eci
# 722 : mms2_mec_v_eci
# 723 : mms2_mec_r_gsm
# 724 : mms2_mec_v_gsm
# 725 : mms2_mec_quat_eci_to_gsm
# 726 : mms2_mec_r_geo
# 727 : mms2_mec_v_geo
# 728 : mms2_mec_quat_eci_to_geo
# 729 : mms2_mec_r_sm
# 730 : mms2_mec_v_sm
# 731 : mms2_mec_quat_eci_to_sm
# 732 : mms2_mec_r_gse
# 733 : mms2_mec_v_gse
# 734 : mms2_mec_quat_eci_to_gse
# 735 : mms2_mec_r_gse2000
# 736 : mms2_mec_v_gse2000
# 737 : mms2_mec_quat_eci_to_gse2000
# 738 : mms2_mec_geod_lat
# 739 : mms2_mec_geod_lon
# 740 : mms2_mec_geod_height
# 741 : mms2_mec_r_sun_de421_eci
# 742 : mms2_mec_r_moon_de421_eci
# 743 : mms2_mec_fieldline_type
# 744 : mms2_mec_bsc_gsm
# 745 : mms2_mec_loss_cone_angle_s
# 746 : mms2_mec_loss_cone_angle_n
# 747 : mms2_mec_pfs_geod_latlon
# 748 : mms2_mec_pfn_geod_latlon
# 749 : mms2_mec_pfs_gsm
# 750 : mms2_mec_bfs_gsm
# 751 : mms2_mec_pfn_gsm
# 752 : mms2_mec_bfn_gsm
# 753 : mms2_mec_pmin_gsm
# 754 : mms2_mec_bmin_gsm
# 755 : mms3_mec_dipole_tilt
# 756 : mms3_mec_gmst
# 757 : mms3_mec_mlat
# 758 : mms3_mec_mlt
# 759 : mms3_mec_l_dipole
# 760 : mms3_mec_quat_eci_to_bcs
# 761 : mms3_mec_quat_eci_to_dbcs
# 762 : mms3_mec_quat_eci_to_dmpa
# 763 : mms3_mec_quat_eci_to_smpa
# 764 : mms3_mec_quat_eci_to_dsl
# 765 : mms3_mec_quat_eci_to_ssl
# 766 : mms3_mec_L_vec
# 767 : mms3_mec_Z_vec
# 768 : mms3_mec_P_vec
# 769 : mms3_mec_L_phase
# 770 : mms3_mec_Z_phase
# 771 : mms3_mec_P_phase
# 772 : mms3_mec_kp
# 773 : mms3_mec_dst
# 774 : mms3_mec_earth_eclipse_flag
# 775 : mms3_mec_moon_eclipse_flag
# 776 : mms3_mec_r_eci
# 777 : mms3_mec_v_eci
# 778 : mms3_mec_r_gsm
# 779 : mms3_mec_v_gsm
# 780 : mms3_mec_quat_eci_to_gsm
# 781 : mms3_mec_r_geo
# 782 : mms3_mec_v_geo
# 783 : mms3_mec_quat_eci_to_geo
# 784 : mms3_mec_r_sm
# 785 : mms3_mec_v_sm
# 786 : mms3_mec_quat_eci_to_sm
# 787 : mms3_mec_r_gse
# 788 : mms3_mec_v_gse
# 789 : mms3_mec_quat_eci_to_gse
# 790 : mms3_mec_r_gse2000
# 791 : mms3_mec_v_gse2000
# 792 : mms3_mec_quat_eci_to_gse2000
# 793 : mms3_mec_geod_lat
# 794 : mms3_mec_geod_lon
# 795 : mms3_mec_geod_height
# 796 : mms3_mec_r_sun_de421_eci
# 797 : mms3_mec_r_moon_de421_eci
# 798 : mms3_mec_fieldline_type
# 799 : mms3_mec_bsc_gsm
# 800 : mms3_mec_loss_cone_angle_s
# 801 : mms3_mec_loss_cone_angle_n
# 802 : mms3_mec_pfs_geod_latlon
# 803 : mms3_mec_pfn_geod_latlon
# 804 : mms3_mec_pfs_gsm
# 805 : mms3_mec_bfs_gsm
# 806 : mms3_mec_pfn_gsm
# 807 : mms3_mec_bfn_gsm
# 808 : mms3_mec_pmin_gsm
# 809 : mms3_mec_bmin_gsm
# 810 : mms4_mec_dipole_tilt
# 811 : mms4_mec_gmst
# 812 : mms4_mec_mlat
# 813 : mms4_mec_mlt
# 814 : mms4_mec_l_dipole
# 815 : mms4_mec_quat_eci_to_bcs
# 816 : mms4_mec_quat_eci_to_dbcs
# 817 : mms4_mec_quat_eci_to_dmpa
# 818 : mms4_mec_quat_eci_to_smpa
# 819 : mms4_mec_quat_eci_to_dsl
# 820 : mms4_mec_quat_eci_to_ssl
# 821 : mms4_mec_L_vec
# 822 : mms4_mec_Z_vec
# 823 : mms4_mec_P_vec
# 824 : mms4_mec_L_phase
# 825 : mms4_mec_Z_phase
# 826 : mms4_mec_P_phase
# 827 : mms4_mec_kp
# 828 : mms4_mec_dst
# 829 : mms4_mec_earth_eclipse_flag
# 830 : mms4_mec_moon_eclipse_flag
# 831 : mms4_mec_r_eci
# 832 : mms4_mec_v_eci
# 833 : mms4_mec_r_gsm
# 834 : mms4_mec_v_gsm
# 835 : mms4_mec_quat_eci_to_gsm
# 836 : mms4_mec_r_geo
# 837 : mms4_mec_v_geo
# 838 : mms4_mec_quat_eci_to_geo
# 839 : mms4_mec_r_sm
# 840 : mms4_mec_v_sm
# 841 : mms4_mec_quat_eci_to_sm
# 842 : mms4_mec_r_gse
# 843 : mms4_mec_v_gse
# 844 : mms4_mec_quat_eci_to_gse
# 845 : mms4_mec_r_gse2000
# 846 : mms4_mec_v_gse2000
# 847 : mms4_mec_quat_eci_to_gse2000
# 848 : mms4_mec_geod_lat
# 849 : mms4_mec_geod_lon
# 850 : mms4_mec_geod_height
# 851 : mms4_mec_r_sun_de421_eci
# 852 : mms4_mec_r_moon_de421_eci
# 853 : mms4_mec_fieldline_type
# 854 : mms4_mec_bsc_gsm
# 855 : mms4_mec_loss_cone_angle_s
# 856 : mms4_mec_loss_cone_angle_n
# 857 : mms4_mec_pfs_geod_latlon
# 858 : mms4_mec_pfn_geod_latlon
# 859 : mms4_mec_pfs_gsm
# 860 : mms4_mec_bfs_gsm
# 861 : mms4_mec_pfn_gsm
# 862 : mms4_mec_bfn_gsm
# 863 : mms4_mec_pmin_gsm
# 864 : mms4_mec_bmin_gsm
# 865 : mms1_defeph_pos-itrp
# 866 : mms1_defeph_pos_gse
# 867 : mms1_defeph_vel-itrp
# 868 : mms1_defeph_vel_gse
# 869 : mms2_defeph_pos-itrp
# 870 : mms2_defeph_pos_gse
# 871 : mms2_defeph_vel-itrp
# 872 : mms2_defeph_vel_gse
# 873 : mms3_defeph_pos-itrp
# 874 : mms3_defeph_pos_gse
# 875 : mms3_defeph_vel-itrp
# 876 : mms3_defeph_vel_gse
# 877 : mms4_defeph_pos-itrp
# 878 : mms4_defeph_pos_gse
# 879 : mms4_defeph_vel-itrp
# 880 : mms4_defeph_vel_gse
# 881 : mms1_defeph_pos_gse_tinterp
# 882 : mms1_mms2_dist
# 883 : mms1_mms3_dist
# 884 : mms1_mms4_dist
# 885 : mms2_defeph_pos_gse_tinterp
# 886 : mms2_mms3_dist
# 887 : mms1_mms2_dist_mag
# 888 : mms1_mms3_dist_mag
# 889 : mms1_mms4_dist_mag
# 890 : mms2_mms3_dist_mag
# 891 : mms1_defeph_vel_gse_mag
# 892 : mms1_defeph_pos_gse_df
# 893 : mms1_fgm_b_gse_brst_l2_df
# 894 : mms1_fgm_b_gse_brst_l2_sm
# 895 : mms2_defeph_pos_gse_df
# 896 : mms2_fgm_b_gse_brst_l2_df
# 897 : mms2_fgm_b_gse_brst_l2_sm
# 898 : mms3_defeph_pos_gse_df
# 899 : mms3_fgm_b_gse_brst_l2_df
# 900 : mms3_fgm_b_gse_brst_l2_sm
# 901 : mms4_defeph_pos_gse_df
# 902 : mms4_fgm_b_gse_brst_l2_df
# 903 : mms4_fgm_b_gse_brst_l2_sm
# 904 : f0_tc
# 905 : pos1_i
# 906 : pos2_i
# 907 : pos3_i
# 908 : pos4_i
# 909 : b1_i
# 910 : b2_i
# 911 : b3_i
# 912 : b4_i
# 913 : null_pos
# 914 : null_bary_dist
# 915 : null_type3
# 916 : null_type4
# 917 : null_type5
# 918 : null_type6
# 919 : null_type7
# 920 : null_type8
# 921 : null_type9
# 922 : null_type10
# 923 : null_bary_dist_types  data from:  null_bary_dist null_type3 null_type4 null_type5 null_type6 null_type7 null_type8 null_type9 null_type10
# 924 : null_sc_distances
# 925 : null_eta
# 926 : null_xi
# 927 : null_fom
# 928 : null_typecode
# 929 : max_reconstruction_error
# ['null_pos', 'null_bary_dist', 'null_bary_dist_types', 'null_sc_distances', 'null_fom', 'null_typecode', 'max_reconstruction_error']

# %% [markdown]
# The variables returned by find_magnetic_nulls_fote are:
#
# null_pos: The position of reported null points, in the same coordinate system as the position inputs (here, GSE)
#
# null_bary_dist:  The scalar distance between the null and the consteallation barycenter
#
# null_bary_dist_types:  A composite tplot variable with a scatter plot of null topology types, superimposed on the null_bary_dist values
#
# null_sc_distances: The scalar distances between the null point and each of the four spacecraft.
#
# null_fom:  Two scalar figures of merit, eta and xi, representing the confidence in the null detection and null topology classification
#
# null_typecode: Integer type codes representing the topological classification of the null points.
#
# max_reconstruction_error:  The maximum difference, in nT, between the spacecraft magnetic field measurements, and the Taylor expansion of the field using the calculated field value and field gradients at the constellation barycenter.
#
# It's hard to make sense of the plots of magnetic null results on timescales longer than a few seconds, so we'll want to zoom in on some shorter time intervals.,
#
# First, we'll look at 60 seconds worth of data starting at 07:01:

# %%
timespan('2023-03-24/07:01:00',60,'seconds')
options('null_fom','yrange',[0.0,0.5])
tplot(['mms1_fgm_b_gse_brst_l2','mms2_fgm_b_gse_brst_l2','mms3_fgm_b_gse_brst_l2','mms4_fgm_b_gse_brst_l2','null_sc_distances','null_bary_dist_types','null_fom'])

# %% [markdown]
# Just after 07:01:40, all four spacecraft are seeing low fields, so let's zoom in on that:

# %%
timespan('2023-03-24/07:01:40',10,'seconds')
options('null_fom','yrange',[0.0,1.0])
options('null_sc_distances','yrange',[0.0, 100.0])
options('null_bary_dist','yrange',[0.0,100.0])
tplot(['mms1_fgm_b_gse_brst_l2','mms2_fgm_b_gse_brst_l2','mms3_fgm_b_gse_brst_l2','mms4_fgm_b_gse_brst_l2','null_sc_distances','null_bary_dist','null_bary_dist_types','null_fom'])

# %% [markdown]
# Looking at the quality variables (lower=better), and null_sc and null_barycenter distances, it appears that several magnetic nulls were reliably detected and classified, perhaps even enclosed by the MMS tetrahedron, around 41-42 and 46 seconds after 07:01 UT.

# %% [markdown]
# Now we'll look at another time interval starting at 07:07:00:

# %%
timespan('2023-03-24/07:07:00',60,'seconds')
options('null_fom','yrange',[0.0,0.5])
options('null_sc_distances','yrange',[0.0, 1000.0])
options('null_bary_dist','yrange',[0.0,1000.0])
tplot(['null_sc_distances','null_bary_dist_types','null_fom'])

# %% [markdown]
# Now we'll look at the time interval 07:07:20 - 07:07:25:

# %%
timespan('2023-03-24/07:07:20',5,'seconds')
tplot(['null_sc_distances','null_bary_dist_types','null_fom'])
# Out:
# 28-Dec-24 20:12:43: No data found in the time range: null_type8

# %% [markdown]
# Between 21-15 seconds after 7:07, we seem to have a reliable detection of a Type A radial null at a distance of about 500 km from the formation.  This coincides with the magnetic reconnection signature observed in MMS-1 at this time: anti-parallel magnetic field lines, fast ion flows and flow reversals.

# %% [markdown]
# # Cloud Catalog Demo
#
# - https://github.com/heliocloud-data/science-tutorials/blob/main/CloudCatalog-Demo.ipynb
# - https://github.com/heliocloud-data/cloudcatalog

# %% [markdown]
# The cloudcatalog standard enables any Python script that can see AWS to access the Petabytes of data stored in the GSFC, APL and other HelioCloud data repositories. Both data from the NASA public and TOPS (Transform to Open Science) AWS data stores and data that other HelioClouds have made public are equally accessible via this interface. Currently cloudcatalog lets you access datasets you are aware of, or walk through the public listing of available datasets. Search and improved findability are expected future features.

# %% [markdown]
# ## Setup
# ```
# pip install cloudcatalog
# ```

# %%
import cloudcatalog
import cdflib
import matplotlib.pyplot as plt
from pprint import pprint

# %% [markdown]
# ## Searching for data with EntireCatalogSearch

# %%
search = cloudcatalog.EntireCatalogSearch()

# %%
search.search_by_id('mms1_feeps')
# Out:
# [{'id': 'mms1_feeps_brst_electron',
#   'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/feeps/brst/l2/electron/',
#   'title': 'mms1/feeps/brst/l2/electron/',
#   'start': '2015-06-01T00:00.00Z',
#   'stop': '2023-09-30T23:59.00Z',
#   'modification': '2024-02-28T17:10.00Z',
#   'indextype': 'csv',
#   'filetype': 'cdf',
#   'description': 'Optional description for dataset',
#   'resourceID': 'optional identifier e.g. SPASE ID',
#   'creationDate': 'optional ISO 8601 date/time of the dataset creation',
#   'citation': 'optional how to cite this dataset, DOI or similar',
#   'contact': 'optional contact info, SPASE ID, email, or ORCID',
#   'aboutURL': 'optional website URL for info, team, etc'},
#  {'id': 'mms1_feeps_brst_ion',
#   'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/feeps/brst/l2/ion/',
#   'title': 'mms1/feeps/brst/l2/ion/',
#   'start': '2015-06-01T00:00.00Z',
#   'stop': '2023-09-30T23:59.00Z',
#   'modification': '2024-02-28T17:10.00Z',
#   'indextype': 'csv',
#   'filetype': 'cdf'},
#  {'id': 'mms1_feeps_srvy_electron',
#   'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/feeps/srvy/l2/electron/',
#   'title': 'mms1/feeps/srvy/l2/electron/',
#   'start': '2015-06-01T00:00.00Z',
#   'stop': '2023-09-30T23:59.00Z',
#   'modification': '2024-02-28T17:10.00Z',
#   'indextype': 'csv',
#   'filetype': 'cdf'},
#  {'id': 'mms1_feeps_srvy_ion',
#   'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/feeps/srvy/l2/ion/',
#   'title': 'mms1/feeps/srvy/l2/ion/',
#   'start': '2015-06-01T00:00.00Z',
#   'stop': '2023-09-30T23:59.00Z',
#   'modification': '2024-02-28T17:10.00Z',
#   'indextype': 'csv',
#   'filetype': 'cdf'},
#  {'id': 'MMS1_FEEPS_BRST_L2_ELECTRON',
#   'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/data/mms/indices/',
#   'title': 'Level 2 Flys Eye Energetic Particle Sensor Burst Data - STP (LASP)',
#   'start': '2015-09-01T00:00:00.000Z',
#   'stop': '2024-08-22T23:59:59.000Z',
#   'indextype': 'csv',
#   'filetype': 'CDF',
#   'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_FEEPS_BRST_L2_ELECTRON',
#   'contact': 'STP',
#   'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_FEEPS_BRST_L2_ELECTRON',
#   'collections': ['CDAWeb', 'MMS']},
#  {'id': 'MMS1_FEEPS_BRST_L2_ION',
#   'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/data/mms/indices/',
#   'title': 'Level 2 Flys Eye Energetic Particle Sensor Burst Data - STP (LASP)',
#   'start': '2015-09-01T00:00:00.000Z',
#   'stop': '2024-08-22T23:59:59.000Z',
#   'indextype': 'csv',
#   'filetype': 'CDF',
#   'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_FEEPS_BRST_L2_ION',
#   'contact': 'STP',
#   'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_FEEPS_BRST_L2_ION',
#   'collections': ['CDAWeb', 'MMS']},
#  {'id': 'MMS1_FEEPS_SRVY_L2_ELECTRON',
#   'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/data/mms/indices/',
#   'title': 'Level 2 Flys Eye Energetic Particle Sensor Survey Data - STP (LASP)',
#   'start': '2015-09-01T00:00:00.000Z',
#   'stop': '2024-08-22T23:59:59.000Z',
#   'indextype': 'csv',
#   'filetype': 'CDF',
#   'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_FEEPS_SRVY_L2_ELECTRON',
#   'contact': 'STP',
#   'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_FEEPS_SRVY_L2_ELECTRON',
#   'collections': ['CDAWeb', 'MMS']},
#  {'id': 'MMS1_FEEPS_SRVY_L2_ION',
#   'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/data/mms/indices/',
#   'title': 'Level 2 Flys Eye Energetic Particle Sensor Survey Data - STP (LASP)',
#   'start': '2015-09-01T00:00:00.000Z',
#   'stop': '2024-08-22T23:59:59.000Z',
#   'indextype': 'csv',
#   'filetype': 'CDF',
#   'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_FEEPS_SRVY_L2_ION',
#   'contact': 'STP',
#   'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_FEEPS_SRVY_L2_ION',
#   'collections': ['CDAWeb', 'MMS']}]

# %%
search.search_by_id('srvy_ion')
# Out:
# [{'id': 'mms1_feeps_srvy_ion',
#   'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/feeps/srvy/l2/ion/',
#   'title': 'mms1/feeps/srvy/l2/ion/',
#   'start': '2015-06-01T00:00.00Z',
#   'stop': '2023-09-30T23:59.00Z',
#   'modification': '2024-02-28T17:10.00Z',
#   'indextype': 'csv',
#   'filetype': 'cdf'},
#  {'id': 'mms2_feeps_srvy_ion',
#   'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms2/feeps/srvy/l2/ion/',
#   'title': 'mms2/feeps/srvy/l2/ion/',
#   'start': '2015-06-01T00:00.00Z',
#   'stop': '2023-09-30T23:59.00Z',
#   'modification': '2024-02-28T17:10.00Z',
#   'indextype': 'csv',
#   'filetype': 'cdf'},
#  {'id': 'mms3_feeps_srvy_ion',
#   'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms3/feeps/srvy/l2/ion/',
#   'title': 'mms3/feeps/srvy/l2/ion/',
#   'start': '2015-06-01T00:00.00Z',
#   'stop': '2023-09-30T23:59.00Z',
#   'modification': '2024-02-28T17:10.00Z',
#   'indextype': 'csv',
#   'filetype': 'cdf'},
#  {'id': 'mms4_feeps_srvy_ion',
#   'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms4/feeps/srvy/l2/ion/',
#   'title': 'mms4/feeps/srvy/l2/ion/',
#   'start': '2015-06-01T00:00.00Z',
#   'stop': '2023-09-30T23:59.00Z',
#   'modification': '2024-02-28T17:10.00Z',
#   'indextype': 'csv',
#   'filetype': 'cdf'}]

# %%
search.search_by_title('mms1/fpi/b')
# Out:
# [{'id': 'mms1_fpi_brst_des-dist',
#   'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/fpi/brst/l2/des-dist/',
#   'title': 'mms1/fpi/brst/l2/des-dist/',
#   'start': '2015-06-01T00:00.00Z',
#   'stop': '2023-09-30T23:59.00Z',
#   'modification': '2024-02-28T17:10.00Z',
#   'indextype': 'csv',
#   'filetype': 'cdf'},
#  {'id': 'mms1_fpi_brst_des-moms',
#   'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/fpi/brst/l2/des-moms/',
#   'title': 'mms1/fpi/brst/l2/des-moms/',
#   'start': '2015-06-01T00:00.00Z',
#   'stop': '2023-09-30T23:59.00Z',
#   'modification': '2024-02-28T17:10.00Z',
#   'indextype': 'csv',
#   'filetype': 'cdf'},
#  {'id': 'mms1_fpi_brst_dis-dist',
#   'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/fpi/brst/l2/dis-dist/',
#   'title': 'mms1/fpi/brst/l2/dis-dist/',
#   'start': '2015-06-01T00:00.00Z',
#   'stop': '2023-09-30T23:59.00Z',
#   'modification': '2024-02-28T17:10.00Z',
#   'indextype': 'csv',
#   'filetype': 'cdf'},
#  {'id': 'mms1_fpi_brst_dis-moms',
#   'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/fpi/brst/l2/dis-moms/',
#   'title': 'mms1/fpi/brst/l2/dis-moms/',
#   'start': '2015-06-01T00:00.00Z',
#   'stop': '2023-09-30T23:59.00Z',
#   'modification': '2024-02-28T17:10.00Z',
#   'indextype': 'csv',
#   'filetype': 'cdf'}]

# %%
search.search_by_title('des-dist')[:2]
# Out:
# [{'id': 'mms1_fpi_brst_des-dist',
#   'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/fpi/brst/l2/des-dist/',
#   'title': 'mms1/fpi/brst/l2/des-dist/',
#   'start': '2015-06-01T00:00.00Z',
#   'stop': '2023-09-30T23:59.00Z',
#   'modification': '2024-02-28T17:10.00Z',
#   'indextype': 'csv',
#   'filetype': 'cdf'},
#  {'id': 'mms1_fpi_fast_des-dist',
#   'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/fpi/fast/l2/des-dist/',
#   'title': 'mms1/fpi/fast/l2/des-dist/',
#   'start': '2015-06-01T00:00.00Z',
#   'stop': '2023-09-30T23:59.00Z',
#   'modification': '2024-02-28T17:10.00Z',
#   'indextype': 'csv',
#   'filetype': 'cdf'}]

# %%
search.search_by_keywords(['mms2', 'brst', 'apples'])[:3]
# Out:
# [{'id': 'mms2_feeps_brst_electron',
#   'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms2/feeps/brst/l2/electron/',
#   'title': 'mms2/feeps/brst/l2/electron/',
#   'start': '2015-06-01T00:00.00Z',
#   'stop': '2023-09-30T23:59.00Z',
#   'modification': '2024-02-28T17:10.00Z',
#   'indextype': 'csv',
#   'filetype': 'cdf'},
#  {'id': 'mms2_feeps_brst_ion',
#   'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms2/feeps/brst/l2/ion/',
#   'title': 'mms2/feeps/brst/l2/ion/',
#   'start': '2015-06-01T00:00.00Z',
#   'stop': '2023-09-30T23:59.00Z',
#   'modification': '2024-02-28T17:10.00Z',
#   'indextype': 'csv',
#   'filetype': 'cdf'},
#  {'id': 'mms2_fgm_brst',
#   'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms2/fgm/brst/l2/',
#   'title': 'mms2/fgm/brst/l2/',
#   'start': '2015-06-01T00:00.00Z',
#   'stop': '2023-09-30T23:59.00Z',
#   'modification': '2024-02-28T17:10.00Z',
#   'indextype': 'csv',
#   'filetype': 'cdf'}]

# %% [markdown]
# ## Working with the global catalog (..the name)

# %%
cr = cloudcatalog.CatalogRegistry()

# %%
cr.get_catalog()
# Out:
# {'version': '0.4',
#  'modification': '2022-01-01T00:00Z',
#  'registry': [{'endpoint': 's3://gov-nasa-hdrl-data1/',
#    'name': 'HelioCloud, including SDO',
#    'region': 'us-east-1'}]}

# %%
cr.get_registry()
# Out:
# [{'endpoint': 's3://gov-nasa-hdrl-data1/',
#   'name': 'HelioCloud, including SDO',
#   'region': 'us-east-1'}]

# %%
cr.get_entries()
# Out:
# {'endpoint': 's3://gov-nasa-hdrl-data1/',
#  'name': 'HelioCloud, including SDO',
#  'region': 'us-east-1'}

# %%
endpoint = cr.get_endpoint('HelioCloud, including SDO')
endpoint
# Out:
# 's3://gov-nasa-hdrl-data1/'

# %%
cr.catalog
# Out:
# {'version': '0.4',
#  'modification': '2022-01-01T00:00Z',
#  'registry': [{'endpoint': 's3://gov-nasa-hdrl-data1/',
#    'name': 'HelioCloud, including SDO',
#    'region': 'us-east-1'}]}

# %% [markdown]
# ## Working with a local catalog

# %%
fr = cloudcatalog.CloudCatalog(endpoint, cache=False)

# %%
fr.get_catalog()
# Out:
# {'Cloudy': '0.6',
#  'endpoint': 's3://gov-nasa-hdrl-data1/',
#  'name': 'GSFC HelioCloud',
#  'contact': 'Brian Thomas, brian.a.thomas@nasa.gov',
#  'description': 'NASA TOPS ODR datasets',
#  'citation': 'tbd',
#  'catalog': [{'id': 'aia_0094',
#    'title': 'AIA 0094 FITS data',
#    'index': 's3://gov-nasa-hdrl-data1/sdo/aia/registries/',
#    'start': '2010-05-13T00:00:00Z',
#    'stop': '2022-12-31T23:56:00Z',
#    'modification': '2023-05-04T00:00:00Z',
#    'indextype': 'csv',
#    'filetype': 'fits'},
#   {'id': 'aia_0131',
#    'index': 's3://gov-nasa-hdrl-data1/sdo/aia/registries/',
#    'title': 'AIA 0131 FITS data',
#    'start': '2015-06-01T00:00:00Z',
#    'stop': '2021-12-31T23:59:59Z',
#    'modification': '2023-05-04:00:00:00Z',
#    'indextype': 'csv',
#    'filetype': 'fits'},
#   {'id': 'aia_0171',
#    'index': 's3://gov-nasa-hdrl-data1/sdo/aia/registries/',
#    'title': 'AIA 0171 FITS data',
#    'start': '2015-06-01T00:00:00Z',
#    'stop': '2021-12-31T23:59:59Z',
#    'modification': '2023-05-04:00:00:00Z',
#    'indextype': 'csv',
#    'filetype': 'fits'},
#   {'id': 'aia_0193',
#    'index': 's3://gov-nasa-hdrl-data1/sdo/aia/registries/',
#    'title': 'AIA 0193 FITS data',
#    'start': '2015-06-01T00:00:00Z',
#    'stop': '2021-12-31T23:59:59Z',
#    'modification': '2023-05-04:00:00:00Z',
#    'indextype': 'csv',
#    'filetype': 'fits'},
#   {'id': 'aia_0211',
#    'index': 's3://gov-nasa-hdrl-data1/sdo/aia/registries/',
#    'title': 'AIA 0211 FITS data',
#    'start': '2015-06-01T00:00:00Z',
#    'stop': '2021-12-31T23:59:59Z',
#    'modification': '2023-05-04:00:00:00Z',
#    'indextype': 'csv',
#    'filetype': 'fits'},
#   {'id': 'aia_0304',
#    'index': 's3://gov-nasa-hdrl-data1/sdo/aia/registries/',
#    'title': 'AIA 0304 FITS data',
#    'start': '2015-06-01T00:00:00Z',
#    'stop': '2021-12-31T23:59:59Z',
#    'modification': '2023-05-04:00:00:00Z',
#    'indextype': 'csv',
#    'filetype': 'fits'},
#   {'id': 'aia_0335',
#    'index': 's3://gov-nasa-hdrl-data1/sdo/aia/registries/',
#    'title': 'AIA 0335 FITS data',
#    'start': '2015-06-01T00:00:00Z',
#    'stop': '2021-12-31T23:59:59Z',
#    'modification': '2023-05-04:00:00:00Z',
#    'indextype': 'csv',
#    'filetype': 'fits'},
#   {'id': 'aia_1600',
#    'index': 's3://gov-nasa-hdrl-data1/sdo/aia/registries/',
#    'title': 'AIA 1600 FITS data',
#    'start': '2015-06-01T00:00:00Z',
#    'stop': '2021-12-31T23:59:59Z',
#    'modification': '2023-05-04:00:00:00Z',
#    'indextype': 'csv',
#    'filetype': 'fits'},
#   {'id': 'aia_1700',
#    'index': 's3://gov-nasa-hdrl-data1/sdo/aia/registries/',
#    'title': 'AIA 1700 FITS data',
#    'start': '2015-06-01T00:00:00Z',
#    'stop': '2021-12-31T23:59:59Z',
#    'modification': '2023-05-04:00:00:00Z',
#    'indextype': 'csv',
#    'filetype': 'fits'},
#   {'id': 'LatLonVMu',
#    'index': 's3://gov-nasa-hdrl-data1/sdo/ancillary/registries/',
#    'title': 'LatLonVMu FITS data',
#    'start': '2015-06-01T00:00:00Z',
#    'stop': '2021-12-31T23:59:59Z',
#    'modification': '2023-05-04:00:00:00Z',
#    'indextype': 'csv',
#    'filetype': 'fits'},
#   {'id': 'hmi_B',
#    'index': 's3://gov-nasa-hdrl-data1/sdo/hmi/registries/',
#    'title': 'HMI B FITS data',
#    'start': '2015-06-01T00:00:00Z',
#    'stop': '2021-12-31T23:59:59Z',
#    'modification': '2023-05-04:00:00:00Z',
#    'indextype': 'csv',
#    'filetype': 'fits'},
#   {'id': 'hmi_Ic',
#    'index': 's3://gov-nasa-hdrl-data1/sdo/hmi/registries/',
#    'title': 'HMI Ic FITS data',
#    'start': '2015-06-01T00:00:00Z',
#    'stop': '2021-12-31T23:59:59Z',
#    'modification': '2023-05-04:00:00:00Z',
#    'indextype': 'csv',
#    'filetype': 'fits'},
#   {'id': 'hmi_Ic_noLimbDark',
#    'index': 's3://gov-nasa-hdrl-data1/sdo/hmi/registries/',
#    'title': 'HMI Ic_noLimbDark FITS data',
#    'start': '2015-06-01T00:00:00Z',
#    'stop': '2021-12-31T23:59:59Z',
#    'modification': '2023-05-04:00:00:00Z',
#    'indextype': 'csv',
#    'filetype': 'fits'},
#   {'id': 'hmi_M',
#    'index': 's3://gov-nasa-hdrl-data1/sdo/hmi/registries/',
#    'title': 'HMI M FITS data',
#    'start': '2015-06-01T00:00:00Z',
#    'stop': '2021-12-31T23:59:59Z',
#    'modification': '2023-05-04:00:00:00Z',
#    'indextype': 'csv',
#    'filetype': 'fits'},
#   {'id': 'hmi_V',
#    'index': 's3://gov-nasa-hdrl-data1/sdo/hmi/registries/',
#    'title': 'HMI V FITS data',
#    'start': '2015-06-01T00:00:00Z',
#    'stop': '2021-12-31T23:59:59Z',
#    'modification': '2023-05-04:00:00:00Z',
#    'indextype': 'csv',
#    'filetype': 'fits'},
#   {'id': 'euvml',
#    'index': 's3://gov-nasa-hdrl-data1/contrib/euvml/registries/',
#    'title': 'EUV-ML dataset',
#    'start': '1996-01-01T00:00.00Z',
#    'stop': '2021-12-31T00:00.00Z',
#    'modification': '2024-06-03T00:00.00Z',
#    'indextype': 'csv',
#    'filetype': 'fits',
#    'description': 'EUVML set of STEREO/EUVI and SOHO/EIT 512x512 unified ML-ready FITS images',
#    'resource': 'DOI tbd',
#    'creation': '2023-11-01T00:00.00Z',
#    'citation': 'tbd',
#    'contact': 'JHUAPL.edu',
#    'about': 'optional website URL for info, team, etc'},
#   {'id': 'euvml_soho',
#    'index': 's3://gov-nasa-hdrl-data1/contrib/euvml/registries/',
#    'title': 'EUV-ML dataset, SOHO-only',
#    'start': '1996-01-01T00:00.00Z',
#    'stop': '2020-12-31T00:00.00Z',
#    'modification': '2024-06-03T00:00.00Z',
#    'indextype': 'csv',
#    'filetype': 'fits',
#    'description': 'EUVML set of SOHO/EIT 512x512 unified ML-ready FITS images',
#    'resource': 'DOI tbd',
#    'creation': '2023-11-01T00:00.00Z',
#    'citation': 'tbd',
#    'contact': 'JHUAPL.edu',
#    'about': 'optional website URL for info, team, etc'},
#   {'id': 'euvml_stereoa',
#    'index': 's3://gov-nasa-hdrl-data1/contrib/euvml/registries/',
#    'title': 'EUV-ML dataset, STEREO-A only',
#    'start': '2007-01-01T00:00.00Z',
#    'stop': '2021-12-31T00:00.00Z',
#    'modification': '2024-06-03T00:00.00Z',
#    'indextype': 'csv',
#    'filetype': 'fits',
#    'description': 'EUVML set of STEREO-A/EUVI 512x512 unified ML-ready FITS images',
#    'resource': 'DOI tbd',
#    'creation': '2023-11-01T00:00.00Z',
#    'citation': 'tbd',
#    'contact': 'JHUAPL.edu',
#    'about': 'optional website URL for info, team, etc'},
#   {'id': 'euvml_stereob',
#    'index': 's3://gov-nasa-hdrl-data1/contrib/euvml/registries/',
#    'title': 'EUV-ML dataset, STEREO-B only',
#    'start': '2008-01-01T00:00.00Z',
#    'stop': '2014-12-31T00:00.00Z',
#    'modification': '2024-06-03T00:00.00Z',
#    'indextype': 'csv',
#    'filetype': 'fits',
#    'description': 'EUVML set of STEREO-B/EUVI 512x512 unified ML-ready FITS images',
#    'resource': 'DOI tbd',
#    'creation': '2023-11-01T00:00.00Z',
#    'citation': 'tbd',
#    'contact': 'JHUAPL.edu',
#    'about': 'optional website URL for info, team, etc'},
#   {'id': 'euvml_171',
#    'index': 's3://gov-nasa-hdrl-data1/contrib/euvml/registries/',
#    'title': 'EUV-ML 171A dataset',
#    'start': '1996-01-01T00:00.00Z',
#    'stop': '2021-12-31T00:00.00Z',
#    'modification': '2024-06-03T00:00.00Z',
#    'indextype': 'csv',
#    'filetype': 'fits',
#    'description': 'EUVML set of STEREO/EUVI and SOHO/EIT 512x512 unified ML-ready FITS images, 171A only',
#    'resource': 'DOI tbd',
#    'creation': '2023-11-01T00:00.00Z',
#    'citation': 'tbd',
#    'contact': 'JHUAPL.edu',
#    'about': 'optional website URL for info, team, etc'},
#   {'id': 'euvml_195',
#    'index': 's3://gov-nasa-hdrl-data1/contrib/euvml/registries/',
#    'title': 'EUV-ML 195A dataset',
#    'start': '1996-01-01T00:00.00Z',
#    'stop': '2021-12-31T00:00.00Z',
#    'modification': '2024-06-03T00:00.00Z',
#    'indextype': 'csv',
#    'filetype': 'fits',
#    'description': 'EUVML set of STEREO/EUVI and SOHO/EIT 512x512 unified ML-ready FITS images, 195A only',
#    'resource': 'DOI tbd',
#    'creation': '2023-11-01T00:00.00Z',
#    'citation': 'tbd',
#    'contact': 'JHUAPL.edu',
#    'about': 'optional website URL for info, team, etc'},
#   {'id': 'euvml_284',
#    'index': 's3://gov-nasa-hdrl-data1/contrib/euvml/registries/',
#    'title': 'EUV-ML 284A dataset',
#    'start': '1996-01-01T00:00.00Z',
#    'stop': '2021-12-31T00:00.00Z',
#    'modification': '2024-06-03T00:00.00Z',
#    'indextype': 'csv',
#    'filetype': 'fits',
#    'description': 'EUVML set of STEREO/EUVI and SOHO/EIT 512x512 unified ML-ready FITS images, 284A only',
#    'resource': 'DOI tbd',
#    'creation': '2023-11-01T00:00.00Z',
#    'citation': 'tbd',
#    'contact': 'JHUAPL.edu',
#    'about': 'optional website URL for info, team, etc'},
#   {'id': 'euvml_304',
#    'index': 's3://gov-nasa-hdrl-data1/contrib/euvml/registries/',
#    'title': 'EUV-ML 304A dataset',
#    'start': '1996-01-01T00:00.00Z',
#    'stop': '2021-12-31T00:00.00Z',
#    'modification': '2024-06-03T00:00.00Z',
#    'indextype': 'csv',
#    'filetype': 'fits',
#    'description': 'EUVML set of STEREO/EUVI and SOHO/EIT 512x512 unified ML-ready FITS images, 304A only',
#    'resource': 'DOI tbd',
#    'creation': '2023-11-01T00:00.00Z',
#    'citation': 'tbd',
#    'contact': 'JHUAPL.edu',
#    'about': 'optional website URL for info, team, etc'},
#   {'id': 'euvml_soho_171',
#    'index': 's3://gov-nasa-hdrl-data1/contrib/euvml/registries/',
#    'title': 'EUV-ML 171A dataset, SOHO-only',
#    'start': '1996-01-01T00:00.00Z',
#    'stop': '2020-12-31T00:00.00Z',
#    'modification': '2024-06-03T00:00.00Z',
#    'indextype': 'csv',
#    'filetype': 'fits',
#    'description': 'EUVML set of SOHO/EIT 512x512 unified ML-ready FITS images, 171A only',
#    'resource': 'DOI tbd',
#    'creation': '2023-11-01T00:00.00Z',
#    'citation': 'tbd',
#    'contact': 'JHUAPL.edu',
#    'about': 'optional website URL for info, team, etc'},
#   {'id': 'euvml_soho_194',
#    'index': 's3://gov-nasa-hdrl-data1/contrib/euvml/registries/',
#    'title': 'EUV-ML 194A dataset, SOHO-only',
#    'start': '1996-01-01T00:00.00Z',
#    'stop': '2020-12-31T00:00.00Z',
#    'modification': '2024-06-03T00:00.00Z',
#    'indextype': 'csv',
#    'filetype': 'fits',
#    'description': 'EUVML set of SOHO/EIT 512x512 unified ML-ready FITS images, 194A only',
#    'resource': 'DOI tbd',
#    'creation': '2023-11-01T00:00.00Z',
#    'citation': 'tbd',
#    'contact': 'JHUAPL.edu',
#    'about': 'optional website URL for info, team, etc'},
#   {'id': 'euvml_soho_284',
#    'index': 's3://gov-nasa-hdrl-data1/contrib/euvml/registries/',
#    'title': 'EUV-ML 284A dataset, SOHO-only',
#    'start': '1996-01-01T00:00.00Z',
#    'stop': '2020-12-31T00:00.00Z',
#    'modification': '2024-06-03T00:00.00Z',
#    'indextype': 'csv',
#    'filetype': 'fits',
#    'description': 'EUVML set of SOHO/EIT 512x512 unified ML-ready FITS images, 284A only',
#    'resource': 'DOI tbd',
#    'creation': '2023-11-01T00:00.00Z',
#    'citation': 'tbd',
#    'contact': 'JHUAPL.edu',
#    'about': 'optional website URL for info, team, etc'},
#   {'id': 'euvml_soho_304',
#    'index': 's3://gov-nasa-hdrl-data1/contrib/euvml/registries/',
#    'title': 'EUV-ML 304A dataset, SOHO-only',
#    'start': '1996-01-01T00:00.00Z',
#    'stop': '2020-12-31T00:00.00Z',
#    'modification': '2024-06-03T00:00.00Z',
#    'indextype': 'csv',
#    'filetype': 'fits',
#    'description': 'EUVML set of SOHO/EIT 512x512 unified ML-ready FITS images, 304A only',
#    'resource': 'DOI tbd',
#    'creation': '2023-11-01T00:00.00Z',
#    'citation': 'tbd',
#    'contact': 'JHUAPL.edu',
#    'about': 'optional website URL for info, team, etc'},
#   {'id': 'euvml_stereoa_171',
#    'index': 's3://gov-nasa-hdrl-data1/contrib/euvml/registries/',
#    'title': 'EUV-ML 171A dataset, STEREO-A only',
#    'start': '2007-01-01T00:00.00Z',
#    'stop': '2021-12-31T00:00.00Z',
#    'modification': '2024-06-03T00:00.00Z',
#    'indextype': 'csv',
#    'filetype': 'fits',
#    'description': 'EUVML set of STEREO-A/EUVI 512x512 unified ML-ready FITS images, 171A only',
#    'resource': 'DOI tbd',
#    'creation': '2023-11-01T00:00.00Z',
#    'citation': 'tbd',
#    'contact': 'JHUAPL.edu',
#    'about': 'optional website URL for info, team, etc'},
#   {'id': 'euvml_stereoa_194',
#    'index': 's3://gov-nasa-hdrl-data1/contrib/euvml/registries/',
#    'title': 'EUV-ML 194A dataset, STEREO-A only',
#    'start': '2007-01-01T00:00.00Z',
#    'stop': '2021-12-31T00:00.00Z',
#    'modification': '2024-06-03T00:00.00Z',
#    'indextype': 'csv',
#    'filetype': 'fits',
#    'description': 'EUVML set of STEREO-A/EUVI 512x512 unified ML-ready FITS images, 194A only',
#    'resource': 'DOI tbd',
#    'creation': '2023-11-01T00:00.00Z',
#    'citation': 'tbd',
#    'contact': 'JHUAPL.edu',
#    'about': 'optional website URL for info, team, etc'},
#   {'id': 'euvml_stereoa_284',
#    'index': 's3://gov-nasa-hdrl-data1/contrib/euvml/registries/',
#    'title': 'EUV-ML 284A dataset, STEREO-A only',
#    'start': '2007-01-01T00:00.00Z',
#    'stop': '2021-12-31T00:00.00Z',
#    'modification': '2024-06-03T00:00.00Z',
#    'indextype': 'csv',
#    'filetype': 'fits',
#    'description': 'EUVML set of STEREO-A/EUVI 512x512 unified ML-ready FITS images, 284A only',
#    'resource': 'DOI tbd',
#    'creation': '2023-11-01T00:00.00Z',
#    'citation': 'tbd',
#    'contact': 'JHUAPL.edu',
#    'about': 'optional website URL for info, team, etc'},
#   {'id': 'euvml_stereoa_304',
#    'index': 's3://gov-nasa-hdrl-data1/contrib/euvml/registries/',
#    'title': 'EUV-ML 304A dataset, STEREO-A only',
#    'start': '2007-01-01T00:00.00Z',
#    'stop': '2021-12-31T00:00.00Z',
#    'modification': '2024-06-03T00:00.00Z',
#    'indextype': 'csv',
#    'filetype': 'fits',
#    'description': 'EUVML set of STEREO-A/EUVI 512x512 unified ML-ready FITS images, 304A only',
#    'resource': 'DOI tbd',
#    'creation': '2023-11-01T00:00.00Z',
#    'citation': 'tbd',
#    'contact': 'JHUAPL.edu',
#    'about': 'optional website URL for info, team, etc'},
#   {'id': 'euvml_stereob_171',
#    'index': 's3://gov-nasa-hdrl-data1/contrib/euvml/registries/',
#    'title': 'EUV-ML 171A dataset, STEREO-B only',
#    'start': '2008-01-01T00:00.00Z',
#    'stop': '2014-12-31T00:00.00Z',
#    'modification': '2024-06-03T00:00.00Z',
#    'indextype': 'csv',
#    'filetype': 'fits',
#    'description': 'EUVML set of STEREO-B/EUVI 512x512 unified ML-ready FITS images, 171A only',
#    'resource': 'DOI tbd',
#    'creation': '2023-11-01T00:00.00Z',
#    'citation': 'tbd',
#    'contact': 'JHUAPL.edu',
#    'about': 'optional website URL for info, team, etc'},
#   {'id': 'euvml_stereob_194',
#    'index': 's3://gov-nasa-hdrl-data1/contrib/euvml/registries/',
#    'title': 'EUV-ML 194A dataset, STEREO-B only',
#    'start': '2008-01-01T00:00.00Z',
#    'stop': '2014-12-31T00:00.00Z',
#    'modification': '2024-06-03T00:00.00Z',
#    'indextype': 'csv',
#    'filetype': 'fits',
#    'description': 'EUVML set of STEREO-B/EUVI 512x512 unified ML-ready FITS images, 194A only',
#    'resource': 'DOI tbd',
#    'creation': '2023-11-01T00:00.00Z',
#    'citation': 'tbd',
#    'contact': 'JHUAPL.edu',
#    'about': 'optional website URL for info, team, etc'},
#   {'id': 'euvml_stereob_284',
#    'index': 's3://gov-nasa-hdrl-data1/contrib/euvml/registries/',
#    'title': 'EUV-ML 284A dataset, STEREO-B only',
#    'start': '2008-01-01T00:00.00Z',
#    'stop': '2014-12-31T00:00.00Z',
#    'modification': '2024-06-03T00:00.00Z',
#    'indextype': 'csv',
#    'filetype': 'fits',
#    'description': 'EUVML set of STEREO-B/EUVI 512x512 unified ML-ready FITS images, 284A only',
#    'resource': 'DOI tbd',
#    'creation': '2023-11-01T00:00.00Z',
#    'citation': 'tbd',
#    'contact': 'JHUAPL.edu',
#    'about': 'optional website URL for info, team, etc'},
#   {'id': 'euvml_stereob_304',
#    'index': 's3://gov-nasa-hdrl-data1/contrib/euvml/registries/',
#    'title': 'EUV-ML 304A dataset, STEREO-B only',
#    'start': '2008-01-01T00:00.00Z',
#    'stop': '2014-12-31T00:00.00Z',
#    'modification': '2024-06-03T00:00.00Z',
#    'indextype': 'csv',
#    'filetype': 'fits',
#    'description': 'EUVML set of STEREO-B/EUVI 512x512 unified ML-ready FITS images, 304A only',
#    'resource': 'DOI tbd',
#    'creation': '2023-11-01T00:00.00Z',
#    'citation': 'tbd',
#    'contact': 'JHUAPL.edu',
#    'about': 'optional website URL for info, team, etc'},
#   {'id': 'mms1_feeps_brst_electron',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/feeps/brst/l2/electron/',
#    'title': 'mms1/feeps/brst/l2/electron/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf',
#    'description': 'Optional description for dataset',
#    'resourceID': 'optional identifier e.g. SPASE ID',
#    'creationDate': 'optional ISO 8601 date/time of the dataset creation',
#    'citation': 'optional how to cite this dataset, DOI or similar',
#    'contact': 'optional contact info, SPASE ID, email, or ORCID',
#    'aboutURL': 'optional website URL for info, team, etc'},
#   {'id': 'mms1_feeps_brst_ion',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/feeps/brst/l2/ion/',
#    'title': 'mms1/feeps/brst/l2/ion/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms1_feeps_srvy_electron',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/feeps/srvy/l2/electron/',
#    'title': 'mms1/feeps/srvy/l2/electron/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms1_feeps_srvy_ion',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/feeps/srvy/l2/ion/',
#    'title': 'mms1/feeps/srvy/l2/ion/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms1_fgm_brst',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/fgm/brst/l2/',
#    'title': 'mms1/fgm/brst/l2/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms1_fgm_srvy',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/fgm/srvy/l2/',
#    'title': 'mms1/fgm/srvy/l2/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms1_fpi_brst_des-dist',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/fpi/brst/l2/des-dist/',
#    'title': 'mms1/fpi/brst/l2/des-dist/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms1_fpi_brst_des-moms',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/fpi/brst/l2/des-moms/',
#    'title': 'mms1/fpi/brst/l2/des-moms/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms1_fpi_brst_dis-dist',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/fpi/brst/l2/dis-dist/',
#    'title': 'mms1/fpi/brst/l2/dis-dist/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms1_fpi_brst_dis-moms',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/fpi/brst/l2/dis-moms/',
#    'title': 'mms1/fpi/brst/l2/dis-moms/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms1_fpi_fast_des-dist',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/fpi/fast/l2/des-dist/',
#    'title': 'mms1/fpi/fast/l2/des-dist/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms1_fpi_fast_des-moms',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/fpi/fast/l2/des-moms/',
#    'title': 'mms1/fpi/fast/l2/des-moms/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms1_fpi_fast_dis-dist',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/fpi/fast/l2/dis-dist/',
#    'title': 'mms1/fpi/fast/l2/dis-dist/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms1_fpi_fast_dis-moms',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/fpi/fast/l2/dis-moms/',
#    'title': 'mms1/fpi/fast/l2/dis-moms/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms1_mec_brst_epht89d',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/mec/brst/l2/epht89d/',
#    'title': 'mms1/mec/brst/l2/epht89d/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms1_mec_srvy_epht89d',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/mec/srvy/l2/epht89d/',
#    'title': 'mms1/mec/srvy/l2/epht89d/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms2_feeps_brst_electron',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms2/feeps/brst/l2/electron/',
#    'title': 'mms2/feeps/brst/l2/electron/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms2_feeps_brst_ion',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms2/feeps/brst/l2/ion/',
#    'title': 'mms2/feeps/brst/l2/ion/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms2_feeps_srvy_electron',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms2/feeps/srvy/l2/electron/',
#    'title': 'mms2/feeps/srvy/l2/electron/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms2_feeps_srvy_ion',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms2/feeps/srvy/l2/ion/',
#    'title': 'mms2/feeps/srvy/l2/ion/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms2_fgm_brst',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms2/fgm/brst/l2/',
#    'title': 'mms2/fgm/brst/l2/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms2_fgm_srvy',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms2/fgm/srvy/l2/',
#    'title': 'mms2/fgm/srvy/l2/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms2_fpi_brst_des-dist',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms2/fpi/brst/l2/des-dist/',
#    'title': 'mms2/fpi/brst/l2/des-dist/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms2_fpi_brst_des-moms',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms2/fpi/brst/l2/des-moms/',
#    'title': 'mms2/fpi/brst/l2/des-moms/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms2_fpi_brst_dis-dist',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms2/fpi/brst/l2/dis-dist/',
#    'title': 'mms2/fpi/brst/l2/dis-dist/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms2_fpi_brst_dis-moms',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms2/fpi/brst/l2/dis-moms/',
#    'title': 'mms2/fpi/brst/l2/dis-moms/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms2_fpi_fast_des-dist',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms2/fpi/fast/l2/des-dist/',
#    'title': 'mms2/fpi/fast/l2/des-dist/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms2_fpi_fast_des-moms',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms2/fpi/fast/l2/des-moms/',
#    'title': 'mms2/fpi/fast/l2/des-moms/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms2_fpi_fast_dis-dist',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms2/fpi/fast/l2/dis-dist/',
#    'title': 'mms2/fpi/fast/l2/dis-dist/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms2_fpi_fast_dis-moms',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms2/fpi/fast/l2/dis-moms/',
#    'title': 'mms2/fpi/fast/l2/dis-moms/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms2_mec_brst_epht89d',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms2/mec/brst/l2/epht89d/',
#    'title': 'mms2/mec/brst/l2/epht89d/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms2_mec_srvy_epht89d',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms2/mec/srvy/l2/epht89d/',
#    'title': 'mms2/mec/srvy/l2/epht89d/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms3_feeps_brst_electron',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms3/feeps/brst/l2/electron/',
#    'title': 'mms3/feeps/brst/l2/electron/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms3_feeps_brst_ion',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms3/feeps/brst/l2/ion/',
#    'title': 'mms3/feeps/brst/l2/ion/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms3_feeps_srvy_electron',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms3/feeps/srvy/l2/electron/',
#    'title': 'mms3/feeps/srvy/l2/electron/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms3_feeps_srvy_ion',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms3/feeps/srvy/l2/ion/',
#    'title': 'mms3/feeps/srvy/l2/ion/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms3_fgm_brst',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms3/fgm/brst/l2/',
#    'title': 'mms3/fgm/brst/l2/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms3_fgm_srvy',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms3/fgm/srvy/l2/',
#    'title': 'mms3/fgm/srvy/l2/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms3_fpi_brst_des-dist',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms3/fpi/brst/l2/des-dist/',
#    'title': 'mms3/fpi/brst/l2/des-dist/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms3_fpi_brst_des-moms',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms3/fpi/brst/l2/des-moms/',
#    'title': 'mms3/fpi/brst/l2/des-moms/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms3_fpi_brst_dis-dist',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms3/fpi/brst/l2/dis-dist/',
#    'title': 'mms3/fpi/brst/l2/dis-dist/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms3_fpi_brst_dis-moms',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms3/fpi/brst/l2/dis-moms/',
#    'title': 'mms3/fpi/brst/l2/dis-moms/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms3_fpi_fast_des-dist',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms3/fpi/fast/l2/des-dist/',
#    'title': 'mms3/fpi/fast/l2/des-dist/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms3_fpi_fast_des-moms',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms3/fpi/fast/l2/des-moms/',
#    'title': 'mms3/fpi/fast/l2/des-moms/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms3_fpi_fast_dis-dist',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms3/fpi/fast/l2/dis-dist/',
#    'title': 'mms3/fpi/fast/l2/dis-dist/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms3_fpi_fast_dis-moms',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms3/fpi/fast/l2/dis-moms/',
#    'title': 'mms3/fpi/fast/l2/dis-moms/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms3_mec_brst_epht89d',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms3/mec/brst/l2/epht89d/',
#    'title': 'mms3/mec/brst/l2/epht89d/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms3_mec_srvy_epht89d',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms3/mec/srvy/l2/epht89d/',
#    'title': 'mms3/mec/srvy/l2/epht89d/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms4_feeps_brst_electron',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms4/feeps/brst/l2/electron/',
#    'title': 'mms4/feeps/brst/l2/electron/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms4_feeps_brst_ion',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms4/feeps/brst/l2/ion/',
#    'title': 'mms4/feeps/brst/l2/ion/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms4_feeps_srvy_electron',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms4/feeps/srvy/l2/electron/',
#    'title': 'mms4/feeps/srvy/l2/electron/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms4_feeps_srvy_ion',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms4/feeps/srvy/l2/ion/',
#    'title': 'mms4/feeps/srvy/l2/ion/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms4_fgm_brst',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms4/fgm/brst/l2/',
#    'title': 'mms4/fgm/brst/l2/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms4_fgm_srvy',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms4/fgm/srvy/l2/',
#    'title': 'mms4/fgm/srvy/l2/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms4_fpi_brst_des-dist',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms4/fpi/brst/l2/des-dist/',
#    'title': 'mms4/fpi/brst/l2/des-dist/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms4_fpi_brst_des-moms',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms4/fpi/brst/l2/des-moms/',
#    'title': 'mms4/fpi/brst/l2/des-moms/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms4_fpi_brst_dis-dist',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms4/fpi/brst/l2/dis-dist/',
#    'title': 'mms4/fpi/brst/l2/dis-dist/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms4_fpi_brst_dis-moms',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms4/fpi/brst/l2/dis-moms/',
#    'title': 'mms4/fpi/brst/l2/dis-moms/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms4_fpi_fast_des-dist',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms4/fpi/fast/l2/des-dist/',
#    'title': 'mms4/fpi/fast/l2/des-dist/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms4_fpi_fast_des-moms',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms4/fpi/fast/l2/des-moms/',
#    'title': 'mms4/fpi/fast/l2/des-moms/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms4_fpi_fast_dis-dist',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms4/fpi/fast/l2/dis-dist/',
#    'title': 'mms4/fpi/fast/l2/dis-dist/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms4_fpi_fast_dis-moms',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms4/fpi/fast/l2/dis-moms/',
#    'title': 'mms4/fpi/fast/l2/dis-moms/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms4_mec_brst_epht89d',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms4/mec/brst/l2/epht89d/',
#    'title': 'mms4/mec/brst/l2/epht89d/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'mms4_mec_srvy_epht89d',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms4/mec/srvy/l2/epht89d/',
#    'title': 'mms4/mec/srvy/l2/epht89d/',
#    'start': '2015-06-01T00:00.00Z',
#    'stop': '2023-09-30T23:59.00Z',
#    'modification': '2024-02-28T17:10.00Z',
#    'indextype': 'csv',
#    'filetype': 'cdf'},
#   {'id': 'supermag_ulfncdf',
#    'title': 'SuperMAG ULF files in netcdf format',
#    'index': 's3://gov-nasa-hdrl-data1/contrib/jhuapl/supermag/indices/',
#    'start': '2012-01-01T01Z',
#    'stop': '2024-05-22T01Z',
#    'modification': '2024-09-18T:12:00:00Z',
#    'indextype': 'csv',
#    'filetype': 'netcdf4'},
#   {'id': 'supermag_mag-01s-global',
#    'title': 'SuperMAG global data at 1 second resolution',
#    'index': 's3://gov-nasa-hdrl-data1/contrib/jhuapl/supermag/indices/',
#    'start': '1998-01-01T00Z',
#    'stop': '2024-05-22T03Z',
#    'modification': '2024-09-18T:12:00:00Z',
#    'indextype': 'csv',
#    'filetype': 'DataMap'},
#   {'id': 'supermag_mag-01s-station',
#    'title': 'SuperMAG station data at 1 second resolution',
#    'index': 's3://gov-nasa-hdrl-data1/contrib/jhuapl/supermag/indices/',
#    'start': '1998-01-01T00Z',
#    'stop': '2024-05-22T00Z',
#    'modification': '2024-09-18T:12:00:00Z',
#    'indextype': 'csv',
#    'filetype': 'DataMap'},
#   {'id': 'MMS1_ASPOC_SRVY_L2',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/data/mms/indices/',
#    'title': 'Level 2 Active Spacecraft Potential Control Survey Data - K. Torkar, R. Nakamura (IWF)',
#    'start': '2015-09-01T00:00:00.000Z',
#    'stop': '2024-08-22T23:59:59.000Z',
#    'indextype': 'csv',
#    'filetype': 'CDF',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_ASPOC_SRVY_L2',
#    'contact': 'K. Torkar, R. Nakamura',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_ASPOC_SRVY_L2',
#    'collections': ['CDAWeb', 'MMS']},
#   {'id': 'MMS1_DSP_FAST_L2_BPSD',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/data/mms/indices/',
#    'title': 'SCM Low frequency Magnetic spectral density from the FIELDS Digital Signal Processor - J. Burch, R. Ergun, O. Le Contel (SWRI, LASP, LPP)',
#    'start': '2015-09-01T00:00:00.000Z',
#    'stop': '2024-08-22T23:59:59.000Z',
#    'indextype': 'csv',
#    'filetype': 'CDF',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_DSP_FAST_L2_BPSD',
#    'contact': 'J. Burch, R. Ergun, O. Le Contel',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_DSP_FAST_L2_BPSD',
#    'collections': ['CDAWeb', 'MMS']},
#   {'id': 'MMS1_DSP_FAST_L2_EPSD',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/data/mms/indices/',
#    'title': 'Low and medium frequency Electric Field spectral density from the FIELDS Digital Signal Processor - J. Burch, R. Ergun (SWRI, LASP)',
#    'start': '2015-09-01T00:00:00.000Z',
#    'stop': '2024-08-22T23:59:59.000Z',
#    'indextype': 'csv',
#    'filetype': 'CDF',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_DSP_FAST_L2_EPSD',
#    'contact': 'J. Burch, R. Ergun',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_DSP_FAST_L2_EPSD',
#    'collections': ['CDAWeb', 'MMS']},
#   {'id': 'MMS1_DSP_SLOW_L2_BPSD',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/data/mms/indices/',
#    'title': 'search coil magnetometer spectral density - J. Burch, R. Ergun, O. Le Contel (SWRI, LASP, LPP)',
#    'start': '2015-09-01T00:00:00.000Z',
#    'stop': '2024-08-22T23:59:59.000Z',
#    'indextype': 'csv',
#    'filetype': 'CDF',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_DSP_SLOW_L2_BPSD',
#    'contact': 'J. Burch, R. Ergun, O. Le Contel',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_DSP_SLOW_L2_BPSD',
#    'collections': ['CDAWeb', 'MMS']},
#   {'id': 'MMS1_DSP_SLOW_L2_EPSD',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/data/mms/indices/',
#    'title': 'electric spectral density - J. Burch, R. Ergun (SWRI, LASP)',
#    'start': '2015-09-01T00:00:00.000Z',
#    'stop': '2024-08-22T23:59:59.000Z',
#    'indextype': 'csv',
#    'filetype': 'CDF',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_DSP_SLOW_L2_EPSD',
#    'contact': 'J. Burch, R. Ergun',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_DSP_SLOW_L2_EPSD',
#    'collections': ['CDAWeb', 'MMS']},
#   {'id': 'MMS1_EDI_BRST_L2_AMB-PM2',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/data/mms/indices/',
#    'title': 'Level 2 EDI Ambient electron flux - Roy Torbert, Hans Vaith (UNH)',
#    'start': '2016-01-14T20:45:04.000Z',
#    'stop': '2024-08-22T23:59:59.000Z',
#    'indextype': 'csv',
#    'filetype': 'CDF',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDI_BRST_L2_AMB-PM2',
#    'contact': 'Roy Torbert, Hans Vaith',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDI_BRST_L2_AMB-PM2',
#    'collections': ['CDAWeb', 'MMS']},
#   {'id': 'MMS1_EDI_BRST_L2_AMB',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/data/mms/indices/',
#    'title': 'Level 2 EDI Ambient electron flux - Roy Torbert, Hans Vaith (UNH)',
#    'start': '2015-09-01T12:11:14.000Z',
#    'stop': '2015-12-26T02:14:32.000Z',
#    'indextype': 'csv',
#    'filetype': 'CDF',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDI_BRST_L2_AMB',
#    'contact': 'Roy Torbert, Hans Vaith',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDI_BRST_L2_AMB',
#    'collections': ['CDAWeb', 'MMS']},
#   {'id': 'MMS1_EDI_BRST_L2_EFIELD',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/data/mms/indices/',
#    'title': 'Level 2 EDI electric field - Hans Vaith (UNH)',
#    'start': '2015-09-14T14:13:07.000Z',
#    'stop': '2023-08-11T07:13:57.000Z',
#    'indextype': 'csv',
#    'filetype': 'CDF',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDI_BRST_L2_EFIELD',
#    'contact': 'Hans Vaith',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDI_BRST_L2_EFIELD',
#    'collections': ['CDAWeb', 'MMS']},
#   {'id': 'MMS1_EDI_BRST_L2_Q0',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/data/mms/indices/',
#    'title': 'Level 2 EDI Quality 0 Counts - Roy Torbert, Hans Vaith (UNH)',
#    'start': '2016-04-12T22:24:14.000Z',
#    'stop': '2024-08-22T23:59:59.000Z',
#    'indextype': 'csv',
#    'filetype': 'CDF',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDI_BRST_L2_Q0',
#    'contact': 'Roy Torbert, Hans Vaith',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDI_BRST_L2_Q0',
#    'collections': ['CDAWeb', 'MMS']},
#   {'id': 'MMS1_EDI_SRVY_L2_AMB-PM2',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/data/mms/indices/',
#    'title': 'Level 2 EDI Ambient electron flux - Roy Torbert, Hans Vaith (UNH)',
#    'start': '2016-01-06T00:38:49.000Z',
#    'stop': '2024-08-22T23:59:59.000Z',
#    'indextype': 'csv',
#    'filetype': 'CDF',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDI_SRVY_L2_AMB-PM2',
#    'contact': 'Roy Torbert, Hans Vaith',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDI_SRVY_L2_AMB-PM2',
#    'collections': ['CDAWeb', 'MMS']},
#   {'id': 'MMS1_EDI_SRVY_L2_AMB',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/data/mms/indices/',
#    'title': 'Level 2 EDI Ambient electron flux - Roy Torbert, Hans Vaith (UNH)',
#    'start': '2015-09-01T03:13:11.000Z',
#    'stop': '2016-01-06T00:49:29.000Z',
#    'indextype': 'csv',
#    'filetype': 'CDF',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDI_SRVY_L2_AMB',
#    'contact': 'Roy Torbert, Hans Vaith',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDI_SRVY_L2_AMB',
#    'collections': ['CDAWeb', 'MMS']},
#   {'id': 'MMS1_EDI_SRVY_L2_EFIELD',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/data/mms/indices/',
#    'title': 'Level 2 EDI electric field - Hans Vaith (UNH)',
#    'start': '2015-09-01T00:03:08.000Z',
#    'stop': '2023-08-22T05:37:02.000Z',
#    'indextype': 'csv',
#    'filetype': 'CDF',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDI_SRVY_L2_EFIELD',
#    'contact': 'Hans Vaith',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDI_SRVY_L2_EFIELD',
#    'collections': ['CDAWeb', 'MMS']},
#   {'id': 'MMS1_EDI_SRVY_L2_Q0',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/data/mms/indices/',
#    'title': 'Level 2 EDI Quality 0 Counts - Roy Torbert, Hans Vaith (UNH)',
#    'start': '2015-09-01T00:02:03.000Z',
#    'stop': '2024-08-22T23:59:59.000Z',
#    'indextype': 'csv',
#    'filetype': 'CDF',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDI_SRVY_L2_Q0',
#    'contact': 'Roy Torbert, Hans Vaith',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDI_SRVY_L2_Q0',
#    'collections': ['CDAWeb', 'MMS']},
#   {'id': 'MMS1_EDP_BRST_L2_DCE',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/data/mms/indices/',
#    'title': 'MMS1 L2 (Burst Mode), 3D Electric field - J.Burch, R.Ergun, P.Lindqvist. (SWRI, LASP, KTH)',
#    'start': '2015-09-01T00:00:00.000Z',
#    'stop': '2024-07-10T04:21:52.000Z',
#    'indextype': 'csv',
#    'filetype': 'CDF',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDP_BRST_L2_DCE',
#    'contact': 'J.Burch, R.Ergun, P.Lindqvist.',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDP_BRST_L2_DCE',
#    'collections': ['CDAWeb', 'MMS']},
#   {'id': 'MMS1_EDP_BRST_L2_HMFE',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/data/mms/indices/',
#    'title': 'MMS1 L2 (brst), 3D HMFE Electric field - Burch, J, Ergun, R., Lindqvist, P. (SwRI, LASP, KTH)',
#    'start': '2015-09-01T12:11:18.000Z',
#    'stop': '2024-08-22T23:59:59.000Z',
#    'indextype': 'csv',
#    'filetype': 'CDF',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDP_BRST_L2_HMFE',
#    'contact': 'Burch, J, Ergun, R., Lindqvist, P.',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDP_BRST_L2_HMFE',
#    'collections': ['CDAWeb', 'MMS']},
#   {'id': 'MMS1_EDP_BRST_L2_SCPOT',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/data/mms/indices/',
#    'title': 'MMS 1 dual probe scpot (brst), Spacecraft potential - J.Burch, R.Ergun, P.Lindqvist. (SWRI, LASP, KTH)',
#    'start': '2015-09-01T00:00:00.000Z',
#    'stop': '2024-08-22T23:59:59.000Z',
#    'indextype': 'csv',
#    'filetype': 'CDF',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDP_BRST_L2_SCPOT',
#    'contact': 'J.Burch, R.Ergun, P.Lindqvist.',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDP_BRST_L2_SCPOT',
#    'collections': ['CDAWeb', 'MMS']},
#   {'id': 'MMS1_EDP_FAST_L2_DCE',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/data/mms/indices/',
#    'title': 'MMS1 L2 (fast mode), 3D Electric field - J.Burch, R.Ergun, P.Lindqvist. (SWRI, LASP, KTH)',
#    'start': '2015-09-01T09:51:44.000Z',
#    'stop': '2024-08-14T23:59:59.000Z',
#    'indextype': 'csv',
#    'filetype': 'CDF',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDP_FAST_L2_DCE',
#    'contact': 'J.Burch, R.Ergun, P.Lindqvist.',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDP_FAST_L2_DCE',
#    'collections': ['CDAWeb', 'MMS']},
#   {'id': 'MMS1_EDP_FAST_L2_SCPOT',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/data/mms/indices/',
#    'title': 'MMS 1 dual probe scpot (fast), Spacecraft potential - J.Burch, R.Ergun, P.Lindqvist. (SWRI, LASP, KTH)',
#    'start': '2015-09-01T00:00:00.000Z',
#    'stop': '2024-08-22T23:59:59.000Z',
#    'indextype': 'csv',
#    'filetype': 'CDF',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDP_FAST_L2_SCPOT',
#    'contact': 'J.Burch, R.Ergun, P.Lindqvist.',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDP_FAST_L2_SCPOT',
#    'collections': ['CDAWeb', 'MMS']},
#   {'id': 'MMS1_EDP_SLOW_L2_DCE',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/data/mms/indices/',
#    'title': 'MMS1 L2 (slow mode), 3D Electric field - J.Burch, R.Ergun, P.Lindqvist. (SWRI, LASP, KTH)',
#    'start': '2015-09-01T00:00:00.000Z',
#    'stop': '2024-08-14T21:57:18.000Z',
#    'indextype': 'csv',
#    'filetype': 'CDF',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesM.html#MMS1_EDP_SLOW_L2_DCE',
#    'contact': 'J.Burch, R.Ergun, P.Lindqvist.',
# ...
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesG.html#GPS_TEC1HR_IGS',
#    'collections': ['CDAWeb']},
#   {'id': 'GPS_TEC2HR_IGS',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/gps/tec2hr_igs/',
#    'title': 'GPS-deduced 2-hour Total Electron Content (TEC) maps and movies, IGS= Average of 4 methods, incl. CODE= U Bern Switzerland, ESA= ESOC Darmstadt Germany, JPL= Jet Propulsion Lab. Pasadena USA, UPC= U Politec. Catalonia Barcelona Spain - International Global Navigation Satellite Systems (GNSS) Service Ionosphere Working Group',
#    'start': '1998-06-01T01:00:00.000Z',
#    'stop': '2023-03-13T22:00:00.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesG.html#GPS_TEC2HR_IGS',
#    'contact': 'International Global Navigation Satellite Systems (GNSS) Service Ionosphere Working Group',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesG.html#GPS_TEC2HR_IGS',
#    'collections': ['CDAWeb']},
#   {'id': 'HEL1_6SEC_NESSMAG',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/helios/helios1/mag/6sec_nessmag_cdaweb/',
#    'title': 'HEL1_6SEC_NESSMAG - Mariani/Ness (University of Rome, CNR/Istituto Fisica Interplanetario, and NASA/GSFC)',
#    'start': '1974-12-15T00:01:00.000Z',
#    'stop': '1981-06-16T04:59:06.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HEL1_6SEC_NESSMAG',
#    'contact': 'Mariani/Ness',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HEL1_6SEC_NESSMAG',
#    'collections': ['CDAWeb']},
#   {'id': 'HEL2_6SEC_NESSMAG',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/helios/helios2/mag/6sec_nessmag_cdaweb/',
#    'title': 'HEL2_6SEC_NESSMAG - Mariani/Ness (University of Rome, CNR/Istituto Fisica Interplanetario, and NASA/GSFC)',
#    'start': '1976-01-17T07:34:06.000Z',
#    'stop': '1980-03-08T17:50:00.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HEL2_6SEC_NESSMAG',
#    'contact': 'Mariani/Ness',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HEL2_6SEC_NESSMAG',
#    'collections': ['CDAWeb']},
#   {'id': 'HELIOS1_40SEC_MAG-PLASMA',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/helios/helios1/merged/mag_plasma/40sec_cdf/',
#    'title': 'Merged 40.5 s magnetic field, plasma data, ephemeris - R. Schwenn, F. M. Neubauer (Max Planck Institute for Solar System Research, University of Cologne)',
#    'start': '1974-12-12T01:21:38.000Z',
#    'stop': '1985-09-04T09:52:10.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HELIOS1_40SEC_MAG-PLASMA',
#    'contact': 'R. Schwenn, F. M. Neubauer',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HELIOS1_40SEC_MAG-PLASMA',
#    'collections': ['CDAWeb']},
#   {'id': 'HELIOS1_COHO1HR_MERGED_MAG_PLASMA',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/helios/helios1/coho1hr_magplasma/',
#    'title': 'Helios-1 merged hourly magnetic field, plasma, proton fluxes, and ephermis data - N. Ness, F. Neubauer, F. Mariani (magnetic field), H. Rosenbauer, R. Schwenn (plasma) and J. Freeman (all affiliated with ESA or NASA)',
#    'start': '1974-01-01T00:00:00.000Z',
#    'stop': '1981-12-31T23:00:00.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HELIOS1_COHO1HR_MERGED_MAG_PLASMA',
#    'contact': 'N. Ness, F. Neubauer, F. Mariani (magnetic field), H. Rosenbauer, R. Schwenn (plasma) and J. Freeman',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HELIOS1_COHO1HR_MERGED_MAG_PLASMA',
#    'collections': ['CDAWeb']},
#   {'id': 'HELIOS1_E6_1HOUR_PARTICLE_FLUX',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/helios/helios1/e6_particle_flux/1hour_cdf/1974/',
#    'title': 'hourly averaged fluxes of e, H and He -  H. Kunow (University of Kiel)',
#    'start': '1974-12-11T21:07:00.000Z',
#    'stop': '1983-12-31T22:01:00.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HELIOS1_E6_1HOUR_PARTICLE_FLUX',
#    'contact': ' H. Kunow',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HELIOS1_E6_1HOUR_PARTICLE_FLUX',
#    'collections': ['CDAWeb']},
#   {'id': 'HELIOS1_E6_KUNOW_1HOUR_PARTICLE-FLUX',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/helios/helios1/e6_particle_flux_kunow/1hour_cdf/1974/',
#    'title': 'Hourly averaged fluxes of e, H and He from Helios-1/E6(Kunow) -  H. Kunow (University of Kiel)',
#    'start': '1974-12-11T21:07:00.000Z',
#    'stop': '1983-12-31T14:35:00.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HELIOS1_E6_KUNOW_1HOUR_PARTICLE-FLUX',
#    'contact': ' H. Kunow',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HELIOS1_E6_KUNOW_1HOUR_PARTICLE-FLUX',
#    'collections': ['CDAWeb']},
#   {'id': 'HELIOS1_HELIO1DAY_POSITION',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/helios/helios1/helio1day/',
#    'title': 'Position in heliocentric coordinates from SPDF Helioweb - Natalia Papitashvili (NASA/GSFC/SPDF)',
#    'start': '1974-12-10T00:00:00.000Z',
#    'stop': '1985-12-30T00:00:00.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HELIOS1_HELIO1DAY_POSITION',
#    'contact': 'Natalia Papitashvili',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HELIOS1_HELIO1DAY_POSITION',
#    'collections': ['CDAWeb']},
#   {'id': 'HELIOS2_40SEC_MAG-PLASMA',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/helios/helios2/merged/mag_plasma/40sec_cdf/',
#    'title': 'Merged 40.5 s magnetic field, plasma data, ephemeris - R. Schwenn, F. M. Neubauer (Max Planck Institute for Solar System Research, University of Cologne)',
#    'start': '1976-01-17T01:21:36.000Z',
#    'stop': '1980-03-08T17:43:50.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HELIOS2_40SEC_MAG-PLASMA',
#    'contact': 'R. Schwenn, F. M. Neubauer',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HELIOS2_40SEC_MAG-PLASMA',
#    'collections': ['CDAWeb']},
#   {'id': 'HELIOS2_COHO1HR_MERGED_MAG_PLASMA',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/helios/helios2/coho1hr_magplasma/',
#    'title': 'Helios-2 merged hourly magnetic field, plasma, proton fluxes, and ephermis data - N. Ness, F. Neubauer, F. Mariani (magnetic field), H. Rosenbauer, R. Schwenn (plasma) and J. Freeman (all affiliated with ESA or NASA)',
#    'start': '1976-01-01T00:00:00.000Z',
#    'stop': '1980-12-31T23:00:00.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HELIOS2_COHO1HR_MERGED_MAG_PLASMA',
#    'contact': 'N. Ness, F. Neubauer, F. Mariani (magnetic field), H. Rosenbauer, R. Schwenn (plasma) and J. Freeman',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HELIOS2_COHO1HR_MERGED_MAG_PLASMA',
#    'collections': ['CDAWeb']},
#   {'id': 'HELIOS2_E6_1HOUR_PARTICLE_FLUX',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/helios/helios2/e6_particle_flux/1hour_cdf/1976/',
#    'title': 'hourly averaged fluxes of e, H and He -  H. Kunow (University of Kiel)',
#    'start': '1976-01-16T21:07:00.000Z',
#    'stop': '1980-03-08T16:25:00.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HELIOS2_E6_1HOUR_PARTICLE_FLUX',
#    'contact': ' H. Kunow',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HELIOS2_E6_1HOUR_PARTICLE_FLUX',
#    'collections': ['CDAWeb']},
#   {'id': 'HELIOS2_E6_KUNOW_1HOUR_PARTICLE-FLUX',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/helios/helios2/e6_particle_flux_kunow/1hour_cdf/1976/',
#    'title': 'Hourly averaged fluxes of e, H and He from Helios-1/E6(Kunow) -  H. Kunow (University of Kiel)',
#    'start': '1976-01-16T21:07:00.000Z',
#    'stop': '1980-03-08T16:25:00.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HELIOS2_E6_KUNOW_1HOUR_PARTICLE-FLUX',
#    'contact': ' H. Kunow',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HELIOS2_E6_KUNOW_1HOUR_PARTICLE-FLUX',
#    'collections': ['CDAWeb']},
#   {'id': 'HELIOS2_HELIO1DAY_POSITION',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/helios/helios2/helio1day/',
#    'title': 'Position in heliocentric coordinates from SPDF Helioweb - Natalia Papitashvili (NASA/GSFC/SPDF)',
#    'start': '1976-01-01T00:00:00.000Z',
#    'stop': '1985-12-31T00:00:00.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HELIOS2_HELIO1DAY_POSITION',
#    'contact': 'Natalia Papitashvili',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HELIOS2_HELIO1DAY_POSITION',
#    'collections': ['CDAWeb']},
#   {'id': 'HK_H0_MAG',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/hawkeye/mag/mag_h0/',
#    'title': 'Hawkeye Magnetic Field Instrument - J. Van Allen (University of Iowa)',
#    'start': '1974-06-06T04:28:06.000Z',
#    'stop': '1978-04-28T17:57:30.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HK_H0_MAG',
#    'contact': 'J. Van Allen',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HK_H0_MAG',
#    'collections': ['CDAWeb']},
#   {'id': 'HK_H0_VLF',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/hawkeye/vlf/vlf_h0/',
#    'title': 'Hk Electric and Magnetic Field Radio Frequency Spectrum Analyzer High Time Resolution - D. Gurnett (University of Iowa)',
#    'start': '1974-06-08T06:45:10.000Z',
#    'stop': '1978-04-26T15:59:05.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HK_H0_VLF',
#    'contact': 'D. Gurnett',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesH.html#HK_H0_VLF',
#    'collections': ['CDAWeb']},
#   {'id': 'I1_AV2_OTT',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/isis/ionogram_new_i1_cdf/isis1/ott_45n_284e/19/',
#    'title': 'ISIS Topside Sounder Ionogram - R.F. Benson (NASA GSFC)',
#    'start': '1969-01-30T14:50:12.000Z',
#    'stop': '1983-12-17T13:08:05.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesI.html#I1_AV2_OTT',
#    'contact': 'R.F. Benson',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesI.html#I1_AV2_OTT',
#    'collections': ['CDAWeb']},
#   {'id': 'I1_AV2_SNT',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/isis/ionogram_new_i1_cdf/isis1/snt_33s_298e/1969/',
#    'title': 'ISIS Topside Sounder Ionogram - R.F. Benson (NASA GSFC)',
#    'start': '1969-01-31T04:32:48.000Z',
#    'stop': '1969-12-27T03:20:57.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesI.html#I1_AV2_SNT',
#    'contact': 'R.F. Benson',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesI.html#I1_AV2_SNT',
#    'collections': ['CDAWeb']},
#   {'id': 'I1_AV2_ULA',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/isis/ionogram_new_i1_cdf/isis1/ula_65n_212e/197/',
#    'title': 'ISIS Topside Sounder Ionogram - R.F. Benson (NASA GSFC)',
#    'start': '1975-01-04T18:15:50.000Z',
#    'stop': '1979-09-14T12:06:30.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesI.html#I1_AV2_ULA',
#    'contact': 'R.F. Benson',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesI.html#I1_AV2_ULA',
#    'collections': ['CDAWeb']},
#   {'id': 'I1_AV_KER',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/isis/ionogram_cdf/isis1/KER_49S_070E/1983/',
#    'title': 'ISIS-1 Topside Sounder Ionograms over Kerguelen Island, France (Lat=-49, Long=70) - R.F. Benson (NASA GSFC)',
#    'start': '1983-08-24T15:21:21.000Z',
#    'stop': '1983-12-30T15:19:33.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesI.html#I1_AV_KER',
#    'contact': 'R.F. Benson',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesI.html#I1_AV_KER',
#    'collections': ['CDAWeb']},
#   {'id': 'I1_AV_KSH',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/isis/ionogram_cdf/isis1/KSH_36N_141E/19/',
#    'title': 'ISIS-1 Topside Sounder Ionogram over Kashima, Japan (lat/lon=36/141) - R.F. Benson (NASA GSFC)',
#    'start': '1978-01-06T04:52:17.000Z',
#    'stop': '1981-12-30T16:22:49.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesI.html#I1_AV_KSH',
#    'contact': 'R.F. Benson',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesI.html#I1_AV_KSH',
#    'collections': ['CDAWeb']},
#   {'id': 'I1_AV_KWA',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/isis/ionogram_cdf/isis1/KWA_09N_168E/1978/',
#    'title': 'ISIS-1 Topside Sounder Ionogram over Kwajalein, Marshall Is. (lat/lon=9/168) - R.F. Benson (NASA GSFC)',
#    'start': '1978-01-03T04:13:25.000Z',
#    'stop': '1978-12-30T21:34:08.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesI.html#I1_AV_KWA',
#    'contact': 'R.F. Benson',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesI.html#I1_AV_KWA',
#    'collections': ['CDAWeb']},
#   {'id': 'I1_AV_ORR',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/isis/ionogram_cdf/isis1/ORR_36S_149E/19/',
#    'title': 'ISIS-1 Topside Sounder Ionogram over Orroral, Australia (lat/lon=-36/149) - R.F. Benson (NASA GSFC)',
#    'start': '1970-01-28T09:47:09.000Z',
#    'stop': '1981-08-24T14:00:56.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesI.html#I1_AV_ORR',
#    'contact': 'R.F. Benson',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesI.html#I1_AV_ORR',
#    'collections': ['CDAWeb']},
#   {'id': 'I1_AV_SOD',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/isis/ionogram_cdf/isis1/SOD_67N_027E/197/',
#    'title': 'ISIS-1 Topside Sounder Ionogram over Sodankyla, Finland (lat/lon=67/27) - R.F. Benson (NASA GSFC)',
#    'start': '1977-12-14T22:30:46.000Z',
#    'stop': '1979-03-30T14:10:33.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesI.html#I1_AV_SOD',
#    'contact': 'R.F. Benson',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesI.html#I1_AV_SOD',
#    'collections': ['CDAWeb']},
#   {'id': 'I1_AV_TRO',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/isis/ionogram_cdf/isis1/TRO_70N_019E/1969/',
#    'title': 'ISIS-1 Topside Sounder Ionogram over Tromso, Norway (lat/lon=70/19) - R.F. Benson (NASA GSFC)',
#    'start': '1969-02-05T18:15:49.000Z',
#    'stop': '1969-12-28T15:12:00.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesI.html#I1_AV_TRO',
#    'contact': 'R.F. Benson',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesI.html#I1_AV_TRO',
#    'collections': ['CDAWeb']},
#   {'id': 'I1_AV_ULA',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/isis/ionogram_cdf/isis1/ULA_65N_212E/197/',
#    'title': 'ISIS-1 Topside Sounder Ionogram over Fairbanks, Alaska (lat/lon=65/212) - R.F. Benson (NASA GSFC)',
#    'start': '1975-01-04T18:15:16.000Z',
#    'stop': '1979-09-14T12:06:35.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesI.html#I1_AV_ULA',
#    'contact': 'R.F. Benson',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesI.html#I1_AV_ULA',
#    'collections': ['CDAWeb']},
#   {'id': 'I1_AV_WNK',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/isis/ionogram_cdf/isis1/WNK_51N_359E/19/',
#    'title': 'ISIS-1 Topside Sounder Ionogram over Winkfield, U.K. (lat/lon=51/359) - R.F. Benson (NASA GSFC)',
#    'start': '1969-02-03T01:02:10.000Z',
#    'stop': '1975-07-18T05:06:36.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesI.html#I1_AV_WNK',
#    'contact': 'R.F. Benson',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesI.html#I1_AV_WNK',
#    'collections': ['CDAWeb']},
#   {'id': 'I1_NEPROF_TOPS',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/isis/crc_ne_profile_cdf/isis1/',
#    'title': 'ISIS-1 Topside Electron Density Profiles, manually scaled at CRC - J. E. Jackson (Communication Research Centre (CRC), Ottawa)',
#    'start': '1969-02-01T15:50:12.000Z',
#    'stop': '1980-05-30T02:41:08.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesI.html#I1_NEPROF_TOPS',
#    'contact': 'J. E. Jackson',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesI.html#I1_NEPROF_TOPS',
#    'collections': ['CDAWeb']},
#   {'id': 'I2_AV_ACN',
#    'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/isis/ionogram_cdf/isis2/ACN_08S_346E/197/',
#    'title': 'ISIS-2 Topside Sounder Ionogram over Ascension Is., U.K. (lat/lon= -8/346) - R.F. Benson (NASA GSFC)',
#    'start': '1975-01-09T01:22:59.000Z',
#    'stop': '1978-09-28T16:37:11.000Z',
#    'resource': 'https://cdaweb.gsfc.nasa.gov/misc/NotesI.html#I2_AV_ACN',
#    'contact': 'R.F. Benson',
#    'about': 'https://cdaweb.gsfc.nasa.gov/misc/NotesI.html#I2_AV_ACN',
#    'collections': ['CDAWeb']},
#   ...],
#  'status': {'code': 1200, 'message': 'OK request successful'}}

# %%
fr_id1 = 'mms1_feeps_brst_electron'
fr_id2 = 'mmm2_feeps_brst_electron'
start_date = '2020-02-01T00:00:00Z'
stop_date =   '2020-02-02T00:00:00Z'

# %%
pprint(fr.get_entry(fr_id1))
# Out:
# {'aboutURL': 'optional website URL for info, team, etc',
#  'citation': 'optional how to cite this dataset, DOI or similar',
#  'contact': 'optional contact info, SPASE ID, email, or ORCID',
#  'creationDate': 'optional ISO 8601 date/time of the dataset creation',
#  'description': 'Optional description for dataset',
#  'filetype': 'cdf',
#  'id': 'mms1_feeps_brst_electron',
#  'index': 's3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/feeps/brst/l2/electron/',
#  'indextype': 'csv',
#  'modification': '2024-02-28T17:10.00Z',
#  'resourceID': 'optional identifier e.g. SPASE ID',
#  'start': '2015-06-01T00:00.00Z',
#  'stop': '2023-09-30T23:59.00Z',
#  'title': 'mms1/feeps/brst/l2/electron/'}

# %%
cloud_catalog1 = fr.request_cloud_catalog(fr_id1, start_date=start_date, stop_date=stop_date, overwrite=False)

# %%
cloud_catalog1
# Out:
#                   start                stop  \
# 589 2020-01-31 21:03:23 2020-02-01 07:55:23
# 590 2020-02-01 07:55:23 2020-02-01 08:17:13
# 591 2020-02-01 08:17:13 2020-02-01 08:19:23
# 592 2020-02-01 08:19:23 2020-02-01 08:21:33
# 593 2020-02-01 08:21:33 2020-02-01 08:23:43
# 594 2020-02-01 08:23:43 2020-02-01 08:26:03
# 595 2020-02-01 08:26:03 2020-02-01 08:28:13
# 596 2020-02-01 08:28:13 2020-02-01 08:30:23
# 597 2020-02-01 08:30:23 2020-02-01 08:37:13
# 598 2020-02-01 08:37:13 2020-02-01 08:39:33
# 599 2020-02-01 08:39:33 2020-02-01 08:41:53
# 600 2020-02-01 08:41:53 2020-02-01 08:44:13
# 601 2020-02-01 08:44:13 2020-02-01 08:46:33
# 602 2020-02-01 08:46:33 2020-02-01 08:48:53
# 603 2020-02-01 08:48:53 2020-02-02 05:53:53
#
#                                                datakey  filesize
# 589  s3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/...   1513848
# 590  s3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/...   1521034
# 591  s3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/...   3166628
# 592  s3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/...   3166628
# 593  s3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/...   3166628
# 594  s3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/...   3396580
# 595  s3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/...   3166628
# 596  s3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/...   3159442
# 597  s3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/...   3152256
# 598  s3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/...   3396580
# 599  s3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/...   3396580
# 600  s3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/...   3403766
# 601  s3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/...   3396580
# 602  s3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/...   3396580
# 603  s3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/...   3389394

# %%
print('Python Hash of File | Start Date | File Size')
fr.stream(cloud_catalog1, lambda bo, d, e, f: print(hash(bo.read()), d.replace(' ', 'T')+'Z', e.replace(' ', 'T')+'Z', f))
# Out:
# Python Hash of File | Start Date | File Size
# -2897497954974540665 2020-01-31T21:03:23Z 2020-02-01T07:55:23Z 1513848
# 37428944624398684 2020-02-01T07:55:23Z 2020-02-01T08:17:13Z 1521034
# 2594315964674133613 2020-02-01T08:17:13Z 2020-02-01T08:19:23Z 3166628
# -5958892510480470689 2020-02-01T08:19:23Z 2020-02-01T08:21:33Z 3166628
# -7085627884421940977 2020-02-01T08:21:33Z 2020-02-01T08:23:43Z 3166628
# -6655426856081156260 2020-02-01T08:23:43Z 2020-02-01T08:26:03Z 3396580
# 6486493426938573185 2020-02-01T08:26:03Z 2020-02-01T08:28:13Z 3166628
# -3352788590612995755 2020-02-01T08:28:13Z 2020-02-01T08:30:23Z 3159442
# -2769170418102329978 2020-02-01T08:30:23Z 2020-02-01T08:37:13Z 3152256
# 5535292942423015907 2020-02-01T08:37:13Z 2020-02-01T08:39:33Z 3396580
# 6524401821450331057 2020-02-01T08:39:33Z 2020-02-01T08:41:53Z 3396580
# 610330354237872011 2020-02-01T08:41:53Z 2020-02-01T08:44:13Z 3403766
# 3552024716765160502 2020-02-01T08:44:13Z 2020-02-01T08:46:33Z 3396580
# 4353234088540681730 2020-02-01T08:46:33Z 2020-02-01T08:48:53Z 3396580
# 112207326345672290 2020-02-01T08:48:53Z 2020-02-02T05:53:53Z 3389394

# %%
cloud_catalog1[:2]
# Out:
#                   start                stop  \
# 589 2020-01-31 21:03:23 2020-02-01 07:55:23
# 590 2020-02-01 07:55:23 2020-02-01 08:17:13
#
#                                                datakey  filesize
# 589  s3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/...   1513848
# 590  s3://gov-nasa-hdrl-data1/spdf/cdaweb/mms/mms1/...   1521034

# %%
def plot_cdf(s3_uri, d, f):
    cdf = cdflib.CDF(s3_uri)
    
    print(len(cdf.cdf_info().zVariables), d.replace(' ', 'T')+'Z', f)
    
    # Get the variable name and its data
    var_name = cdf.cdf_info().zVariables[2]
    var_data = cdf.varget(var_name)

    # Plot the variable
    plt.figure()
    plt.plot(var_data)
    plt.xlabel("Index")
    plt.ylabel(var_name)
    plt.title(f"Plot of {var_name}")
    plt.show()

print('# of zVariables | Start Date | File Size')
fr.stream_uri(cloud_catalog1[:2], lambda s3_uri, d, e, f: plot_cdf(s3_uri, d, f))
# Out:
# # of zVariables | Start Date | File Size
# 77 2020-01-31T21:03:23Z 1513848
# 77 2020-02-01T07:55:23Z 1521034

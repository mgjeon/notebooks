# %% [markdown]
# # Neural ODEs in NeuroMANCER
#
#
# This tutorial demonstrates the use of [Neural Ordinary Differential Equations](https://arxiv.org/abs/1806.07366) (NODE) for system identificaiton of dynamical systems.
#
#
# ## System Identification Problem Setup
#
# <img src="https://github.com/pnnl/neuromancer/blob/master/examples/figs/NODE.PNG?raw=1" width="600">
#
#
# Starting from a given initial condition  $x_{0}$, the next state of the system  $x_{k+1}$
# is obtained by feeding the current state $x_{k}$ into the neural network $N$ that generates a derivative to be
# integrated using an integration scheme $\int$. In system identification, the loss $\mathcal{L}$ is evaluated by comparing the  trajectory generated by the model with the training trajectory. The process can be repeated for multiple trajectories to improve the generalization of the model.
#
#
# ### References
#
# [1] [Ricky T. Q. Chen, Yulia Rubanova, Jesse Bettencourt, David Duvenaud, Neural Ordinary Differential Equations, NeurIPS 2018](https://arxiv.org/abs/1806.07366)
# [2] http://implicit-layers-tutorial.org/neural_odes/
# [3] https://github.com/Zymrael/awesome-neural-ode
# [4] https://rkevingibson.github.io/blog/neural-networks-as-ordinary-differential-equations/
# [5] [Christian Legaard, Thomas Schranz, Gerald Schweiger, Ján Drgoňa, Basak Falay, Cláudio Gomes, Alexandros Iosifidis, Mahdi Abkar, and Peter Larsen. 2023. Constructing Neural Network Based Models for Simulating Dynamical Systems. ACM Comput. Surv. 55, 11, Article 236 (November 2023), 34 pages.](https://dl.acm.org/doi/10.1145/3567591)
#
# - https://colab.research.google.com/github/pnnl/neuromancer/blob/master/examples/ODEs/Part_1_NODE.ipynb

# %%
import torch
from neuromancer.psl import plot
from neuromancer import psl
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

from neuromancer.system import Node, System
from neuromancer.dynamics import integrators, ode
from neuromancer.trainer import Trainer
from neuromancer.problem import Problem
from neuromancer.loggers import BasicLogger
from neuromancer.dataset import DictDataset
from neuromancer.constraint import variable
from neuromancer.loss import PenaltyLoss
from neuromancer.modules import blocks

torch.manual_seed(0);

# %% [markdown]
# ## Generate trajectories from ODE system
#
# Consider the [VanDerPol system](https://en.wikipedia.org/wiki/Van_der_Pol_oscillator) defined by the [ordinary differential equations](https://en.wikipedia.org/wiki/Ordinary_differential_equation):
#
# $$
#  \frac{dx_1}{dt} = \mu (x_1 - \frac{1}{3}x_1^3 - x_2)
# $$
# $$
#  \frac{dx_2}{dt} = \frac{x_1}{\mu}
# $$
#
# In this example we don't assume any prior knowledge on the system dynamics. We will only have access to limited measurements of the system states $x$.

# %%
# %%  ground truth system
system = psl.systems['VanDerPol']
modelSystem = system()
ts = modelSystem.ts
nx = modelSystem.nx
raw = modelSystem.simulate(nsim=1000, ts=ts)
plot.pltOL(Y=raw['Y'])
plot.pltPhase(X=raw['Y'])

# %% [markdown]
# ## Create training data of sampled trajectories
#
# We will obtain a dataset of sampled trajectories of the system dynamics to model:
# $$\hat{X} = [\hat{x}^i_0, ..., \hat{x}^i_{N}], \, \, i \in [1, ..., m]$$
# where $N$ represents the prediction horizon, $m$ represents number of measured trajectories, and $i$ represents an index of the sampled trajectory.

# %%
def get_data(sys, nsim, nsteps, ts, bs):
    """
    :param nsteps: (int) Number of timesteps for each batch of training data
    :param sys: (psl.system)
    :param ts: (float) step size
    :param bs: (int) batch size

    """
    train_sim, dev_sim, test_sim = [sys.simulate(nsim=nsim, ts=ts) for i in range(3)]
    nx = sys.nx
    nbatch = nsim//nsteps
    length = (nsim//nsteps) * nsteps

    trainX = train_sim['X'][:length].reshape(nbatch, nsteps, nx)
    trainX = torch.tensor(trainX, dtype=torch.float32)
    train_data = DictDataset({'X': trainX, 'xn': trainX[:, 0:1, :]}, name='train')
    train_loader = DataLoader(train_data, batch_size=bs,
                              collate_fn=train_data.collate_fn, shuffle=True)

    devX = dev_sim['X'][:length].reshape(nbatch, nsteps, nx)
    devX = torch.tensor(devX, dtype=torch.float32)
    dev_data = DictDataset({'X': devX, 'xn': devX[:, 0:1, :]}, name='dev')
    dev_loader = DataLoader(dev_data, batch_size=bs,
                            collate_fn=dev_data.collate_fn, shuffle=True)

    testX = test_sim['X'][:length].reshape(1, nsim, nx)
    testX = torch.tensor(testX, dtype=torch.float32)
    test_data = {'X': testX, 'xn': testX[:, 0:1, :]}

    return train_loader, dev_loader, test_data

# %%
nsim = 600   # number of simulation steps in the dataset
nsteps = 2   # number of prediction horizon steps in the loss function
bs = 100     # minibatching batch size
train_loader, dev_loader, test_data = get_data(modelSystem, nsim, nsteps, ts, bs)

# %% [markdown]
# ## NODE system model in Neuromancer
#
# Here we construct a continuous-time NODE model  $\dot{x} = f_{\theta}(x)$ with trainable parameters $\theta$.

# %%
# define neural network of the NODE
fx = blocks.MLP(nx, nx, bias=True,
                linear_map=torch.nn.Linear,
                nonlin=torch.nn.ReLU,
                hsizes=[60, 60, 60])

# %% [markdown]
# Next we need to solve the continuous-time NODE model with suitable ODE solver, e.g., [Runge–Kutta integrator](https://en.wikipedia.org/wiki/Runge%E2%80%93Kutta_methods).
# $x_{k+1} = \text{ODESolve}(f_{\theta}(x_k))$
#
# For training we need to obtain accurate reverse-mode gradients of the integrated NODE system. This can be done in two ways, either by unrolling the operations of the ODE solver and using the [backpropagation through time](https://en.wikipedia.org/wiki/Backpropagation_through_time) (BPTT) algorithm, or via [Adjoint state method](https://en.wikipedia.org/wiki/Adjoint_state_method).
#
# Schematics illustrating the adjoing method used in the [Neural Ordinary Differential Equations](https://arxiv.org/abs/1806.07366) paper:
# <img src="https://github.com/pnnl/neuromancer/blob/master/examples/figs/NODE_backprop.png?raw=1" width="500">
#
# Neuromancer provides a set of ODE solvers implemented in [integrators.py](https://github.com/pnnl/neuromancer/blob/master/src/neuromancer/dynamics/integrators.py).
# For adjoint method we provide the interface to the [open-source implementation](https://github.com/rtqichen/torchdiffeq) via DiffEqIntegrator class.

# %%
# integrate NODE with adjoint-based solver
fxRK4 = integrators.DiffEqIntegrator(fx, h=ts, method='rk4')

# %% [markdown]
# Next we construct an open-loop system composed of a symbolic NODE model

# %%
# create symbolic system model in Neuromancer
model = Node(fxRK4, ['xn'], ['xn'], name='NODE')
dynamics_model = System([model], name='system', nsteps=nsteps)

# %% [markdown]
# ## Define system identification loss function terms
#
# Here we define loss function terms to fit the ODE parameters from given time-series data.
#
# **Tracking loss:**
# $$\ell_x = Q_x||x^i_k - \hat{x}^i_k||_2^2$$
# **Finite difference loss:**
# $$\ell_{dx} =  Q_{dx}||\Delta x^i_k - \Delta \hat{x}^i_k||_2^2$$
# where $\Delta x^i_k = x^i_{k+1} - x^i_k$

# %%
# %% Constraints + losses:
x = variable("X")
xhat = variable('xn')[:, :-1, :]
# finite difference variables
xFD = (x[:, 1:, :] - x[:, :-1, :])
xhatFD = (xhat[:, 1:, :] - xhat[:, :-1, :])

# trajectory tracking loss
reference_loss = (xhat == x)^2
reference_loss.name = "ref_loss"

# finite difference loss
fd_loss = 2.*(xFD == xhatFD)^2
fd_loss.name = 'FD_loss'

# %% [markdown]
# ## Construct System ID learning problem
#
# Given the training dataset $\hat{X} = [\hat{x}^i_0, ..., \hat{x}^i_{N}]$ we want to solve the following problem:
#
# $$
# \begin{align}
# &\underset{\theta}{\text{minimize}}     && \sum_{i=1}^m \Big(\sum_{k=1}^{N}  Q_x||x^i_k - \hat{x}^i_k||_2^2  +  \sum_{k=1}^{N-1}  Q_{dx}||\Delta x^i_k - \Delta \hat{x}^i_k||_2^2  \Big) \\
# &\text{subject to}    && x^i_{k+1} =  \text{ODESolve}(f_{\theta}(x^i_k)) \\
# \end{align}
# $$

# %%
# aggregate list of objective terms and constraints
objectives = [reference_loss, fd_loss]
constraints = []
# create constrained optimization loss
loss = PenaltyLoss(objectives, constraints)
# construct constrained optimization problem
problem = Problem([dynamics_model], loss)

# %%
# plot computational graph
problem.show()

# %% [markdown]
# ## Solve the problem
#
# We fit the unknown NODE parameters $\theta$ using stochastic gradient descent.

# %%
optimizer = torch.optim.Adam(problem.parameters(), lr=0.001)
logger = BasicLogger(args=None, savedir='test', verbosity=1,
                     stdout=['dev_loss', 'train_loss'])
# define neuromancer trainer
trainer = Trainer(
    problem,
    train_loader,
    dev_loader,
    test_data,
    optimizer,
    patience=50,
    warmup=100,
    epochs=500,
    eval_metric="dev_loss",
    train_metric="train_loss",
    dev_metric="dev_loss",
    test_metric="dev_loss",
    logger=logger,
)
# Out:
# None
# Number of parameters: 7622

# %%
# %% train
best_model = trainer.train()
problem.load_state_dict(best_model)
# Out:
# epoch: 0	train_loss: 0.04616	dev_loss: 0.04439	eltime:  8.88977
# epoch: 1	train_loss: 0.04229	dev_loss: 0.04218	eltime:  8.93529
# epoch: 2	train_loss: 0.04167	dev_loss: 0.04180	eltime:  8.97854
# epoch: 3	train_loss: 0.03413	dev_loss: 0.03351	eltime:  9.01383
# epoch: 4	train_loss: 0.03059	dev_loss: 0.02892	eltime:  9.05454
# epoch: 5	train_loss: 0.02564	dev_loss: 0.02503	eltime:  9.09801
# epoch: 6	train_loss: 0.02355	dev_loss: 0.02029	eltime:  9.14008
# epoch: 7	train_loss: 0.01770	dev_loss: 0.01689	eltime:  9.17750
# epoch: 8	train_loss: 0.01419	dev_loss: 0.01275	eltime:  9.21570
# epoch: 9	train_loss: 0.00927	dev_loss: 0.00872	eltime:  9.25754
# epoch: 10	train_loss: 0.00631	dev_loss: 0.00595	eltime:  9.30020
# epoch: 11	train_loss: 0.00430	dev_loss: 0.00368	eltime:  9.34501
# epoch: 12	train_loss: 0.00309	dev_loss: 0.00285	eltime:  9.39746
# epoch: 13	train_loss: 0.00317	dev_loss: 0.00305	eltime:  9.43796
# epoch: 14	train_loss: 0.00260	dev_loss: 0.00232	eltime:  9.47618
# epoch: 15	train_loss: 0.00224	dev_loss: 0.00163	eltime:  9.54048
# epoch: 16	train_loss: 0.00149	dev_loss: 0.00127	eltime:  9.58575
# epoch: 17	train_loss: 0.00103	dev_loss: 0.00086	eltime:  9.62468
# epoch: 18	train_loss: 0.00104	dev_loss: 0.00094	eltime:  9.66473
# epoch: 19	train_loss: 0.00108	dev_loss: 0.00077	eltime:  9.70257
# epoch: 20	train_loss: 0.00068	dev_loss: 0.00074	eltime:  9.74317
# epoch: 21	train_loss: 0.00057	dev_loss: 0.00059	eltime:  9.79076
# epoch: 22	train_loss: 0.00046	dev_loss: 0.00044	eltime:  9.83267
# epoch: 23	train_loss: 0.00043	dev_loss: 0.00042	eltime:  9.87493
# epoch: 24	train_loss: 0.00038	dev_loss: 0.00030	eltime:  9.92285
# epoch: 25	train_loss: 0.00038	dev_loss: 0.00032	eltime:  9.96531
# epoch: 26	train_loss: 0.00027	dev_loss: 0.00022	eltime:  10.00200
# epoch: 27	train_loss: 0.00021	dev_loss: 0.00022	eltime:  10.03792
# epoch: 28	train_loss: 0.00021	dev_loss: 0.00020	eltime:  10.08682
# epoch: 29	train_loss: 0.00021	dev_loss: 0.00017	eltime:  10.13213
# epoch: 30	train_loss: 0.00016	dev_loss: 0.00016	eltime:  10.17136
# epoch: 31	train_loss: 0.00015	dev_loss: 0.00015	eltime:  10.22476
# epoch: 32	train_loss: 0.00013	dev_loss: 0.00012	eltime:  10.26607
# epoch: 33	train_loss: 0.00011	dev_loss: 0.00011	eltime:  10.30318
# epoch: 34	train_loss: 0.00010	dev_loss: 0.00010	eltime:  10.35227
# epoch: 35	train_loss: 0.00010	dev_loss: 0.00010	eltime:  10.39938
# epoch: 36	train_loss: 0.00010	dev_loss: 0.00009	eltime:  10.50715
# epoch: 37	train_loss: 0.00009	dev_loss: 0.00008	eltime:  10.58850
# epoch: 38	train_loss: 0.00008	dev_loss: 0.00008	eltime:  10.65277
# epoch: 39	train_loss: 0.00007	dev_loss: 0.00006	eltime:  10.69972
# epoch: 40	train_loss: 0.00006	dev_loss: 0.00007	eltime:  10.73775
# epoch: 41	train_loss: 0.00006	dev_loss: 0.00005	eltime:  10.77849
# epoch: 42	train_loss: 0.00006	dev_loss: 0.00005	eltime:  10.81936
# epoch: 43	train_loss: 0.00005	dev_loss: 0.00005	eltime:  10.86223
# epoch: 44	train_loss: 0.00004	dev_loss: 0.00004	eltime:  10.91256
# epoch: 45	train_loss: 0.00004	dev_loss: 0.00005	eltime:  10.96189
# epoch: 46	train_loss: 0.00005	dev_loss: 0.00004	eltime:  11.01284
# epoch: 47	train_loss: 0.00003	dev_loss: 0.00004	eltime:  11.05653
# epoch: 48	train_loss: 0.00004	dev_loss: 0.00003	eltime:  11.09945
# epoch: 49	train_loss: 0.00003	dev_loss: 0.00003	eltime:  11.14805
# epoch: 50	train_loss: 0.00004	dev_loss: 0.00003	eltime:  11.18813
# epoch: 51	train_loss: 0.00003	dev_loss: 0.00003	eltime:  11.22531
# epoch: 52	train_loss: 0.00003	dev_loss: 0.00003	eltime:  11.26760
# epoch: 53	train_loss: 0.00003	dev_loss: 0.00002	eltime:  11.30973
# epoch: 54	train_loss: 0.00003	dev_loss: 0.00003	eltime:  11.35063
# epoch: 55	train_loss: 0.00002	dev_loss: 0.00003	eltime:  11.38052
# epoch: 56	train_loss: 0.00003	dev_loss: 0.00002	eltime:  11.42043
# epoch: 57	train_loss: 0.00002	dev_loss: 0.00002	eltime:  11.46660
# epoch: 58	train_loss: 0.00003	dev_loss: 0.00002	eltime:  11.51186
# epoch: 59	train_loss: 0.00002	dev_loss: 0.00002	eltime:  11.54992
# epoch: 60	train_loss: 0.00002	dev_loss: 0.00002	eltime:  11.59637
# epoch: 61	train_loss: 0.00002	dev_loss: 0.00002	eltime:  11.63120
# epoch: 62	train_loss: 0.00002	dev_loss: 0.00002	eltime:  11.66385
# epoch: 63	train_loss: 0.00002	dev_loss: 0.00001	eltime:  11.70109
# epoch: 64	train_loss: 0.00002	dev_loss: 0.00002	eltime:  11.73747
# epoch: 65	train_loss: 0.00001	dev_loss: 0.00002	eltime:  11.77447
# epoch: 66	train_loss: 0.00002	dev_loss: 0.00002	eltime:  11.81121
# epoch: 67	train_loss: 0.00002	dev_loss: 0.00002	eltime:  11.84622
# epoch: 68	train_loss: 0.00002	dev_loss: 0.00001	eltime:  11.88123
# epoch: 69	train_loss: 0.00002	dev_loss: 0.00001	eltime:  11.91828
# epoch: 70	train_loss: 0.00001	dev_loss: 0.00001	eltime:  11.96180
# epoch: 71	train_loss: 0.00001	dev_loss: 0.00001	eltime:  12.01860
# epoch: 72	train_loss: 0.00001	dev_loss: 0.00002	eltime:  12.06917
# epoch: 73	train_loss: 0.00001	dev_loss: 0.00001	eltime:  12.12153
# epoch: 74	train_loss: 0.00001	dev_loss: 0.00001	eltime:  12.16153
# epoch: 75	train_loss: 0.00001	dev_loss: 0.00001	eltime:  12.19685
# epoch: 76	train_loss: 0.00001	dev_loss: 0.00001	eltime:  12.23048
# epoch: 77	train_loss: 0.00001	dev_loss: 0.00001	eltime:  12.27313
# epoch: 78	train_loss: 0.00001	dev_loss: 0.00001	eltime:  12.31825
# epoch: 79	train_loss: 0.00001	dev_loss: 0.00001	eltime:  12.35602
# epoch: 80	train_loss: 0.00001	dev_loss: 0.00001	eltime:  12.39199
# epoch: 81	train_loss: 0.00001	dev_loss: 0.00001	eltime:  12.43055
# epoch: 82	train_loss: 0.00001	dev_loss: 0.00001	eltime:  12.46974
# epoch: 83	train_loss: 0.00001	dev_loss: 0.00001	eltime:  12.51372
# epoch: 84	train_loss: 0.00002	dev_loss: 0.00001	eltime:  12.55742
# epoch: 85	train_loss: 0.00001	dev_loss: 0.00001	eltime:  12.59294
# epoch: 86	train_loss: 0.00001	dev_loss: 0.00001	eltime:  12.63346
# epoch: 87	train_loss: 0.00001	dev_loss: 0.00001	eltime:  12.67139
# epoch: 88	train_loss: 0.00001	dev_loss: 0.00001	eltime:  12.71881
# epoch: 89	train_loss: 0.00001	dev_loss: 0.00001	eltime:  12.77566
# epoch: 90	train_loss: 0.00001	dev_loss: 0.00001	eltime:  12.81160
# epoch: 91	train_loss: 0.00001	dev_loss: 0.00001	eltime:  12.85169
# epoch: 92	train_loss: 0.00001	dev_loss: 0.00001	eltime:  12.88757
# epoch: 93	train_loss: 0.00001	dev_loss: 0.00001	eltime:  12.92411
# epoch: 94	train_loss: 0.00001	dev_loss: 0.00001	eltime:  12.97143
# epoch: 95	train_loss: 0.00001	dev_loss: 0.00000	eltime:  13.00955
# epoch: 96	train_loss: 0.00001	dev_loss: 0.00001	eltime:  13.04095
# epoch: 97	train_loss: 0.00001	dev_loss: 0.00001	eltime:  13.07317
# epoch: 98	train_loss: 0.00001	dev_loss: 0.00000	eltime:  13.10944
# epoch: 99	train_loss: 0.00001	dev_loss: 0.00000	eltime:  13.14803
# epoch: 100	train_loss: 0.00001	dev_loss: 0.00000	eltime:  13.18165
# epoch: 101	train_loss: 0.00000	dev_loss: 0.00001	eltime:  13.21847
# epoch: 102	train_loss: 0.00000	dev_loss: 0.00000	eltime:  13.25739
# epoch: 103	train_loss: 0.00001	dev_loss: 0.00001	eltime:  13.31573
# epoch: 104	train_loss: 0.00000	dev_loss: 0.00001	eltime:  13.35762
# epoch: 105	train_loss: 0.00000	dev_loss: 0.00001	eltime:  13.39432
# epoch: 106	train_loss: 0.00000	dev_loss: 0.00001	eltime:  13.43320
# epoch: 107	train_loss: 0.00000	dev_loss: 0.00001	eltime:  13.47197
# epoch: 108	train_loss: 0.00000	dev_loss: 0.00001	eltime:  13.50979
# epoch: 109	train_loss: 0.00000	dev_loss: 0.00000	eltime:  13.55289
# epoch: 110	train_loss: 0.00001	dev_loss: 0.00001	eltime:  13.59300
# epoch: 111	train_loss: 0.00000	dev_loss: 0.00001	eltime:  13.62790
# epoch: 112	train_loss: 0.00000	dev_loss: 0.00001	eltime:  13.66118
# epoch: 113	train_loss: 0.00001	dev_loss: 0.00000	eltime:  13.70158
# epoch: 114	train_loss: 0.00000	dev_loss: 0.00001	eltime:  13.74376
# epoch: 115	train_loss: 0.00001	dev_loss: 0.00001	eltime:  13.79931
# epoch: 116	train_loss: 0.00000	dev_loss: 0.00000	eltime:  13.83649
# epoch: 117	train_loss: 0.00000	dev_loss: 0.00000	eltime:  13.88345
# epoch: 118	train_loss: 0.00001	dev_loss: 0.00001	eltime:  13.91689
# epoch: 119	train_loss: 0.00000	dev_loss: 0.00001	eltime:  13.95414
# epoch: 120	train_loss: 0.00001	dev_loss: 0.00001	eltime:  13.99829
# epoch: 121	train_loss: 0.00001	dev_loss: 0.00000	eltime:  14.05404
# epoch: 122	train_loss: 0.00000	dev_loss: 0.00000	eltime:  14.09730
# epoch: 123	train_loss: 0.00001	dev_loss: 0.00000	eltime:  14.13762
# epoch: 124	train_loss: 0.00001	dev_loss: 0.00001	eltime:  14.18207
# epoch: 125	train_loss: 0.00000	dev_loss: 0.00001	eltime:  14.22060
# epoch: 126	train_loss: 0.00001	dev_loss: 0.00000	eltime:  14.26499
# epoch: 127	train_loss: 0.00000	dev_loss: 0.00000	eltime:  14.33617
# epoch: 128	train_loss: 0.00000	dev_loss: 0.00000	eltime:  14.38075
# epoch: 129	train_loss: 0.00000	dev_loss: 0.00000	eltime:  14.42176
# epoch: 130	train_loss: 0.00000	dev_loss: 0.00000	eltime:  14.45563
# epoch: 131	train_loss: 0.00000	dev_loss: 0.00000	eltime:  14.50422
# epoch: 132	train_loss: 0.00001	dev_loss: 0.00001	eltime:  14.54953
# epoch: 133	train_loss: 0.00000	dev_loss: 0.00000	eltime:  14.59896
# epoch: 134	train_loss: 0.00000	dev_loss: 0.00000	eltime:  14.67608
# epoch: 135	train_loss: 0.00000	dev_loss: 0.00001	eltime:  14.72709
# epoch: 136	train_loss: 0.00001	dev_loss: 0.00000	eltime:  14.76840
# epoch: 137	train_loss: 0.00000	dev_loss: 0.00001	eltime:  14.80444
# epoch: 138	train_loss: 0.00001	dev_loss: 0.00001	eltime:  14.85656
# epoch: 139	train_loss: 0.00001	dev_loss: 0.00000	eltime:  14.90752
# epoch: 140	train_loss: 0.00000	dev_loss: 0.00000	eltime:  14.95754
# epoch: 141	train_loss: 0.00000	dev_loss: 0.00000	eltime:  14.99272
# epoch: 142	train_loss: 0.00000	dev_loss: 0.00001	eltime:  15.03179
# epoch: 143	train_loss: 0.00001	dev_loss: 0.00001	eltime:  15.06916
# epoch: 144	train_loss: 0.00001	dev_loss: 0.00000	eltime:  15.10189
# epoch: 145	train_loss: 0.00000	dev_loss: 0.00001	eltime:  15.13792
# epoch: 146	train_loss: 0.00001	dev_loss: 0.00000	eltime:  15.17263
# epoch: 147	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.21348
# epoch: 148	train_loss: 0.00001	dev_loss: 0.00000	eltime:  15.24904
# epoch: 149	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.28696
# epoch: 150	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.32310
# epoch: 151	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.37683
# epoch: 152	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.41501
# epoch: 153	train_loss: 0.00000	dev_loss: 0.00001	eltime:  15.45698
# epoch: 154	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.50567
# epoch: 155	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.54422
# epoch: 156	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.58132
# epoch: 157	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.62105
# epoch: 158	train_loss: 0.00000	dev_loss: 0.00001	eltime:  15.65812
# epoch: 159	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.70539
# epoch: 160	train_loss: 0.00000	dev_loss: 0.00001	eltime:  15.74347
# epoch: 161	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.78263
# epoch: 162	train_loss: 0.00001	dev_loss: 0.00000	eltime:  15.84047
# epoch: 163	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.88729
# epoch: 164	train_loss: 0.00000	dev_loss: 0.00001	eltime:  15.92878
# epoch: 165	train_loss: 0.00001	dev_loss: 0.00000	eltime:  15.97637
# epoch: 166	train_loss: 0.00001	dev_loss: 0.00000	eltime:  16.01325
# epoch: 167	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.05533
# epoch: 168	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.10450
# epoch: 169	train_loss: 0.00000	dev_loss: 0.00001	eltime:  16.14832
# epoch: 170	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.18124
# epoch: 171	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.23064
# epoch: 172	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.27019
# epoch: 173	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.31865
# epoch: 174	train_loss: 0.00000	dev_loss: 0.00001	eltime:  16.35163
# epoch: 175	train_loss: 0.00000	dev_loss: 0.00001	eltime:  16.39137
# epoch: 176	train_loss: 0.00001	dev_loss: 0.00000	eltime:  16.43267
# epoch: 177	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.46743
# epoch: 178	train_loss: 0.00000	dev_loss: 0.00001	eltime:  16.51441
# epoch: 179	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.55910
# epoch: 180	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.60548
# epoch: 181	train_loss: 0.00001	dev_loss: 0.00000	eltime:  16.65550
# epoch: 182	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.69839
# epoch: 183	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.74364
# epoch: 184	train_loss: 0.00000	dev_loss: 0.00001	eltime:  16.78183
# epoch: 185	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.82111
# epoch: 186	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.87088
# epoch: 187	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.90699
# epoch: 188	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.94866
# epoch: 189	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.99216
# epoch: 190	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.02223
# epoch: 191	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.06671
# epoch: 192	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.09867
# epoch: 193	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.13006
# epoch: 194	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.16822
# epoch: 195	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.20759
# epoch: 196	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.24467
# epoch: 197	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.27814
# epoch: 198	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.31396
# epoch: 199	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.35626
# epoch: 200	train_loss: 0.00001	dev_loss: 0.00000	eltime:  17.39326
# epoch: 201	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.42741
# epoch: 202	train_loss: 0.00001	dev_loss: 0.00001	eltime:  17.46151
# epoch: 203	train_loss: 0.00001	dev_loss: 0.00000	eltime:  17.49661
# epoch: 204	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.53777
# epoch: 205	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.57767
# epoch: 206	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.61522
# epoch: 207	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.65846
# epoch: 208	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.68816
# epoch: 209	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.72270
# epoch: 210	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.76245
# epoch: 211	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.80347
# epoch: 212	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.84199
# epoch: 213	train_loss: 0.00001	dev_loss: 0.00001	eltime:  17.88274
# epoch: 214	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.91564
# epoch: 215	train_loss: 0.00000	dev_loss: 0.00001	eltime:  17.95134
# epoch: 216	train_loss: 0.00001	dev_loss: 0.00001	eltime:  17.99703
# epoch: 217	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.03805
# epoch: 218	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.07815
# epoch: 219	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.11352
# epoch: 220	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.18442
# epoch: 221	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.21860
# epoch: 222	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.25075
# epoch: 223	train_loss: 0.00001	dev_loss: 0.00000	eltime:  18.28718
# epoch: 224	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.32356
# epoch: 225	train_loss: 0.00001	dev_loss: 0.00000	eltime:  18.36127
# epoch: 226	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.40499
# epoch: 227	train_loss: 0.00001	dev_loss: 0.00000	eltime:  18.44957
# epoch: 228	train_loss: 0.00000	dev_loss: 0.00001	eltime:  18.48470
# epoch: 229	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.52949
# epoch: 230	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.57149
# epoch: 231	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.61132
# epoch: 232	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.65521
# epoch: 233	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.70082
# epoch: 234	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.73745
# epoch: 235	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.77440
# epoch: 236	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.81364
# epoch: 237	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.86164
# epoch: 238	train_loss: 0.00000	dev_loss: 0.00001	eltime:  18.89818
# Early stopping!!!
# <All keys matched successfully>

# %% [markdown]
# ## Parameter estimation results

# %%
# update the rollout length based on the test data
dynamics_model.nsteps = test_data['X'].shape[1]

# %%
# Test set results
test_outputs = dynamics_model(test_data)

pred_traj = test_outputs['xn'][:, :-1, :]
true_traj = test_data['X']
pred_traj = pred_traj.detach().numpy().reshape(-1, nx)
true_traj = true_traj.detach().numpy().reshape(-1, nx)
pred_traj, true_traj = pred_traj.transpose(1, 0), true_traj.transpose(1, 0)

# %%
# plot rollout
figsize = 25
fig, ax = plt.subplots(nx, figsize=(figsize, figsize))
labels = [f'$y_{k}$' for k in range(len(true_traj))]
for row, (t1, t2, label) in enumerate(zip(true_traj, pred_traj, labels)):
    if nx > 1:
        axe = ax[row]
    else:
        axe = ax
    axe.set_ylabel(label, rotation=0, labelpad=20, fontsize=figsize)
    axe.plot(t1, 'c', linewidth=4.0, label='True')
    axe.plot(t2, 'm--', linewidth=4.0, label='Pred')
    axe.tick_params(labelbottom=False, labelsize=figsize)
axe.tick_params(labelbottom=True, labelsize=figsize)
axe.legend(fontsize=figsize)
axe.set_xlabel('$time$', fontsize=figsize)
plt.tight_layout()

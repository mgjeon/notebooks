# %% [markdown]
# # YOLO11 Tutorial
#
# - https://github.com/ultralytics
# - https://colab.research.google.com/github/ultralytics/ultralytics/blob/main/examples/tutorial.ipynb

# %% [markdown]
# YOLO11 is the latest version of the YOLO (You Only Look Once) AI models developed by Ultralytics. (2024.12.01.)

# %%
from IPython.display import Image

# %%
from ultralytics import YOLO

# %% [markdown]
# ## 1. Detection

# %%
model = YOLO('yolo11n.pt')  # load a pretrained YOLO detection model
results = model('https://ultralytics.com/images/bus.jpg')  # predict on an image
results[0].save('output.jpg')
Image('output.jpg')
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /home/mgj/workspace/notebooks/YOLO/bus.jpg: 640x480 4 persons, 1 bus, 39.7ms
# Speed: 1.4ms preprocess, 39.7ms inference, 56.1ms postprocess per image at shape (1, 3, 640, 480)

# %% [markdown]
# ## 2. Segmentation

# %%
model = YOLO('yolo11n-seg.pt')  # load a pretrained YOLO segmentation model
results = model('https://ultralytics.com/images/bus.jpg')  # predict on an image
results[0].save('output.jpg')
Image('output.jpg')
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /home/mgj/workspace/notebooks/YOLO/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 14.3ms
# Speed: 1.5ms preprocess, 14.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)

# %% [markdown]
# ## 3. Classification

# %%
model = YOLO('yolo11n-cls.pt')  # load a pretrained YOLO classification model
results = model('https://ultralytics.com/images/bus.jpg')  # predict on an image
results[0].save('output.jpg')
Image('output.jpg')
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /home/mgj/workspace/notebooks/YOLO/bus.jpg: 224x224 minibus 0.57, police_van 0.34, trolleybus 0.04, recreational_vehicle 0.01, amphibian 0.01, 3.6ms
# Speed: 6.0ms preprocess, 3.6ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)

# %% [markdown]
# ## 4. Pose

# %%
model = YOLO('yolo11n-pose.pt')  # load a pretrained YOLO pose model
results = model('https://ultralytics.com/images/bus.jpg')  # predict on an image
results[0].save('output.jpg')
Image('output.jpg')
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /home/mgj/workspace/notebooks/YOLO/bus.jpg: 640x480 4 persons, 17.5ms
# Speed: 1.4ms preprocess, 17.5ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 480)

# %% [markdown]
# ## 5. Oriented Bounding Boxes (OBB)

# %%
model = YOLO('yolo11n-obb.pt')  # load a pretrained YOLO OBB model
results = model('https://ultralytics.com/images/boats.jpg')  # predict on an image
results[0].save('output.jpg')
Image('output.jpg')
# Out:
# Found https://ultralytics.com/images/boats.jpg locally at boats.jpg
# image 1/1 /home/mgj/workspace/notebooks/YOLO/boats.jpg: 576x1024 54.5ms
# Speed: 4.4ms preprocess, 54.5ms inference, 15.4ms postprocess per image at shape (1, 3, 576, 1024)

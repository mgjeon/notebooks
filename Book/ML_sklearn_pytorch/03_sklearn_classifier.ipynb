# %% [markdown]
# # Chapter 3: A Tour of Machine Learning Classifiers Using Scikit-Learn

# %% [markdown]
# ## Data

# %%
from sklearn import datasets
import numpy as np

# %%
iris = datasets.load_iris()

# %%
iris.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
iris.data.shape
# Out:
# (150, 4)

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target.shape
# Out:
# (150,)

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
X = iris.data[:, [2, 3]] 
y = iris.target

# %%
print('Class labels:', np.unique(y))
# Out:
# Class labels: [0 1 2]

# %%
from sklearn.model_selection import train_test_split

# %%
print(X.shape)
print(y.shape)
# Out:
# (150, 2)
# (150,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (105, 2)
# (45, 2)
# (105,)
# (45,)

# %%
print('Labels counts in y:', np.bincount(y))
# Out:
# Labels counts in y: [50 50 50]

# %%
print('Labels counts in y_train:', np.bincount(y_train))
# Out:
# Labels counts in y_train: [35 35 35]

# %%
print('Labels counts in y_test:', np.bincount(y_test))
# Out:
# Labels counts in y_test: [15 15 15]

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
sc.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

# %% [markdown]
# ## Perceptron

# %%
from sklearn.linear_model import Perceptron

# %%
ppn = Perceptron(eta0=0.1, random_state=1)

# %%
ppn.fit(X_train_std, y_train)
# Out:
# Perceptron(eta0=0.1, random_state=1)

# %%
y_pred = ppn.predict(X_test_std)

# %%
y_test
# Out:
# array([2, 0, 0, 2, 1, 1, 2, 1, 2, 0, 0, 2, 0, 1, 0, 1, 2, 1, 1, 2, 2, 0,
#        1, 2, 1, 1, 1, 2, 0, 2, 0, 0, 1, 1, 2, 2, 0, 0, 0, 1, 2, 2, 1, 0,
#        0])

# %%
y_pred
# Out:
# array([2, 0, 0, 2, 1, 1, 2, 1, 2, 0, 0, 2, 0, 1, 0, 1, 2, 1, 1, 2, 2, 0,
#        1, 2, 1, 1, 0, 2, 0, 2, 0, 0, 1, 1, 2, 2, 0, 0, 0, 1, 2, 2, 1, 0,
#        0])

# %%
print('Misclassified examples: {:d}'.format((y_test != y_pred).sum()))
# Out:
# Misclassified examples: 1

# %%
from sklearn.metrics import accuracy_score

print('Accuracy: {:.3f}'.format(accuracy_score(y_test, y_pred)))
# Out:
# Accuracy: 0.978

# %%
print('Accuracy: {:.3f}'.format(ppn.score(X_test_std, y_test)))
# Out:
# Accuracy: 0.978

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

def plot_decision_regions(X, y, classifier, test_idx=None, resolution=0.02):

    # setup marker generator and color map
    markers = ('o', 's', '^', 'v', '<')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])

    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))
    lab = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    lab = lab.reshape(xx1.shape)
    plt.contourf(xx1, xx2, lab, alpha=0.3, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    # plot class examples
    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], 
                    y=X[y == cl, 1],
                    alpha=0.8, 
                    c=colors[idx],
                    marker=markers[idx], 
                    label=f'Class {cl}', 
                    edgecolor='black')

    # highlight test examples
    if test_idx:
        # plot all examples
        X_test, y_test = X[test_idx, :], y[test_idx]

        plt.scatter(X_test[:, 0],
                    X_test[:, 1],
                    c='none',
                    edgecolor='black',
                    alpha=1.0,
                    linewidth=1,
                    marker='o',
                    s=100, 
                    label='Test set')

# %%
X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))

plot_decision_regions(X=X_combined_std, y=y_combined,
                      classifier=ppn, test_idx=range(105, 150))
plt.xlabel('Petal length [standardized]')
plt.ylabel('Petal width [standardized]')
plt.legend(loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier

lr = OneVsRestClassifier(LogisticRegression(C=100.0, solver='lbfgs'))
""" 
C: float, default=1.0
    - Inverse of regularization strength; must be a positive float. Like in support vector machines, smaller values specify stronger regularization.
"""
lr.fit(X_train_std, y_train)
print('Accuray: {:.3f}'.format(lr.score(X_test_std, y_test)))

plot_decision_regions(X_combined_std, y_combined,
                      classifier=lr, test_idx=range(105, 150))
plt.xlabel('Petal length [standardized]')
plt.ylabel('Petal width [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# Accuray: 0.978

# %%
lr.predict_proba(X_test_std[:3, :])
# Out:
# array([[6.63770505e-09, 1.44747233e-01, 8.55252760e-01],
#        [8.34031210e-01, 1.65968790e-01, 3.20815954e-13],
#        [8.48822884e-01, 1.51177116e-01, 2.57998350e-14]])

# %%
lr.predict_proba(X_test_std[:3, :]).sum(axis=1)
# Out:
# array([1., 1., 1.])

# %%
lr.predict_proba(X_test_std[:3, :]).argmax(axis=1)
# Out:
# array([2, 0, 0])

# %%
lr.predict(X_test_std[:3, :])
# Out:
# array([2, 0, 0])

# %%
try: 
    lr.predict(X_test_std[0, :])
except ValueError as e:
    print(e)
# Out:
# Expected 2D array, got 1D array instead:
# array=[0.89820289 1.44587881].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
lr.predict(X_test_std[0, :].reshape(1, -1))
# Out:
# array([2])

# %%
weights, params = [], []
for c in np.arange(-5, 5):
    lr = OneVsRestClassifier(LogisticRegression(C=10.**c))  # C: inverse regularization strength
    lr.fit(X_train_std, y_train)
    weights.append(lr.estimators_[1].coef_[0])  # weight coefficients of class 1 (versicolor)
    params.append(10.**c)

weights = np.array(weights)
plt.plot(params, weights[:, 0],
         label='Petal length')
plt.plot(params, weights[:, 1], linestyle='--',
         label='Petal width')
plt.ylabel('Weight coefficient')
plt.xlabel('<-- high regularization --      C      -- low regularization -->')
plt.legend(loc='upper left')
plt.xscale('log')
plt.show()

# %% [markdown]
# ## Support vector machine (SVM)

# %% [markdown]
# - Perceptron -> Minimize misclassification errors
# - Logistic regression -> Maximize conditional likelihood of the training data
# - SVM -> Maximize margin
#     - large C -> large error penalty -> low regularization
#     - small C -> small error penalty -> high regularization

# %%
from sklearn.svm import SVC

svm = SVC(kernel='linear', C=1.0, random_state=1)
svm.fit(X_train_std, y_train)
print('Accuray: {:.3f}'.format(svm.score(X_test_std, y_test)))

plot_decision_regions(X_combined_std, y_combined,
                      classifier=svm, test_idx=range(105, 150))
plt.xlabel('Petal length [standardized]')
plt.ylabel('Petal width [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# Accuray: 0.978

# %% [markdown]
# ## Kernel SVM

# %%
# XOR dataset
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(1)
X_xor = np.random.randn(200, 2)
y_xor = np.logical_xor(X_xor[:, 0] > 0,
                       X_xor[:, 1] > 0)
y_xor = np.where(y_xor, 1, 0)

plt.scatter(X_xor[y_xor == 0, 0],
            X_xor[y_xor == 0, 1],
            c='tomato',
            marker='o',
            label='Class 0')
plt.scatter(X_xor[y_xor == 1, 0],
            X_xor[y_xor == 1, 1],
            c='royalblue',
            marker='s',
            label='Class 1')

plt.xlim([-3, 3])
plt.ylim([-3, 3])
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')

plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %%
svm = SVC(kernel='rbf', random_state=1, gamma=0.1, C=10.0)
svm.fit(X_xor, y_xor)
print('Accuray: {:.3f}'.format(svm.score(X_xor, y_xor)))

plot_decision_regions(X_xor, y_xor, classifier=svm)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# Accuray: 0.910

# %%
svm = SVC(kernel='rbf', random_state=1, gamma=0.2, C=1.0)
svm.fit(X_train_std, y_train)
print('Accuray: {:.3f}'.format(svm.score(X_test_std, y_test)))

plot_decision_regions(X_combined_std, y_combined,
                      classifier=svm, test_idx=range(105, 150))
plt.xlabel('Petal length [standardized]')
plt.ylabel('Petal width [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# Accuray: 0.978

# %%
svm = SVC(kernel='rbf', random_state=1, gamma=100.0, C=1.0)
svm.fit(X_train_std, y_train)
print('Accuray: {:.3f}'.format(svm.score(X_test_std, y_test)))

plot_decision_regions(X_combined_std, y_combined,
                      classifier=svm, test_idx=range(105, 150))
plt.xlabel('Petal length [standardized]')
plt.ylabel('Petal width [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# Accuray: 0.933

# %% [markdown]
# ## Decision tree

# %% [markdown]
# - Objective: Maximize information gain at each split

# %%
from sklearn.tree import DecisionTreeClassifier

tree_model = DecisionTreeClassifier(criterion='gini',
                                    max_depth=4,
                                    random_state=1)
tree_model.fit(X_train, y_train)
print('Accuray: {:.3f}'.format(tree_model.score(X_test, y_test)))

X_combined = np.vstack((X_train, X_test))
y_combined = np.hstack((y_train, y_test))
plot_decision_regions(X_combined, y_combined,
                      classifier=tree_model, test_idx=range(105, 150))
plt.xlabel('Petal length [cm]')
plt.ylabel('Petal width [cm]')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# Accuray: 0.978

# %%
from sklearn import tree
feature_names = ['Petal length', 'Petal width']
tree.plot_tree(tree_model, feature_names=feature_names, filled=True)
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(n_estimators=25,
                                random_state=1,
                                n_jobs=2)
forest.fit(X_train, y_train)
print('Accuray: {:.3f}'.format(forest.score(X_test, y_test)))

plot_decision_regions(X_combined, y_combined,
                      classifier=forest, test_idx=range(105, 150))
plt.xlabel('Petal length [cm]')
plt.ylabel('Petal width [cm]')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# Accuray: 0.978

# %% [markdown]
# ## K-nearest neighbors (KNN)
#
# - lazy learning algorithm (instance-based learning with no cost for training)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5, p=2, metric='minkowski')
knn.fit(X_train_std, y_train)

print('Accuray: {:.3f}'.format(knn.score(X_test_std, y_test)))

plot_decision_regions(X_combined_std, y_combined,
                      classifier=knn, test_idx=range(105, 150))
plt.xlabel('Petal length [standardized]')
plt.ylabel('Petal width [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# Accuray: 1.000

# %% [markdown]
# ## RAPIDS: GPU Accelerated Data Science
#
# - https://rapids.ai
